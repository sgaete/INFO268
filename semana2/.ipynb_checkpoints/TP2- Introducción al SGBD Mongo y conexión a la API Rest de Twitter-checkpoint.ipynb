# %% [markdown]
# # TP2- Introducción al SGBD MongoDB y Conexión a la API Rest de Twitter

# %% [markdown]
# En este trabajo práctico queremos descubrir las características del SGBD no relacional MongoDB. En este sentido, vamos a desarrollar un script que se conecta a la API Rest de Twitter para: 1) descargar datos al formato JSON, 2) almacenarlos en una base Mongo y 3) realizar algunas consultas sobre los datos.

# %% [markdown]
# ## 1. Conectarse a la API Rest de Twitter

# %% [markdown]
# - ¿Cómo crear una aplicación utilizando los datos de Twitter?: https://developer.twitter.com/en/docs/basics/getting-started
# - Crear una aplicación utilizando los datos de Twitter: https://apps.twitter.com/
# - ¿Qué deberían saber todos los desarrolladores antes de jugar con la API de twitter?: https://developer.twitter.com/en/docs/basics/things-every-developer-should-know

# %%
from twython import Twython
APP_KEY = ''
APP_SECRET = ''
OAUTH_TOKEN = ''
OAUTH_TOKEN_SECRET = ''
twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %% [markdown]
# ## 2. Consultar la API de Twitter

# %% [markdown]
# - Utilizando una librería Python que permite enviar consultas HTTP a la API de Twitter, conectarse a un 'endpoint' de la API para leer datos. Ver la lista de los endpoints: https://developer.twitter.com/en/docs/tweets/post-and-engage/overview

# %%
import pprint
results = twitter.search(q="valdivia", )
pprint.pprint(results['statuses'])
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:43:56 +0000 2018',
#   'entities': {'hashtags': [{'indices': [0, 17], 'text': 'QuieroMiSpalding'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985302668112531456,
#   'id_str': '985302668112531456',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" '
#             'rel="nofollow">Twitter for Android</a>',
#   'text': '#QuieroMiSpalding saludos desde las Animas, Valdivia. Apoyando a '
#           'los fantasmas. Cariños',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sun Jul 02 06:22:14 +0000 2017',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': '',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 1,
#            'follow_request_sent': False,
#            'followers_count': 2,
#            'following': False,
#            'friends_count': 18,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 881397582433538048,
#            'id_str': '881397582433538048',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'es',
#            'listed_count': 0,
#            'location': '',
#            'name': 'Ivonne Fernandez',
#            'notifications': False,
#            'profile_background_color': 'F5F8FA',
#            'profile_background_image_url': None,
#            'profile_background_image_url_https': None,
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/881403025016967168/NiCSKMHz_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/881403025016967168/NiCSKMHz_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'VonchyValdivia',
#            'statuses_count': 15,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:43:51 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 95539786,
#                                   'id_str': '95539786',
#                                   'indices': [3, 15],
#                                   'name': '#poderanimal',
#                                   'screen_name': 'poderanimal'},
#                                  {'id': 4661601869,
#                                   'id_str': '4661601869',
#                                   'indices': [17, 27],
#                                   'name': 'Jime',
#                                   'screen_name': 'jimenab67'},
#                                  {'id': 116848943,
#                                   'id_str': '116848943',
#                                   'indices': [28, 44],
#                                   'name': 'Perros Tuiteros🐾 y Furiosos '
#                                           '\U0001f98a',
#                                   'screen_name': 'PerrosPlazaHuem'},
#                                  {'id': 394320248,
#                                   'id_str': '394320248',
#                                   'indices': [45, 57],
#                                   'name': 'Sita Marce',
#                                   'screen_name': 'Chilena9772'},
#                                  {'id': 95942356,
#                                   'id_str': '95942356',
#                                   'indices': [58, 64],
#                                   'name': 'vero',
#                                   'screen_name': 'ver65'},
#                                  {'id': 726195092,
#                                   'id_str': '726195092',
#                                   'indices': [65, 73],
#                                   'name': 'silfon',
#                                   'screen_name': 'silvfon'},
#                                  {'id': 118784585,
#                                   'id_str': '118784585',
#                                   'indices': [74, 87],
#                                   'name': 'Carabineros de Chile',
#                                   'screen_name': 'Carabdechile'},
#                                  {'id': 226192416,
#                                   'id_str': '226192416',
#                                   'indices': [88, 97],
#                                   'name': 'UAA Chile',
#                                   'screen_name': 'UaaChile'},
#                                  {'id': 541906006,
#                                   'id_str': '541906006',
#                                   'indices': [98, 114],
#                                   'name': 'romina saez',
#                                   'screen_name': 'rominasaoficial'},
#                                  {'id': 510561598,
#                                   'id_str': '510561598',
#                                   'indices': [115, 131],
#                                   'name': 'MYRIAM HILL AVALOS',
#                                   'screen_name': 'MYRIAMHILLAVALO'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985302647614902272,
#   'id_str': '985302647614902272',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Sat Apr 14 22:04:07 +0000 2018',
#                        'entities': {'hashtags': [],
#                                     'symbols': [],
#                                     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                                               'expanded_url': 'https://twitter.com/i/web/status/985277545833750528',
#                                               'indices': [116, 139],
#                                               'url': 'https://t.co/kKU0DSoBRi'}],
#                                     'user_mentions': [{'id': 4661601869,
#                                                        'id_str': '4661601869',
#                                                        'indices': [0, 10],
#                                                        'name': 'Jime',
#                                                        'screen_name': 'jimenab67'},
#                                                       {'id': 116848943,
#                                                        'id_str': '116848943',
#                                                        'indices': [11, 27],
#                                                        'name': 'Perros '
#                                                                'Tuiteros🐾 y '
#                                                                'Furiosos '
#                                                                '\U0001f98a',
#                                                        'screen_name': 'PerrosPlazaHuem'},
#                                                       {'id': 394320248,
#                                                        'id_str': '394320248',
#                                                        'indices': [28, 40],
#                                                        'name': 'Sita Marce',
#                                                        'screen_name': 'Chilena9772'},
#                                                       {'id': 95942356,
#                                                        'id_str': '95942356',
#                                                        'indices': [41, 47],
#                                                        'name': 'vero',
#                                                        'screen_name': 'ver65'},
#                                                       {'id': 726195092,
#                                                        'id_str': '726195092',
#                                                        'indices': [48, 56],
#                                                        'name': 'silfon',
#                                                        'screen_name': 'silvfon'},
#                                                       {'id': 118784585,
#                                                        'id_str': '118784585',
#                                                        'indices': [57, 70],
#                                                        'name': 'Carabineros de '
#                                                                'Chile',
#                                                        'screen_name': 'Carabdechile'},
#                                                       {'id': 226192416,
#                                                        'id_str': '226192416',
#                                                        'indices': [71, 80],
#                                                        'name': 'UAA Chile',
#                                                        'screen_name': 'UaaChile'},
#                                                       {'id': 541906006,
#                                                        'id_str': '541906006',
#                                                        'indices': [81, 97],
#                                                        'name': 'romina saez',
#                                                        'screen_name': 'rominasaoficial'},
#                                                       {'id': 510561598,
#                                                        'id_str': '510561598',
#                                                        'indices': [98, 114],
#                                                        'name': 'MYRIAM HILL '
#                                                                'AVALOS',
#                                                        'screen_name': 'MYRIAMHILLAVALO'}]},
#                        'favorite_count': 2,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 985277545833750528,
#                        'id_str': '985277545833750528',
#                        'in_reply_to_screen_name': 'jimenab67',
#                        'in_reply_to_status_id': 985274204621824000,
#                        'in_reply_to_status_id_str': '985274204621824000',
#                        'in_reply_to_user_id': 4661601869,
#                        'in_reply_to_user_id_str': '4661601869',
#                        'is_quote_status': False,
#                        'lang': 'es',
#                        'metadata': {'iso_language_code': 'es',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'retweet_count': 1,
#                        'retweeted': False,
#                        'source': '<a href="http://twitter.com" '
#                                  'rel="nofollow">Twitter Web Client</a>',
#                        'text': '@jimenab67 @PerrosPlazaHuem @Chilena9772 '
#                                '@ver65 @silvfon @Carabdechile @UaaChile '
#                                '@rominasaoficial @MYRIAMHILLAVALO… '
#                                'https://t.co/kKU0DSoBRi',
#                        'truncated': True,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Wed Dec 09 00:49:43 +0000 2009',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': '#poderanimal ( Sin fines de '
#                                                'lucro ) aprende, adopta, '
#                                                'difunde e infórmate.',
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'poderanimal.com',
#                                                                'expanded_url': 'http://poderanimal.com',
#                                                                'indices': [0,
#                                                                            22],
#                                                                'url': 'http://t.co/w7Tr4ZoKfO'}]}},
#                                 'favourites_count': 213,
#                                 'follow_request_sent': False,
#                                 'followers_count': 16729,
#                                 'following': False,
#                                 'friends_count': 7628,
#                                 'geo_enabled': False,
#                                 'has_extended_profile': False,
#                                 'id': 95539786,
#                                 'id_str': '95539786',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': 'es',
#                                 'listed_count': 84,
#                                 'location': 'Chile 🇨🇱',
#                                 'name': '#poderanimal',
#                                 'notifications': False,
#                                 'profile_background_color': 'FFC600',
#                                 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/444895341913968640/qRRAcXEm.jpeg',
#                                 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/444895341913968640/qRRAcXEm.jpeg',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/95539786/1521344555',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/924860322996944898/JyBIC0FU_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/924860322996944898/JyBIC0FU_normal.jpg',
#                                 'profile_link_color': '1B95E0',
#                                 'profile_sidebar_border_color': '000000',
#                                 'profile_sidebar_fill_color': 'EEEEEE',
#                                 'profile_text_color': '666666',
#                                 'profile_use_background_image': False,
#                                 'protected': False,
#                                 'screen_name': 'poderanimal',
#                                 'statuses_count': 18127,
#                                 'time_zone': 'Santiago',
#                                 'translator_type': 'regular',
#                                 'url': 'http://t.co/w7Tr4ZoKfO',
#                                 'utc_offset': -10800,
#                                 'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" '
#             'rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @poderanimal: @jimenab67 @PerrosPlazaHuem @Chilena9772 @ver65 '
#           '@silvfon @Carabdechile @UaaChile @rominasaoficial @MYRIAMHILLAVALO '
#           '@FundAn…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Thu Aug 22 20:01:00 +0000 2013',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': '',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 94559,
#            'follow_request_sent': False,
#            'followers_count': 2231,
#            'following': False,
#            'friends_count': 2414,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 1691997499,
#            'id_str': '1691997499',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'es',
#            'listed_count': 67,
#            'location': '',
#            'name': 'Eugenia Gonzalez',
#            'notifications': False,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000057337799/95e18945651464cee5c072b13d295eba.jpeg',
#            'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000057337799/95e18945651464cee5c072b13d295eba.jpeg',
#            'profile_background_tile': True,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1691997499/1377202582',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000341048751/dfea063abd795657036036cec562cacc_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000341048751/dfea063abd795657036036cec562cacc_normal.jpeg',
#            'profile_link_color': '0084B4',
#            'profile_sidebar_border_color': 'FFFFFF',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'eugenialanonna',
#            'statuses_count': 136472,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:43:47 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'bit.ly/2IWMMPg',
#                          'expanded_url': 'https://bit.ly/2IWMMPg',
#                          'indices': [112, 135],
#                          'url': 'https://t.co/p7Yc8naanT'}],
#                'user_mentions': [{'id': 221897750,
#                                   'id_str': '221897750',
#                                   'indices': [3, 14],
#                                   'name': 'RioenLinea',
#                                   'screen_name': 'rioenlinea'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985302630477062144,
#   'id_str': '985302630477062144',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': True,
#   'retweet_count': 7,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Sat Apr 14 21:26:08 +0000 2018',
#                        'entities': {'hashtags': [],
#                                     'symbols': [],
#                                     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                                               'expanded_url': 'https://twitter.com/i/web/status/985267987392487430',
#                                               'indices': [97, 120],
#                                               'url': 'https://t.co/pwU1pXWPWR'}],
#                                     'user_mentions': []},
#                        'favorite_count': 4,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 985267987392487430,
#                        'id_str': '985267987392487430',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'es',
#                        'metadata': {'iso_language_code': 'es',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 7,
#                        'retweeted': False,
#                        'source': '<a href="http://twitter.com" '
#                                  'rel="nofollow">Twitter Web Client</a>',
#                        'text': 'Carabineros allanó local clandestino “La '
#                                'Ratonera” en Valdivia: Detuvieron a una mujer '
#                                'por robo… https://t.co/pwU1pXWPWR',
#                        'truncated': True,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Wed Dec 01 22:42:00 +0000 2010',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': 'Diario electrónico de la '
#                                                'Región de Los Ríos. Cuéntanos '
#                                                'qué está pasando donde tú '
#                                                'estas, mencionando @rioenlinea',
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'rioenlinea.cl',
#                                                                'expanded_url': 'http://www.rioenlinea.cl',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/PPoq3cdMfH'}]}},
#                                 'favourites_count': 2637,
#                                 'follow_request_sent': False,
#                                 'followers_count': 16735,
#                                 'following': False,
#                                 'friends_count': 1205,
#                                 'geo_enabled': True,
#                                 'has_extended_profile': False,
#                                 'id': 221897750,
#                                 'id_str': '221897750',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': 'es',
#                                 'listed_count': 84,
#                                 'location': 'Valdivia, Chile',
#                                 'name': 'RioenLinea',
#                                 'notifications': False,
#                                 'profile_background_color': 'F7F9FA',
#                                 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000073198073/9c577b79b70d3c18ba7179edf1779d76.jpeg',
#                                 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000073198073/9c577b79b70d3c18ba7179edf1779d76.jpeg',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/221897750/1510719508',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/948503796359057408/Lb_PL96g_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948503796359057408/Lb_PL96g_normal.jpg',
#                                 'profile_link_color': '1162A9',
#                                 'profile_sidebar_border_color': 'FFFFFF',
#                                 'profile_sidebar_fill_color': 'DDEEF6',
#                                 'profile_text_color': '333333',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'rioenlinea',
#                                 'statuses_count': 33322,
#                                 'time_zone': 'Santiago',
#                                 'translator_type': 'regular',
#                                 'url': 'https://t.co/PPoq3cdMfH',
#                                 'utc_offset': -10800,
#                                 'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" '
#             'rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @rioenlinea: Carabineros allanó local clandestino “La Ratonera” '
#           'en Valdivia: Detuvieron a una mujer por robo '
#           'https://t.co/p7Yc8naanT #Va…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Thu Jul 07 18:37:17 +0000 2011',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': '100% perruna,denuncio maltrato animal y me cargan '
#                           'los racistas, todos somos hijos de Dios solo cambia '
#                           'el color.',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 5925,
#            'follow_request_sent': False,
#            'followers_count': 133,
#            'following': False,
#            'friends_count': 570,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 331151239,
#            'id_str': '331151239',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'es',
#            'listed_count': 0,
#            'location': 'chile',
#            'name': '@bellita56',
#            'notifications': False,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/955908380450803713/Z8MJ0WOP_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/955908380450803713/Z8MJ0WOP_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'bellita56',
#            'statuses_count': 20824,
#            'time_zone': 'Greenland',
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': -7200,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:43:29 +0000 2018',
#   'entities': {'hashtags': [{'indices': [0, 17], 'text': 'QuieroMiSpalding'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985302554857951232,
#   'id_str': '985302554857951232',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" '
#             'rel="nofollow">Twitter for Android</a>',
#   'text': '#QuieroMiSpalding. Desde Valdivia apoyando a las Animas con Claudia '
#           'Susana y Pilar',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sun Apr 08 15:58:55 +0000 2018',
#            'default_profile': True,
#            'default_profile_image': True,
#            'description': '',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 2,
#            'follow_request_sent': False,
#            'followers_count': 0,
#            'following': False,
#            'friends_count': 31,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 983011315735318528,
#            'id_str': '983011315735318528',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 0,
#            'location': '',
#            'name': 'Waldo Poblete',
#            'notifications': False,
#            'profile_background_color': 'F5F8FA',
#            'profile_background_image_url': None,
#            'profile_background_image_url_https': None,
#            'profile_background_tile': False,
#            'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#            'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'poblete_waldo',
#            'statuses_count': 5,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:43:29 +0000 2018',
#   'entities': {'hashtags': [],
#                'media': [{'display_url': 'pic.twitter.com/lEkw6aqQYF',
#                           'expanded_url': 'https://twitter.com/fernandoubiergo/status/985284357958066176/photo/1',
#                           'id': 985284355676409856,
#                           'id_str': '985284355676409856',
#                           'indices': [99, 122],
#                           'media_url': 'http://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                           'media_url_https': 'https://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                           'sizes': {'large': {'h': 1315,
#                                               'resize': 'fit',
#                                               'w': 2048},
#                                     'medium': {'h': 771,
#                                                'resize': 'fit',
#                                                'w': 1200},
#                                     'small': {'h': 437,
#                                               'resize': 'fit',
#                                               'w': 680},
#                                     'thumb': {'h': 150,
#                                               'resize': 'crop',
#                                               'w': 150}},
#                           'source_status_id': 985284357958066176,
#                           'source_status_id_str': '985284357958066176',
#                           'source_user_id': 18551146,
#                           'source_user_id_str': '18551146',
#                           'type': 'photo',
#                           'url': 'https://t.co/lEkw6aqQYF'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 18551146,
#                                   'id_str': '18551146',
#                                   'indices': [3, 19],
#                                   'name': 'fernando ubiergo',
#                                   'screen_name': 'fernandoubiergo'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/lEkw6aqQYF',
#                                    'expanded_url': 'https://twitter.com/fernandoubiergo/status/985284357958066176/photo/1',
#                                    'id': 985284355676409856,
#                                    'id_str': '985284355676409856',
#                                    'indices': [99, 122],
#                                    'media_url': 'http://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                                    'media_url_https': 'https://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                                    'sizes': {'large': {'h': 1315,
#                                                        'resize': 'fit',
#                                                        'w': 2048},
#                                              'medium': {'h': 771,
#                                                         'resize': 'fit',
#                                                         'w': 1200},
#                                              'small': {'h': 437,
#                                                        'resize': 'fit',
#                                                        'w': 680},
#                                              'thumb': {'h': 150,
#                                                        'resize': 'crop',
#                                                        'w': 150}},
#                                    'source_status_id': 985284357958066176,
#                                    'source_status_id_str': '985284357958066176',
#                                    'source_user_id': 18551146,
#                                    'source_user_id_str': '18551146',
#                                    'type': 'photo',
#                                    'url': 'https://t.co/lEkw6aqQYF'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985302552701960192,
#   'id_str': '985302552701960192',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 10,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Sat Apr 14 22:31:11 +0000 2018',
#                        'entities': {'hashtags': [],
#                                     'media': [{'display_url': 'pic.twitter.com/lEkw6aqQYF',
#                                                'expanded_url': 'https://twitter.com/fernandoubiergo/status/985284357958066176/photo/1',
#                                                'id': 985284355676409856,
#                                                'id_str': '985284355676409856',
#                                                'indices': [78, 101],
#                                                'media_url': 'http://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                                                'media_url_https': 'https://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                                                'sizes': {'large': {'h': 1315,
#                                                                    'resize': 'fit',
#                                                                    'w': 2048},
#                                                          'medium': {'h': 771,
#                                                                     'resize': 'fit',
#                                                                     'w': 1200},
#                                                          'small': {'h': 437,
#                                                                    'resize': 'fit',
#                                                                    'w': 680},
#                                                          'thumb': {'h': 150,
#                                                                    'resize': 'crop',
#                                                                    'w': 150}},
#                                                'type': 'photo',
#                                                'url': 'https://t.co/lEkw6aqQYF'}],
#                                     'symbols': [],
#                                     'urls': [],
#                                     'user_mentions': []},
#                        'extended_entities': {'media': [{'display_url': 'pic.twitter.com/lEkw6aqQYF',
#                                                         'expanded_url': 'https://twitter.com/fernandoubiergo/status/985284357958066176/photo/1',
#                                                         'id': 985284355676409856,
#                                                         'id_str': '985284355676409856',
#                                                         'indices': [78, 101],
#                                                         'media_url': 'http://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                                                         'media_url_https': 'https://pbs.twimg.com/media/Daxu5rbXkAAQ04K.jpg',
#                                                         'sizes': {'large': {'h': 1315,
#                                                                             'resize': 'fit',
#                                                                             'w': 2048},
#                                                                   'medium': {'h': 771,
#                                                                              'resize': 'fit',
#                                                                              'w': 1200},
#                                                                   'small': {'h': 437,
#                                                                             'resize': 'fit',
#                                                                             'w': 680},
#                                                                   'thumb': {'h': 150,
#                                                                             'resize': 'crop',
#                                                                             'w': 150}},
#                                                         'type': 'photo',
#                                                         'url': 'https://t.co/lEkw6aqQYF'}]},
#                        'favorite_count': 43,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 985284357958066176,
#                        'id_str': '985284357958066176',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'es',
#                        'metadata': {'iso_language_code': 'es',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 10,
#                        'retweeted': False,
#                        'source': '<a href="http://twitter.com/download/iphone" '
#                                  'rel="nofollow">Twitter for iPhone</a>',
#                        'text': 'Se va el día en la bella Valdivia.  \n'
#                                'Esta noche nuestro concierto a las 22:30 '
#                                'https://t.co/lEkw6aqQYF',
#                        'truncated': False,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Fri Jan 02 12:38:43 +0000 2009',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': 'Cantautor',
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'ubiergo.cl',
#                                                                'expanded_url': 'http://www.ubiergo.cl',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/JNOz1T2bX9'}]}},
#                                 'favourites_count': 19086,
#                                 'follow_request_sent': False,
#                                 'followers_count': 21425,
#                                 'following': False,
#                                 'friends_count': 4830,
#                                 'geo_enabled': False,
#                                 'has_extended_profile': False,
#                                 'id': 18551146,
#                                 'id_str': '18551146',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': 'es',
#                                 'listed_count': 92,
#                                 'location': 'iTunes Amazon Spotify Youtube',
#                                 'name': 'fernando ubiergo',
#                                 'notifications': False,
#                                 'profile_background_color': 'D6C77C',
#                                 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/141870957/thumb02.jpg',
#                                 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/141870957/thumb02.jpg',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18551146/1517166187',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/957744755680694272/Uy9h4RMT_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/957744755680694272/Uy9h4RMT_normal.jpg',
#                                 'profile_link_color': '0084B4',
#                                 'profile_sidebar_border_color': 'BDDCAD',
#                                 'profile_sidebar_fill_color': 'DDFFCC',
#                                 'profile_text_color': '120112',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'fernandoubiergo',
#                                 'statuses_count': 2399,
#                                 'time_zone': 'Santiago',
#                                 'translator_type': 'none',
#                                 'url': 'https://t.co/JNOz1T2bX9',
#                                 'utc_offset': -10800,
#                                 'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Tue Jan 19 18:37:43 +0000 2010',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'Hija, esposa y madre. Feliz y agradecida de los '
#                           'dones que Dios me ha dado.....',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 1565,
#            'follow_request_sent': False,
#            'followers_count': 221,
#            'following': False,
#            'friends_count': 414,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 106488080,
#            'id_str': '106488080',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 2,
#            'location': '',
#            'name': 'Carla Montecinos',
#            'notifications': False,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/106488080/1486046146',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/982229092551438338/RCQh7cks_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/982229092551438338/RCQh7cks_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'catamosa',
#            'statuses_count': 5018,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:43:11 +0000 2018',
#   'entities': {'hashtags': [{'indices': [36, 53], 'text': 'QuieroMiSpalding'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985302476722196480,
#   'id_str': '985302476722196480',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Vamos Las Animas, vamos Valdivia!!! #QuieroMiSpalding',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Tue Aug 03 01:44:52 +0000 2010',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Periodista.',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 729,
#            'follow_request_sent': False,
#            'followers_count': 661,
#            'following': False,
#            'friends_count': 747,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 174077367,
#            'id_str': '174077367',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'es',
#            'listed_count': 8,
#            'location': 'Santiago, Chile',
#            'name': 'Alejandro Rosales',
#            'notifications': False,
#            'profile_background_color': '131516',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#            'profile_background_tile': True,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/174077367/1404229074',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/3723506463/5ae6725418481089a19633e64dd95584_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3723506463/5ae6725418481089a19633e64dd95584_normal.jpeg',
#            'profile_link_color': '009999',
# ...
#            'profile_link_color': '0084B4',
#            'profile_sidebar_border_color': 'FFFFFF',
#            'profile_sidebar_fill_color': 'DDFFCC',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'brunogarces',
#            'statuses_count': 2228,
#            'time_zone': 'Greenland',
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': -7200,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:36:50 +0000 2018',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'facebook.com/EstherCoroneld…',
#                          'expanded_url': 'https://www.facebook.com/EstherCoroneldeIberkleid/posts/10155250766942595',
#                          'indices': [84, 107],
#                          'url': 'https://t.co/ZtFhKhyE46'}],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985300880177156096,
#   'id_str': '985300880177156096',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" '
#             'rel="nofollow">Facebook</a>',
#   'text': 'Absolutamente así es! Muy bueno Carola Valdivia Gran abrazo de luz '
#           'amiga querida!!! https://t.co/ZtFhKhyE46',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sun Sep 13 21:28:45 +0000 2009',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'The Clarity Mentor-Leadership Consultant for '
#                           'Visionary Leaders, I Mentor U2 Find ur '
#                           'Purpose/Mission/Vision/Passion! EXECUTIVE COACHING '
#                           'available',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'about.me/EstherCoroneld…',
#                                           'expanded_url': 'http://about.me/EstherCoroneldeIberkleid',
#                                           'indices': [0, 22],
#                                           'url': 'http://t.co/MxiYFMtI2X'}]}},
#            'favourites_count': 812,
#            'follow_request_sent': False,
#            'followers_count': 1318,
#            'following': False,
#            'friends_count': 2161,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 73979321,
#            'id_str': '73979321',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 112,
#            'location': 'La Paz - Bolivia',
#            'name': 'Esther Coronel de Ib',
#            'notifications': False,
#            'profile_background_color': 'B2DFDA',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/73979321/1409183679',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/3178184273/cbabf564df6863af0bc74c2a00bd0f5c_normal.jpeg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3178184273/cbabf564df6863af0bc74c2a00bd0f5c_normal.jpeg',
#            'profile_link_color': '93A644',
#            'profile_sidebar_border_color': 'EEEEEE',
#            'profile_sidebar_fill_color': 'FFFFFF',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'Esthersuchi',
#            'statuses_count': 84733,
#            'time_zone': 'La Paz',
#            'translator_type': 'none',
#            'url': 'http://t.co/MxiYFMtI2X',
#            'utc_offset': -14400,
#            'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 14 23:36:27 +0000 2018',
#   'entities': {'hashtags': [{'indices': [22, 31], 'text': 'Valdivia'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 367923574,
#                                   'id_str': '367923574',
#                                   'indices': [3, 17],
#                                   'name': 'Carla Christie',
#                                   'screen_name': 'ChristieCarla'},
#                                  {'id': 827915644842733568,
#                                   'id_str': '827915644842733568',
#                                   'indices': [72, 87],
#                                   'name': 'Marcha por la Ciencia y el '
#                                           'Conocimiento Chile',
#                                   'screen_name': 'ScienceMarchCL'},
#                                  {'id': 197607452,
#                                   'id_str': '197607452',
#                                   'indices': [88, 104],
#                                   'name': '+ Ciencia Para Chile',
#                                   'screen_name': 'MasCienciaChile'},
#                                  {'id': 21862946,
#                                   'id_str': '21862946',
#                                   'indices': [105, 121],
#                                   'name': 'Universidad Austral',
#                                   'screen_name': 'UAustraldeChile'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 985300784098234368,
#   'id_str': '985300784098234368',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 28,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Sat Apr 14 15:29:57 +0000 2018',
#                        'entities': {'hashtags': [{'indices': [3, 12],
#                                                   'text': 'Valdivia'}],
#                                     'symbols': [],
#                                     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#                                               'expanded_url': 'https://twitter.com/i/web/status/985178353291448323',
#                                               'indices': [104, 127],
#                                               'url': 'https://t.co/4zuk0UHMJ5'}],
#                                     'user_mentions': [{'id': 827915644842733568,
#                                                        'id_str': '827915644842733568',
#                                                        'indices': [53, 68],
#                                                        'name': 'Marcha por la '
#                                                                'Ciencia y el '
#                                                                'Conocimiento '
#                                                                'Chile',
#                                                        'screen_name': 'ScienceMarchCL'},
#                                                       {'id': 197607452,
#                                                        'id_str': '197607452',
#                                                        'indices': [69, 85],
#                                                        'name': '+ Ciencia Para '
#                                                                'Chile',
#                                                        'screen_name': 'MasCienciaChile'},
#                                                       {'id': 21862946,
#                                                        'id_str': '21862946',
#                                                        'indices': [86, 102],
#                                                        'name': 'Universidad '
#                                                                'Austral',
#                                                        'screen_name': 'UAustraldeChile'}]},
#                        'favorite_count': 42,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 985178353291448323,
#                        'id_str': '985178353291448323',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'es',
#                        'metadata': {'iso_language_code': 'es',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 28,
#                        'retweeted': False,
#                        'source': '<a '
#                                  'href="http://twitter.com/download/android" '
#                                  'rel="nofollow">Twitter for Android</a>',
#                        'text': 'En #Valdivia marcha por la ciencia y el '
#                                'conocimiento @ScienceMarchCL @MasCienciaChile '
#                                '@UAustraldeChile… https://t.co/4zuk0UHMJ5',
#                        'truncated': True,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Sun Sep 04 19:54:32 +0000 2011',
#                                 'default_profile': False,
#                                 'default_profile_image': False,
#                                 'description': 'Educación, ciencia y '
#                                                'naturaleza ¿Conoces al delfín '
#                                                'chileno? - Facultad de '
#                                                'Ciencias UACh',
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'ciencias.uach.cl',
#                                                                'expanded_url': 'http://www.ciencias.uach.cl/',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/jpm4BEWH3M'}]}},
#                                 'favourites_count': 3149,
#                                 'follow_request_sent': False,
#                                 'followers_count': 2154,
#                                 'following': False,
#                                 'friends_count': 1944,
#                                 'geo_enabled': False,
#                                 'has_extended_profile': False,
#                                 'id': 367923574,
#                                 'id_str': '367923574',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': 'es',
#                                 'listed_count': 31,
#                                 'location': 'Valdivia - Chile',
#                                 'name': 'Carla Christie',
#                                 'notifications': False,
#                                 'profile_background_color': 'ACDED6',
#                                 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/777908019/72a861adb2584f024fe1d55ba49fc333.jpeg',
#                                 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/777908019/72a861adb2584f024fe1d55ba49fc333.jpeg',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/367923574/1467228878',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/733301077899116544/QTzHxwAr_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/733301077899116544/QTzHxwAr_normal.jpg',
#                                 'profile_link_color': '038543',
#                                 'profile_sidebar_border_color': 'FFFFFF',
#                                 'profile_sidebar_fill_color': 'F6F6F6',
#                                 'profile_text_color': '333333',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'ChristieCarla',
#                                 'statuses_count': 3427,
#                                 'time_zone': 'Santiago',
#                                 'translator_type': 'none',
#                                 'url': 'https://t.co/jpm4BEWH3M',
#                                 'utc_offset': -10800,
#                                 'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#           'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#           '#MarchaPorLaCienc…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Fri Jul 01 13:32:09 +0000 2011',
#            'default_profile': False,
#            'default_profile_image': False,
#            'description': 'Los Chilenos comprenden lo que es necesario para '
#                           'que las cosas que Chile necesita ocurran',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 9311,
#            'follow_request_sent': False,
#            'followers_count': 1588,
#            'following': False,
#            'friends_count': 4971,
#            'geo_enabled': True,
#            'has_extended_profile': False,
#            'id': 327379661,
#            'id_str': '327379661',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'es',
#            'listed_count': 4,
#            'location': 'Valdivia, Chile',
#            'name': 'Luis Alberto Bustos',
#            'notifications': False,
#            'profile_background_color': '000000',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/327379661/1516917959',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/877672846650114049/iaaKPMGp_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877672846650114049/iaaKPMGp_normal.jpg',
#            'profile_link_color': 'DD2E44',
#            'profile_sidebar_border_color': '000000',
#            'profile_sidebar_fill_color': '000000',
#            'profile_text_color': '000000',
#            'profile_use_background_image': False,
#            'protected': False,
#            'screen_name': 'LuisAlbertoBus2',
#            'statuses_count': 14514,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}}]

# %% [markdown]
# ## 3. Conectarse al SGBD Mongo

# %% [markdown]
# - Conectarse a Mongo desde Python utilizando la librería adecuada

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.INFO268

# %% [markdown]
# ## 4. Escribir datos de Twitter en una Base de Datos Mongo

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.INFO268
results = twitter.search(q="valdivia", count=100, result_type="recent")
for i in range(5):
    for tweet in results['statuses']:
        baked = {"fecha":tweet["created_at"], \
               "tweet": tweet['text'], \
               "username": tweet['user']['name'], \
               "location": tweet['user']['location']}
        db.tweets.insert_one(baked)
        pprint.pprint(baked)
    print("............................................................................................")
    results = twitter.search(q="valdivia", count=100, result_type="recent", max_id=tweet["id"]-1)
# Out:
# {'_id': ObjectId('5ad29659d8694d77f392b64d'),
#  'fecha': 'Sun Apr 15 00:00:48 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'Valdivia empató 2-2 contra Deportes Puerto Montt '
#           'https://t.co/jQlaRwx9BZ',
#  'username': 'soyvaldivia.cl'}
# {'_id': ObjectId('5ad29659d8694d77f392b64e'),
#  'fecha': 'Sun Apr 15 00:00:43 +0000 2018',
#  'location': 'Yungay 499, Valdivia',
#  'tweet': 'Valdivia empató 2-2 contra Deportes Puerto Montt '
#           'https://t.co/Ijw7N4aEhN',
#  'username': 'Diario Austral'}
# {'_id': ObjectId('5ad29659d8694d77f392b64f'),
#  'fecha': 'Sun Apr 15 00:00:10 +0000 2018',
#  'location': 'Plaza Huincul, Neuquén, Argen.',
#  'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#           'https://t.co/K85uxOHf0M',
#  'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'}
# {'_id': ObjectId('5ad29659d8694d77f392b650'),
#  'fecha': 'Sat Apr 14 23:59:34 +0000 2018',
#  'location': 'Plaza Huincul, Neuquén, Argen.',
#  'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#           'https://t.co/0xPd7pwBjZ',
#  'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'}
# {'_id': ObjectId('5ad29659d8694d77f392b651'),
#  'fecha': 'Sat Apr 14 23:59:30 +0000 2018',
#  'location': '',
#  'tweet': '@jmc_valdivia Sin vergüenzas inconsecuentes mentirosos corruptos '
#           'aprovechadores todos sinónimos de zurdos',
#  'username': 'sergio sepulveda'}
# {'_id': ObjectId('5ad29659d8694d77f392b652'),
#  'fecha': 'Sat Apr 14 23:59:03 +0000 2018',
#  'location': 'Plaza Huincul, Neuquén, Argen.',
#  'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#           'https://t.co/9DOyklHd62',
#  'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'}
# {'_id': ObjectId('5ad29659d8694d77f392b653'),
#  'fecha': 'Sat Apr 14 23:58:59 +0000 2018',
#  'location': 'Gravity Falls',
#  'tweet': 'Con esto de viajar tanto ahora, he conocido ene de terminales.. por '
#           'el momento me quedo con el de #Valdivia',
#  'username': 'Mabel'}
# {'_id': ObjectId('5ad29659d8694d77f392b654'),
#  'fecha': 'Sat Apr 14 23:58:20 +0000 2018',
#  'location': 'Plaza Huincul, Neuquén, Argen.',
#  'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#           'https://t.co/xuXWI4RYGV',
#  'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'}
# {'_id': ObjectId('5ad29659d8694d77f392b655'),
#  'fecha': 'Sat Apr 14 23:58:10 +0000 2018',
#  'location': 'Valdivia - Chile',
#  'tweet': 'RT @alejoduranr: No hay caso. En @CineplanetChile de Valdivia le '
#           'suben el volumen a la publicidad, pero le bajan a la película. Es '
#           'algo que…',
#  'username': 'Jaime Cardenas'}
# {'_id': ObjectId('5ad29659d8694d77f392b656'),
#  'fecha': 'Sat Apr 14 23:57:42 +0000 2018',
#  'location': 'Plaza Huincul, Neuquén, Argen.',
#  'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#           'https://t.co/G4TbYoBLrq',
#  'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'}
# {'_id': ObjectId('5ad29659d8694d77f392b657'),
#  'fecha': 'Sat Apr 14 23:57:27 +0000 2018',
#  'location': 'Valdivia, Chile.',
#  'tweet': 'Termino un nuevo clásico del sur, igualaron 2-2 Valdivia y Puerto '
#           'Montt. La próxima semana se visita a San Felipe. 💪⚪️🔴',
#  'username': 'Deportes Valdivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b658'),
#  'fecha': 'Sat Apr 14 23:57:10 +0000 2018',
#  'location': 'Plaza Huincul, Neuquén, Argen.',
#  'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#           'https://t.co/zKsrSeNQG7',
#  'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'}
# {'_id': ObjectId('5ad29659d8694d77f392b659'),
#  'fecha': 'Sat Apr 14 23:54:48 +0000 2018',
#  'location': 'La Paz - Bolivia',
#  'tweet': 'Muy bueno Carola Valdivia Hablamos pronto amiga!!! No después! '
#           'https://t.co/2r9lCwRl35',
#  'username': 'Esther Coronel de Ib'}
# {'_id': ObjectId('5ad29659d8694d77f392b65a'),
#  'fecha': 'Sat Apr 14 23:54:26 +0000 2018',
#  'location': 'Osorno de - Chile',
#  'tweet': 'RT @soyvaldiviacl: Valdivia empató 2-2 contra Deportes Puerto '
#           'Montt. https://t.co/AzyPkeEdZj https://t.co/6kRK1NWDAY',
#  'username': 'Comunicar y Servir'}
# {'_id': ObjectId('5ad29659d8694d77f392b65b'),
#  'fecha': 'Sat Apr 14 23:54:13 +0000 2018',
#  'location': 'Santiago, Chile',
#  'tweet': 'RT @ScienceMarchCL: Grande Valdivia!! 👍🏼 https://t.co/eEj8h8z8VB',
#  'username': 'Fco Covarrubias Izq.'}
# {'_id': ObjectId('5ad29659d8694d77f392b65c'),
#  'fecha': 'Sat Apr 14 23:53:09 +0000 2018',
#  'location': '',
#  'tweet': 'RT @MlkdaColina: Hipocrisia que fala, né? https://t.co/jdMcrxNKoB',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad29659d8694d77f392b65d'),
#  'fecha': 'Sat Apr 14 23:53:02 +0000 2018',
#  'location': 'caracas venezuela',
#  'tweet': 'Exelente a pesar de la tristeza en Valdivia, Chile '
#           'https://t.co/JL0VdS3VbD',
#  'username': 'Jesus Rincones A'}
# {'_id': ObjectId('5ad29659d8694d77f392b65e'),
#  'fecha': 'Sat Apr 14 23:52:00 +0000 2018',
#  'location': 'V REGION',
#  'tweet': '@carlosramone6 @SarcasmoChile7 @_The_Shining__ @Kaizer_cl '
#           '@dogfighters74 @jlabranaaburto @Jurel_Cesar @patodelsur53… '
#           'https://t.co/Gw1JGKDIBh',
#  'username': 'CALDERON'}
# {'_id': ObjectId('5ad29659d8694d77f392b65f'),
#  'fecha': 'Sat Apr 14 23:51:55 +0000 2018',
#  'location': '',
#  'tweet': 'RT @legispe: Tutela de derechos y derecho a la prueba del '
#           'sospechoso (Casación 14-2010, La Libertad), por Jaime Coaguila '
#           'Valdivia https://t…',
#  'username': 'FELIPE ANTONIO ROJAS'}
# {'_id': ObjectId('5ad29659d8694d77f392b660'),
#  'fecha': 'Sat Apr 14 23:51:27 +0000 2018',
#  'location': 'PUERTO MONTT, Chile',
#  'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#           'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#           '@canal13. Irem…',
#  'username': 'Hardy'}
# {'_id': ObjectId('5ad29659d8694d77f392b661'),
#  'fecha': 'Sat Apr 14 23:51:26 +0000 2018',
#  'location': 'Lima ',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Nancy Herrera'}
# {'_id': ObjectId('5ad29659d8694d77f392b662'),
#  'fecha': 'Sat Apr 14 23:50:51 +0000 2018',
#  'location': '',
#  'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#           'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#           '@canal13. Irem…',
#  'username': 'Jaime Coloma T.'}
# {'_id': ObjectId('5ad29659d8694d77f392b663'),
#  'fecha': 'Sat Apr 14 23:50:18 +0000 2018',
#  'location': '',
#  'tweet': '@canal_CDO que gane valdivia, y la copa se quede en el sur después '
#           'de ganarle a castro, saludos desde Castro, chilo… '
#           'https://t.co/6Gyjo8JZic',
#  'username': 'ignacio saldivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b664'),
#  'fecha': 'Sat Apr 14 23:50:18 +0000 2018',
#  'location': '',
#  'tweet': '@canal_CDO que ganen las ánimas de valdivia, y la copa se quede en '
#           'el sur después de ganarle a castro, saludos desd… '
#           'https://t.co/IfZ5QnBrUx',
#  'username': 'ignacio saldivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b665'),
#  'fecha': 'Sat Apr 14 23:49:53 +0000 2018',
#  'location': 'Valdivia - Chile',
#  'tweet': '#QuieroMiSPALDING Vamos Fantasmas!! Desde Valdivia apoyando a las '
#           'Ánimas!! 🏆🏀👻👻👻 Mirándolos por #Cdo',
#  'username': 'ClaU Contreras'}
# {'_id': ObjectId('5ad29659d8694d77f392b666'),
#  'fecha': 'Sat Apr 14 23:49:30 +0000 2018',
#  'location': 'Santiago de Chile',
#  'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#           'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#           '@canal13. Irem…',
#  'username': 'Andrea Obaid'}
# {'_id': ObjectId('5ad29659d8694d77f392b667'),
#  'fecha': 'Sat Apr 14 23:48:24 +0000 2018',
#  'location': 'Valdivia',
#  'tweet': '👌🏽 en Valdivia, Chile https://t.co/FtuOFw2R6X',
#  'username': 'Carlos Oporto'}
# {'_id': ObjectId('5ad29659d8694d77f392b668'),
#  'fecha': 'Sat Apr 14 23:48:24 +0000 2018',
#  'location': '',
#  'tweet': 'RT @pierovg2015: hasta cuando Sr @Lenin las unidades medicas '
#           '@IESSGuayas @IESSec van a ser centros de peregrinacion del afiliado '
#           'hoy lleva…',
#  'username': 'Antonio Yepez'}
# {'_id': ObjectId('5ad29659d8694d77f392b669'),
#  'fecha': 'Sat Apr 14 23:48:18 +0000 2018',
#  'location': 'Valdivia',
#  'tweet': 'RT @quieromibarrio: Fiscalizaron obras de #QuieroMiBarrio del '
#           '@Minvu en el sector #TenienteMerino de #Valdivia '
#           'https://t.co/L5aIdncLEL @Min…',
#  'username': 'MINVU LOS RIOS'}
# {'_id': ObjectId('5ad29659d8694d77f392b66a'),
#  'fecha': 'Sat Apr 14 23:46:24 +0000 2018',
#  'location': '',
#  'tweet': 'RT @StephenAmell: Heading to Coachella. When Beyonce gets on stage '
#           'I’ll be watching*.\n'
#           '\n'
#           '* - The #AndreTheGiant documentary at home because I…',
#  'username': 'KATHY VALDIVIA ❤️'}
# {'_id': ObjectId('5ad29659d8694d77f392b66b'),
#  'fecha': 'Sat Apr 14 23:46:00 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': '#QuieromiSpalding Hola canal cdo quiero mi balón spalding desde '
#           'valdivia apoyando el basketball chileno https://t.co/SFcdD5Dmhy',
#  'username': 'Nestor'}
# {'_id': ObjectId('5ad29659d8694d77f392b66c'),
#  'fecha': 'Sat Apr 14 23:45:53 +0000 2018',
#  'location': '',
#  'tweet': '#QuieroMiSpalding  mi pelota quedo quedó en el departamento de mi '
#           'polola y no me la va ha devolver mas :( Gonzalo Tiznado de '
#           'Valdivia.',
#  'username': 'gonzalo tiznado'}
# {'_id': ObjectId('5ad29659d8694d77f392b66d'),
#  'fecha': 'Sat Apr 14 23:45:43 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Grande Valdivia!! 👍🏼 https://t.co/eEj8h8z8VB',
#  'username': 'Marcha por la Ciencia y el Conocimiento Chile'}
# {'_id': ObjectId('5ad29659d8694d77f392b66e'),
#  'fecha': 'Sat Apr 14 23:45:26 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'Un chilote revoloteando por Valdivia necesita y ansía poder ganar '
#           'el balón para ir a lanzar un par de tiros a algun… '
#           'https://t.co/V66zgM0xjh',
#  'username': 'Andrés Reyes Barria'}
# {'_id': ObjectId('5ad29659d8694d77f392b66f'),
#  'fecha': 'Sat Apr 14 23:44:35 +0000 2018',
#  'location': 'Lima ',
#  'tweet': 'RT @fernandoubiergo: Hoy por la noche Temuco, mañana en Valdivia y '
#           'el domingo en Concepción \n'
#           '\n'
#           'Vivo en la carretera 🎶 https://t.co/fbfVhfXZf4',
#  'username': 'Nancy Herrera'}
# {'_id': ObjectId('5ad29659d8694d77f392b670'),
#  'fecha': 'Sat Apr 14 23:43:56 +0000 2018',
#  'location': '',
#  'tweet': '#QuieroMiSpalding saludos desde las Animas, Valdivia. Apoyando a '
#           'los fantasmas. Cariños',
#  'username': 'Ivonne Fernandez'}
# {'_id': ObjectId('5ad29659d8694d77f392b671'),
#  'fecha': 'Sat Apr 14 23:43:51 +0000 2018',
#  'location': '',
#  'tweet': 'RT @poderanimal: @jimenab67 @PerrosPlazaHuem @Chilena9772 @ver65 '
#           '@silvfon @Carabdechile @UaaChile @rominasaoficial @MYRIAMHILLAVALO '
#           '@FundAn…',
#  'username': 'Eugenia Gonzalez'}
# {'_id': ObjectId('5ad29659d8694d77f392b672'),
#  'fecha': 'Sat Apr 14 23:43:47 +0000 2018',
#  'location': 'chile',
#  'tweet': 'RT @rioenlinea: Carabineros allanó local clandestino “La Ratonera” '
#           'en Valdivia: Detuvieron a una mujer por robo '
#           'https://t.co/p7Yc8naanT #Va…',
#  'username': '@bellita56'}
# {'_id': ObjectId('5ad29659d8694d77f392b673'),
#  'fecha': 'Sat Apr 14 23:43:29 +0000 2018',
#  'location': '',
#  'tweet': '#QuieroMiSpalding. Desde Valdivia apoyando a las Animas con Claudia '
#           'Susana y Pilar',
#  'username': 'Waldo Poblete'}
# {'_id': ObjectId('5ad29659d8694d77f392b674'),
#  'fecha': 'Sat Apr 14 23:43:29 +0000 2018',
#  'location': '',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Carla Montecinos'}
# {'_id': ObjectId('5ad29659d8694d77f392b675'),
#  'fecha': 'Sat Apr 14 23:43:11 +0000 2018',
#  'location': 'Santiago, Chile',
#  'tweet': 'Vamos Las Animas, vamos Valdivia!!! #QuieroMiSpalding',
#  'username': 'Alejandro Rosales'}
# {'_id': ObjectId('5ad29659d8694d77f392b676'),
#  'fecha': 'Sat Apr 14 23:42:25 +0000 2018',
#  'location': '',
#  'tweet': 'RT @ciclorecreovia: ¡LOS SÁBADOS TAMBIÉN!\n'
#           '\n'
#           'También los sábados puedes disfrutar CicloRecreoVía.\n'
#           '\n'
#           'CicloRecreoVía funciona cada sábado en el…',
#  'username': 'Ximena Ravanal'}
# {'_id': ObjectId('5ad29659d8694d77f392b677'),
#  'fecha': 'Sat Apr 14 23:42:08 +0000 2018',
#  'location': 'Metropolitana de Santiago',
#  'tweet': 'RT @IntendenciaRM: Sigue estas recomendaciones si vas al partido '
#           'entre @ColoColo y @udechile este domingo en el Estadio Nacional:\n'
#           '⚽️ Puerta…',
#  'username': 'Rosa Oyarce'}
# {'_id': ObjectId('5ad29659d8694d77f392b678'),
#  'fecha': 'Sat Apr 14 23:39:54 +0000 2018',
#  'location': '',
#  'tweet': '@canal_CDO #QuieroMiSpalding desde VALDIVIA disfrutando el '
#           'basquetbol por CDO!!',
#  'username': 'diegoyarzun13'}
# {'_id': ObjectId('5ad29659d8694d77f392b679'),
#  'fecha': 'Sat Apr 14 23:38:54 +0000 2018',
#  'location': 'En Mi Casa',
#  'tweet': '#QuieroMiSpalding #LigaDIRECTV Vamos fantasmas!! Apoyando desde '
#           'Valdivia💪👻',
#  'username': 'Almendra'}
# {'_id': ObjectId('5ad29659d8694d77f392b67a'),
#  'fecha': 'Sat Apr 14 23:38:29 +0000 2018',
#  'location': 'Alagoinhas-BA',
#  'tweet': 'RT @brunogarces: @R0n4ldFla @ColoColo @udechile Barroso twitou '
#           'quando tiraram ele de um jogo, e mandou nas indiretas que o mundo '
#           'da voltas,…',
#  'username': 'SDDS RUEDA'}
# {'_id': ObjectId('5ad29659d8694d77f392b67b'),
#  'fecha': 'Sat Apr 14 23:37:35 +0000 2018',
#  'location': '',
#  'tweet': 'RT @Wbrokering: @DeUrrestiSenado Gracias, Senador, por su visita a '
#           'la recientemente electa directiva de la Junta de Vecinos de '
#           'Torobayo! Mu…',
#  'username': 'Mario Ayala'}
# {'_id': ObjectId('5ad29659d8694d77f392b67c'),
#  'fecha': 'Sat Apr 14 23:37:26 +0000 2018',
#  'location': 'Belo Horizonte',
#  'tweet': '@R0n4ldFla @ColoColo @udechile Barroso twitou quando tiraram ele de '
#           'um jogo, e mandou nas indiretas que o mundo da… '
#           'https://t.co/AEQDHuA09D',
#  'username': 'Bruno Garces'}
# {'_id': ObjectId('5ad29659d8694d77f392b67d'),
#  'fecha': 'Sat Apr 14 23:36:50 +0000 2018',
#  'location': 'La Paz - Bolivia',
#  'tweet': 'Absolutamente así es! Muy bueno Carola Valdivia Gran abrazo de luz '
#           'amiga querida!!! https://t.co/ZtFhKhyE46',
#  'username': 'Esther Coronel de Ib'}
# {'_id': ObjectId('5ad29659d8694d77f392b67e'),
#  'fecha': 'Sat Apr 14 23:36:27 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#           'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#           '#MarchaPorLaCienc…',
#  'username': 'Luis Alberto Bustos'}
# {'_id': ObjectId('5ad29659d8694d77f392b67f'),
#  'fecha': 'Sat Apr 14 23:36:15 +0000 2018',
#  'location': '',
#  'tweet': '@PatoPapao @caju_sz XD\n\nEAE PATO, TUDO BOM?',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad29659d8694d77f392b680'),
#  'fecha': 'Sat Apr 14 23:35:24 +0000 2018',
#  'location': '',
#  'tweet': '@caju_sz alo @EA segue a call',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad29659d8694d77f392b681'),
#  'fecha': 'Sat Apr 14 23:34:27 +0000 2018',
#  'location': '',
#  'tweet': 'RT @Temucodiario: #Temuco: Ministro Monckeberg firma mensajes para '
#           'obras de doble vía Fundo El Carmen y Av. Pedro de Valdivia  '
#           'https://t.co…',
#  'username': 'Carlos v F'}
# {'_id': ObjectId('5ad29659d8694d77f392b682'),
#  'fecha': 'Sat Apr 14 23:33:22 +0000 2018',
#  'location': 'Santiago, Metropolitana de San',
#  'tweet': 'RT @PedroMarinR: El entrenador de @ColoColo Pablo Guede confirma el '
#           '11 para enfrentar a la U. Orión; Campos, Zaldivia, Insaurralde, '
#           'Opazo;…',
#  'username': 'Hector Arenas'}
# {'_id': ObjectId('5ad29659d8694d77f392b683'),
#  'fecha': 'Sat Apr 14 23:33:08 +0000 2018',
#  'location': 'Temuco, Chile',
#  'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt '
#           '#Valdivia empatan 2-2 goles para los salmoneros Joaquín Diaz y '
#           'Jaime Gr…',
#  'username': '#PASIONALBIVERDE 🇨🇱🇳🇬'}
# {'_id': ObjectId('5ad29659d8694d77f392b684'),
#  'fecha': 'Sat Apr 14 23:31:49 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'Valdivia empató 2-2 contra Deportes Puerto Montt. '
#           'https://t.co/AzyPkeEdZj https://t.co/6kRK1NWDAY',
#  'username': 'soyvaldivia.cl'}
# {'_id': ObjectId('5ad29659d8694d77f392b685'),
#  'fecha': 'Sat Apr 14 23:31:47 +0000 2018',
#  'location': '',
#  'tweet': 'RT @rioenlinea: Carabineros allanó local clandestino “La Ratonera” '
#           'en Valdivia: Detuvieron a una mujer por robo '
#           'https://t.co/p7Yc8naanT #Va…',
#  'username': 'LuisAguilera'}
# {'_id': ObjectId('5ad29659d8694d77f392b686'),
#  'fecha': 'Sat Apr 14 23:31:38 +0000 2018',
#  'location': 'Salta- Argentina',
#  'tweet': 'RT @gastonggalindez: #AHORA con @marcos_galian @AmbienteMuni en '
#           'Ciudad Valdivia conversamos con Patricia y Ramón sobre mejoras '
#           'ambientales…',
#  'username': 'Marcela Jesús'}
# {'_id': ObjectId('5ad29659d8694d77f392b687'),
#  'fecha': 'Sat Apr 14 23:31:32 +0000 2018',
#  'location': 'Santiago Chile',
#  'tweet': 'RT @karina_bravof: La @RedInvestChile en la marcha por la ciencia y '
#           'el conocimiento también estuvo presente en regiones.\n'
#           'Valdivia\n'
#           'Valaparaí…',
#  'username': 'Esteban Silva Cuadra'}
# {'_id': ObjectId('5ad29659d8694d77f392b688'),
#  'fecha': 'Sat Apr 14 23:31:17 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'RT @IchiBlake: Vamos Valdivia...todas y todos apoyando a '
#           '@cd_lasanimas #valdiviacl \n'
#           '¡ es nuestro Básquetbol !!',
#  'username': 'Cecilia Aguero R'}
# {'_id': ObjectId('5ad29659d8694d77f392b689'),
#  'fecha': 'Sat Apr 14 23:30:48 +0000 2018',
#  'location': 'Brasília, Distrito Federal',
#  'tweet': 'valdivia do #SPFC fazendo live de PUBG &lt;3 que homem '
#           'https://t.co/8jgz7l6DgK',
#  'username': 'Rafael Vale'}
# {'_id': ObjectId('5ad29659d8694d77f392b68a'),
#  'fecha': 'Sat Apr 14 23:30:44 +0000 2018',
#  'location': 'salta argentina',
#  'tweet': 'RT @gastonggalindez: #AHORA con @marcos_galian @AmbienteMuni en '
#           'Ciudad Valdivia conversamos con Patricia y Ramón sobre mejoras '
#           'ambientales…',
#  'username': 'NiKolas'}
# {'_id': ObjectId('5ad29659d8694d77f392b68b'),
#  'fecha': 'Sat Apr 14 23:30:44 +0000 2018',
#  'location': '',
#  'tweet': '@R_Gacitua Sabes que no he podido encontrar en Valdivia 😣 con queso '
#           'crema no queda nada mal',
#  'username': 'Maca Rodriguez'}
# {'_id': ObjectId('5ad29659d8694d77f392b68c'),
#  'fecha': 'Sat Apr 14 23:30:18 +0000 2018',
#  'location': 'Salta',
#  'tweet': '#AHORA con @marcos_galian @AmbienteMuni en Ciudad Valdivia '
#           'conversamos con Patricia y Ramón sobre mejoras ambiental… '
#           'https://t.co/hhC3GilyBy',
#  'username': 'Gaston Galindez'}
# {'_id': ObjectId('5ad29659d8694d77f392b68d'),
#  'fecha': 'Sat Apr 14 23:29:24 +0000 2018',
#  'location': '',
#  'tweet': '#QuieroMiSpalding Grande @canal_CDO Apoyo a las ánimas.Valdivia '
#           'siempre',
#  'username': 'VICTOR NAVARRETE'}
# {'_id': ObjectId('5ad29659d8694d77f392b68e'),
#  'fecha': 'Sat Apr 14 23:29:24 +0000 2018',
#  'location': 'Temuco, Chile',
#  'tweet': 'RT @municipiotemuco: Muy temprano nuestras vecinas del sector Pedro '
#           'de Valdivia, se reunieron con el alcalde Miguel Becker y su equipo, '
#           'en…',
#  'username': 'Miguel Gamonal'}
# {'_id': ObjectId('5ad29659d8694d77f392b68f'),
#  'fecha': 'Sat Apr 14 23:29:17 +0000 2018',
#  'location': 'Temuco, Chile',
#  'tweet': 'RT @municipiotemuco: Gracias a todas las vecinas del macrosector '
#           'Pedro de Valdivia por su visita y por compartir sus inquietudes. '
#           '#ContigoM…',
#  'username': 'Miguel Gamonal'}
# {'_id': ObjectId('5ad29659d8694d77f392b690'),
#  'fecha': 'Sat Apr 14 23:29:11 +0000 2018',
#  'location': 'Temuco, Chile',
#  'tweet': 'RT @municipiotemuco: Ministro de Vivienda y Urbanismo Cristián '
#           'Monckeberg, en compañía del alcalde Miguel Becker y autoridades '
#           'regionales,…',
#  'username': 'Miguel Gamonal'}
# {'_id': ObjectId('5ad29659d8694d77f392b691'),
#  'fecha': 'Sat Apr 14 23:29:06 +0000 2018',
#  'location': '',
#  'tweet': 'https://t.co/4l7Q3k4YEo',
#  'username': 'Nina Valdivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b692'),
#  'fecha': 'Sat Apr 14 23:28:46 +0000 2018',
#  'location': '',
#  'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt '
#           '#Valdivia empatan 2-2 goles para los salmoneros Joaquín Diaz y '
#           'Jaime Gr…',
#  'username': 'Rumbo a Primera #RP'}
# {'_id': ObjectId('5ad29659d8694d77f392b693'),
#  'fecha': 'Sat Apr 14 23:26:50 +0000 2018',
#  'location': 'Valdivia',
#  'tweet': 'RT @alb0black: Niño comiendo erizos en Mercado Fluvial de Valdivia, '
#           'febrero 1960.\n'
#           '#Chile https://t.co/LxwuNHz8as',
#  'username': 'Danilo Ormeño'}
# {'_id': ObjectId('5ad29659d8694d77f392b694'),
#  'fecha': 'Sat Apr 14 23:25:09 +0000 2018',
#  'location': '',
#  'tweet': 'https://t.co/mo1DDHvHfP',
#  'username': 'Nancy Valdivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b695'),
#  'fecha': 'Sat Apr 14 23:24:46 +0000 2018',
#  'location': ' coquimbo-chile',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Ana Bermont'}
# {'_id': ObjectId('5ad29659d8694d77f392b696'),
#  'fecha': 'Sat Apr 14 23:24:09 +0000 2018',
#  'location': '',
#  'tweet': 'Pull up to my bumper baby! This afternoon in #Sarasota #Florida at '
#           'a @MySFF screening of #BloodlightAndBami, a… '
#           'https://t.co/9QuVIiMzdW',
#  'username': 'YuRay Valdivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b697'),
#  'fecha': 'Sat Apr 14 23:23:59 +0000 2018',
#  'location': 'Talca',
#  'tweet': '@EricksenSalinas Hubo una o 2 llegadas con aaalgo de peligro. Pero '
#           'recién en el último cuarto de cancha nos apretab… '
#           'https://t.co/L1NCoWQptr',
#  'username': 'Paulo'}
# {'_id': ObjectId('5ad29659d8694d77f392b698'),
#  'fecha': 'Sat Apr 14 23:23:15 +0000 2018',
#  'location': 'Santiago de Chile',
#  'tweet': 'RT @ceciliamorel: Qué emoción poder ser parte del primer encuentro '
#           'de la Orquesta Juvenil Regional de Valdivia @FOJIChile. La música '
#           'nos in…',
#  'username': 'Sole Cáceres'}
# {'_id': ObjectId('5ad29659d8694d77f392b699'),
#  'fecha': 'Sat Apr 14 23:23:11 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: En reunión con Alcalde @omar_sabat conversando '
#           'sobre los desafíos de Valdivia. Una ciudad muy linda y según el '
#           'Alcalde…',
#  'username': 'Micky'}
# {'_id': ObjectId('5ad29659d8694d77f392b69a'),
#  'fecha': 'Sat Apr 14 23:22:44 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: Seguimos recorriendo Valdivia! '
#           'https://t.co/O2w2OkvKVX',
#  'username': 'Micky'}
# {'_id': ObjectId('5ad29659d8694d77f392b69b'),
#  'fecha': 'Sat Apr 14 23:22:40 +0000 2018',
#  'location': 'Santiago de Chile',
#  'tweet': 'Naty (M. Pedro de Valdivia): 30.000 la media hora con americana !!! '
#           'Llámame estoy disponible :)… https://t.co/PKuHlezmMT',
#  'username': 'PlanetaEscort.cl'}
# {'_id': ObjectId('5ad29659d8694d77f392b69c'),
#  'fecha': 'Sat Apr 14 23:22:36 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: Terminando encuentro con pastores en Valdivia. '
#           'Siempre es reconfortante conocer la opinión y recibir el apoyo de '
#           'la co…',
#  'username': 'Micky'}
# {'_id': ObjectId('5ad29659d8694d77f392b69d'),
#  'fecha': 'Sat Apr 14 23:22:04 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': '🇨🇱 #ValdiviaCL domingo 15: Mín 11º/Máx 15ºC  En la madrugada: '
#           'Nubosidad parcial, ocasionalmente nublado y niebla '
#           'https://t.co/xTAH155ZGc',
#  'username': 'El Tiempo Valdivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b69e'),
#  'fecha': 'Sat Apr 14 23:22:03 +0000 2018',
#  'location': '',
#  'tweet': 'RT @MERIC_Chile: El Centro de Investigación e Innovación en Energía '
#           'Marina @MERIC_Chile inició los preparativos de la 3ª versión del '
#           'Intern…',
#  'username': 'Francisca Terminel'}
# {'_id': ObjectId('5ad29659d8694d77f392b69f'),
#  'fecha': 'Sat Apr 14 23:20:46 +0000 2018',
#  'location': 'Perú',
#  'tweet': 'RT @legispe: Tutela de derechos y derecho a la prueba del '
#           'sospechoso (Casación 14-2010, La Libertad), por Jaime Coaguila '
#           'Valdivia https://t…',
#  'username': 'Marfe'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a0'),
#  'fecha': 'Sat Apr 14 23:20:30 +0000 2018',
#  'location': 'La Serena',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Daniel San'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a1'),
#  'fecha': 'Sat Apr 14 23:19:20 +0000 2018',
#  'location': 'Venezuela♥/Por ahora en Chile ',
#  'tweet': 'Por el 3ero de la serie Final #LigaDIRECTV Leones de Quilpué Vs. '
#           'Las Ánimas de Valdivia 🏀 en… https://t.co/BOWq9mKvp3',
#  'username': 'Yajaira Basaure'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a2'),
#  'fecha': 'Sat Apr 14 23:19:00 +0000 2018',
#  'location': '',
#  'tweet': '#temuco Dictan acusación contra un General y un Capitán de '
#           'Carabineros (r) por hechos ocurridos en 1973\n'
#           'Abril 6, 20… https://t.co/MnkmBE4BJO',
#  'username': 'El Indio Pérez'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a3'),
#  'fecha': 'Sat Apr 14 23:15:58 +0000 2018',
#  'location': 'Cuiabá-MT',
#  'tweet': '@fcimsep @Copeiro13 @andrizek Surpresa nenhuma vindo desse '
#           'cara!!!Lembra desse safado entregando o Valdívia para o… '
#           'https://t.co/UDcd7zDlVT',
#  'username': 'Dagotiam ENEAcampeão'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a4'),
#  'fecha': 'Sat Apr 14 23:15:12 +0000 2018',
#  'location': 'La Serena, Coquimbo',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Jorge Ortega 🇨🇱'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a5'),
#  'fecha': 'Sat Apr 14 23:14:54 +0000 2018',
#  'location': '',
#  'tweet': '@janatran69 @matizaldivia @JulioBarroso5 No lo hacen porque '
#           'Valdivia y Paredes les ordenan eso. No tienen voz propi… '
#           'https://t.co/FRkKUDkfuT',
#  'username': 'mauricio saldivia'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a6'),
#  'fecha': 'Sat Apr 14 23:14:33 +0000 2018',
#  'location': '',
#  'tweet': 'RT @gidion1208: Los gráficos de la nueva generación son una pasada! '
#           'w/  javigoms  Minimoltech  Manu Valdivia #HAGAMOSVINE #... '
#           'https://t.co…',
#  'username': 'Gidion'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a7'),
#  'fecha': 'Sat Apr 14 23:12:35 +0000 2018',
#  'location': 'Valdivia',
#  'tweet': 'RT @IchiBlake: Vamos Valdivia...todas y todos apoyando a '
#           '@cd_lasanimas #valdiviacl \n'
#           '¡ es nuestro Básquetbol !!',
#  'username': 'Carlos López'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a8'),
#  'fecha': 'Sat Apr 14 23:12:24 +0000 2018',
#  'location': 'Chile, sur',
#  'tweet': 'RT @alb0black: Niño comiendo erizos en Mercado Fluvial de Valdivia, '
#           'febrero 1960.\n'
#           '#Chile https://t.co/LxwuNHz8as',
#  'username': 'Robert Aguayo Rubio'}
# {'_id': ObjectId('5ad29659d8694d77f392b6a9'),
#  'fecha': 'Sat Apr 14 23:11:52 +0000 2018',
#  'location': 'Valdivia - Chile',
#  'tweet': 'Vamos Valdivia...todas y todos apoyando a @cd_lasanimas '
#           '#valdiviacl \n'
#           '¡ es nuestro Básquetbol !!',
#  'username': 'Alicia Blake'}
# {'_id': ObjectId('5ad29659d8694d77f392b6aa'),
#  'fecha': 'Sat Apr 14 23:11:40 +0000 2018',
#  'location': 'Nicaragua',
#  'tweet': 'RT @ToruoAzalia: Tengo miedo por lo que esta pasando en el mundo.',
#  'username': 'Andrea V 🌵'}
# {'_id': ObjectId('5ad29659d8694d77f392b6ab'),
#  'fecha': 'Sat Apr 14 23:11:29 +0000 2018',
#  'location': 'www.deportereyydereyes.cl',
#  'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt '
#           '#Valdivia empatan 2-2 goles para los salmoneros Joaquín Diaz y '
#           'Jaime Gr…',
#  'username': 'Juan Antonio Torres'}
# {'_id': ObjectId('5ad29659d8694d77f392b6ac'),
#  'fecha': 'Sat Apr 14 23:10:50 +0000 2018',
#  'location': 'Lima, Peru',
#  'tweet': 'Tutela de derechos y derecho a la prueba del sospechoso (Casación '
#           '14-2010, La Libertad), por Jaime Coaguila Valdivi… '
#           'https://t.co/Udkt6GNOFD',
#  'username': 'Franco Magnet Zegna'}
# {'_id': ObjectId('5ad29659d8694d77f392b6ad'),
#  'fecha': 'Sat Apr 14 23:10:43 +0000 2018',
#  'location': '',
#  'tweet': '@chico_perez Es atractiva turísticamente, pero para vivir es '
#           'horrible... Fome, pura lluvia y todo lo atractivo está fuera de '
#           'Valdivia.',
#  'username': 'Ca cm0l3d1 Ja'}
# {'_id': ObjectId('5ad29659d8694d77f392b6ae'),
#  'fecha': 'Sat Apr 14 23:10:40 +0000 2018',
#  'location': '',
#  'tweet': 'RT @CebolinhaSEP: Espelando alguém dizer plo Flamengo...\n'
#           '\n'
#           '"Poxa,  pla que isso?"\n'
#           '"Deixa pla lá"\n'
#           '"Vai pelder o foco"\n'
#           '"Tá bligando por bobage…',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad29659d8694d77f392b6af'),
#  'fecha': 'Sat Apr 14 23:10:15 +0000 2018',
#  'location': '',
#  'tweet': '@gustastockler =/',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad29659d8694d77f392b6b0'),
#  'fecha': 'Sat Apr 14 23:10:14 +0000 2018',
#  'location': 'Valdivia- Chile',
#  'tweet': 'Grande @canal_CDO desde Valdivia apoyando a @CDCLosLeones. '
#           '#QuieromiSpalding @camilo_zamora me debe un saludo desde… '
#           'https://t.co/nJCfRaLJwk',
#  'username': 'Benjamin'}
# ............................................................................................
# {'_id': ObjectId('5ad2965ad8694d77f392b6b1'),
#  'fecha': 'Sat Apr 14 23:10:12 +0000 2018',
#  'location': '',
#  'tweet': 'Acostados con mí hijo viendo la final de liga DirecTV ... Mi hijo '
#           'quiere el regalito x fis #QuieroMiSpalding https://t.co/8yLS24WIKp',
#  'username': 'David Caifil'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b2'),
#  'fecha': 'Sat Apr 14 23:10:11 +0000 2018',
#  'location': '',
#  'tweet': '#quieromispalding aunque soy del cdv, con todo apoyamos a los '
#           'fantasmas!!!! Vamos con todo apoyando al basquet de valdivia!!!!',
#  'username': '\uf8ff Cristian'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b3'),
#  'fecha': 'Sat Apr 14 23:09:57 +0000 2018',
#  'location': '',
#  'tweet': '@canal_CDO .apoyando a las animas desde Quellon. Saludos a mi hijo '
#           'Luciano Cadin amante del basquetbol que estudia… '
#           'https://t.co/I1c05xHhQn',
#  'username': 'Hermy del Carmen Moyano Haro'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b4'),
#  'fecha': 'Sat Apr 14 23:09:47 +0000 2018',
#  'location': 'Buenos Aires, Argentina',
#  'tweet': 'RT @miguelisaok: Charla con vecinos de Ciudad Valdivia.\n'
#           'Preocupación por la situación económica del País, pero siempre '
#           'frente a las dificul…',
#  'username': 'Mujeres Peronistas'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b5'),
#  'fecha': 'Sat Apr 14 23:09:34 +0000 2018',
#  'location': '',
#  'tweet': '#QuieroMISPALDING por favor que no se pegue el canal....desde '
#           'Valdivia',
#  'username': 'Pamela Uribe'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b6'),
#  'fecha': 'Sat Apr 14 23:09:31 +0000 2018',
#  'location': 'Sleepy Hollow y Calalini',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Abrahel Angell ♀'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b7'),
#  'fecha': 'Sat Apr 14 23:08:39 +0000 2018',
#  'location': 'SP, Brazil',
#  'tweet': '@Valdivia_10 Hoje tá fora do normal',
#  'username': 'GUST∆'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b8'),
#  'fecha': 'Sat Apr 14 23:08:37 +0000 2018',
#  'location': 'Lima, Peru',
#  'tweet': 'Tutela de derechos y derecho a la prueba del sospechoso (Casación '
#           '14-2010, La Libertad), por Jaime Coaguila Valdivia '
#           'https://t.co/moXYLEr8Ml',
#  'username': 'legis.pe'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6b9'),
#  'fecha': 'Sat Apr 14 23:08:06 +0000 2018',
#  'location': '',
#  'tweet': '@gustastockler so hoje? orraaa uhsahuad',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ba'),
#  'fecha': 'Sat Apr 14 23:07:26 +0000 2018',
#  'location': 'Calama, Chile',
#  'tweet': 'Final jornada día sábado #CampeonatoLoto2018, el puntero consiguió '
#           'un empate en talca ante rangers y D. Valdivia em… '
#           'https://t.co/2TeZKyrZ38',
#  'username': 'Jorge cqn'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6bb'),
#  'fecha': 'Sat Apr 14 23:07:10 +0000 2018',
#  'location': 'Valdivia-Chile',
#  'tweet': '#QuieromiSpalding desde Valdivia apoyando a las '
#           'ánimas👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻\n'
#           '#ligadirectv espero ese balón pa… https://t.co/Y4OwyqzZGC',
#  'username': 'Botitas De Tarth'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6bc'),
#  'fecha': 'Sat Apr 14 23:06:52 +0000 2018',
#  'location': 'Lissabon, Portugal',
#  'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#           'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#           '#MarchaPorLaCienc…',
#  'username': 'Science for Progress - Science Advocacy'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6bd'),
#  'fecha': 'Sat Apr 14 23:06:26 +0000 2018',
#  'location': '',
#  'tweet': '@Jovirone1 melhoras jovi \nxesque',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6be'),
#  'fecha': 'Sat Apr 14 23:06:18 +0000 2018',
#  'location': 'La Serena, Coquimbo',
#  'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#           'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#  'username': 'Fernando Sermeño'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6bf'),
#  'fecha': 'Sat Apr 14 23:06:07 +0000 2018',
#  'location': 'Cuiabá-MT',
#  'tweet': '@WFracari @CebolinhaSEP @andrizek Não esqueci aquela desse cara de '
#           'pau dedar o Valdívia AO VIVO no programa dele para o procurador do '
#           'STJD..',
#  'username': 'Dagotiam ENEAcampeão'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c0'),
#  'fecha': 'Sat Apr 14 23:05:41 +0000 2018',
#  'location': '',
#  'tweet': 'Y aquí estoy... En casa de nuevo, con mi gente, con los que te '
#           'quieren.\n'
#           '\n'
#           'Nos vemos éste noche en Suka!\n'
#           '\n'
#           'PD: Si o no… https://t.co/4NP6J4vzWP',
#  'username': 'Cristian Pérez'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c1'),
#  'fecha': 'Sat Apr 14 23:04:53 +0000 2018',
#  'location': '',
#  'tweet': '@djemerson_crf @FoxSportsBrasil @Flamengo De hoje nem fodendo '
#           'hahahahah',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c2'),
#  'fecha': 'Sat Apr 14 23:04:51 +0000 2018',
#  'location': '',
#  'tweet': 'El recibimiento de los hinchas que viajaron de Valdivia para ver a '
#           '@cd_lasanimas ante @CDCLosLeones en Quilpué… '
#           'https://t.co/e24TvIEerY',
#  'username': 'José Miguel González'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c3'),
#  'fecha': 'Sat Apr 14 23:04:30 +0000 2018',
#  'location': 'Puerto Montt - Chile',
#  'tweet': 'RT @primerabdechile: Terminó.... Terminó, cerrado 2 a 2 entre '
#           '#PuertoMontt y #Valdivia..... Ya 4 fechas sin perder los salmoneros '
#           'y los del…',
#  'username': 'Fernando España T'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c4'),
#  'fecha': 'Sat Apr 14 23:04:14 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: Ahora voy al aire desde Valdivia en @T13 '
#           '#Tele13 conversaré con @Alvaropaci sobre la suspensión de la charla '
#           'de mañana…',
#  'username': 'Peatón Furioso 2017'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c5'),
#  'fecha': 'Sat Apr 14 23:04:08 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: En reunión con Alcalde @omar_sabat conversando '
#           'sobre los desafíos de Valdivia. Una ciudad muy linda y según el '
#           'Alcalde…',
#  'username': 'Peatón Furioso 2017'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c6'),
#  'fecha': 'Sat Apr 14 23:04:02 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: Seguimos recorriendo Valdivia! '
#           'https://t.co/O2w2OkvKVX',
#  'username': 'Peatón Furioso 2017'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c7'),
#  'fecha': 'Sat Apr 14 23:03:55 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: Terminando encuentro con pastores en Valdivia. '
#           'Siempre es reconfortante conocer la opinión y recibir el apoyo de '
#           'la co…',
#  'username': 'Peatón Furioso 2017'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c8'),
#  'fecha': 'Sat Apr 14 23:03:50 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: En la Plaza de Valdivia: conversando con la '
#           'prensa, anotando las inquietudes de la gente; y una que otra selfie '
#           '📷 http…',
#  'username': 'Peatón Furioso 2017'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6c9'),
#  'fecha': 'Sat Apr 14 23:03:47 +0000 2018',
#  'location': 'Puerto Montt, Chile',
#  'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt '
#           '#Valdivia empatan 2-2 goles para los salmoneros Joaquín Diaz y '
#           'Jaime Gr…',
#  'username': 'Puerto es Albiverde'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ca'),
#  'fecha': 'Sat Apr 14 23:03:24 +0000 2018',
#  'location': 'Puerto Montt, Chile',
#  'tweet': 'RT @omarandrest: Con dos pelotas claras para abrir la cuenta en el '
#           '2do tiempo el arquero de Valdivia se transformó en figura, el juego '
#           'mejo…',
#  'username': 'Puerto es Albiverde'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6cb'),
#  'fecha': 'Sat Apr 14 23:01:46 +0000 2018',
#  'location': 'lucanoland',
#  'tweet': 'RT @tejastermaster: updates de cachimbadas hasta el momento:\n'
#           '1eros = Andrea Luna y Wanxaco\n'
#           '2dos = el cumpleañero Valdivia\n'
#           '3eros = Sandro Fa…',
#  'username': 'Lucano'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6cc'),
#  'fecha': 'Sat Apr 14 23:01:08 +0000 2018',
#  'location': 'Santiago de Chile',
#  'tweet': 'Con dos pelotas claras para abrir la cuenta en el 2do tiempo el '
#           'arquero de Valdivia se transformó en figura, el jue… '
#           'https://t.co/lncuuxO329',
#  'username': 'Omar Téllez Elgueta'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6cd'),
#  'fecha': 'Sat Apr 14 23:01:08 +0000 2018',
#  'location': 'US, Chile and every where',
#  'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#           'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#           '#MarchaPorLaCienc…',
#  'username': 'Maximiliano Bello'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ce'),
#  'fecha': 'Sat Apr 14 23:01:04 +0000 2018',
#  'location': 'Brasília, Brasil',
#  'tweet': '@Valdivia_10 @FoxSportsBrasil @Flamengo Irmão, eu acho que não foi, '
#           'vc acha. Tem analista que acha que foi é que nã… '
#           'https://t.co/LEQhAOhN1u',
#  'username': 'CRF Djemerson'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6cf'),
#  'fecha': 'Sat Apr 14 23:00:57 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'Valdivia empata a dos contra Puerto Montt https://t.co/jQlaRwx9BZ',
#  'username': 'soyvaldivia.cl'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d0'),
#  'fecha': 'Sat Apr 14 23:00:46 +0000 2018',
#  'location': '',
#  'tweet': 'RT @primerabdechile: Terminó.... Terminó, cerrado 2 a 2 entre '
#           '#PuertoMontt y #Valdivia..... Ya 4 fechas sin perder los salmoneros '
#           'y los del…',
#  'username': 'Felipe Gonzalez'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d1'),
#  'fecha': 'Sat Apr 14 23:00:43 +0000 2018',
#  'location': 'Yungay 499, Valdivia',
#  'tweet': 'Valdivia empata a dos contra Puerto Montt https://t.co/Ijw7N4aEhN',
#  'username': 'Diario Austral'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d2'),
#  'fecha': 'Sat Apr 14 23:00:33 +0000 2018',
#  'location': '',
#  'tweet': 'Final ! Deportes Puerto Montt 2-2 Deportes Valdivia',
#  'username': 'Felipe Gonzalez'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d3'),
#  'fecha': 'Sat Apr 14 23:00:19 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'RT @primerabdechile: Terminó.... Terminó, cerrado 2 a 2 entre '
#           '#PuertoMontt y #Valdivia..... Ya 4 fechas sin perder los salmoneros '
#           'y los del…',
#  'username': 'Sevienencambios!!!!'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d4'),
#  'fecha': 'Sat Apr 14 23:00:00 +0000 2018',
#  'location': '',
#  'tweet': 'Fiscalizaron obras de #QuieroMiBarrio del @Minvu en el sector '
#           '#TenienteMerino de #Valdivia https://t.co/L5aIdncLEL… '
#           'https://t.co/SDw2UvLvl7',
#  'username': 'Quiero Mi Barrio'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d5'),
#  'fecha': 'Sat Apr 14 22:59:38 +0000 2018',
#  'location': 'Santiago Chile',
#  'tweet': 'RT @ceciliamorel: Seguimos en nuestra gira por la región de Los '
#           'Ríos. Ya estamos en Valdivia, feliz de seguir conociendo propuestas '
#           'que mej…',
#  'username': 'Silvia H Martínez S'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d6'),
#  'fecha': 'Sat Apr 14 22:59:27 +0000 2018',
#  'location': '',
#  'tweet': 'RT @DeUrrestiSenado: Hoy acompañamos a las Agrupación de Parkinson '
#           'Valdivia en la primera marcha 45 socios que se han propuesto '
#           'conseguir u…',
#  'username': 'BrigadaParlamentariaPS'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d7'),
#  'fecha': 'Sat Apr 14 22:59:17 +0000 2018',
#  'location': 'Puerto Montt',
#  'tweet': 'Termina el partido en un empate a 2 goles por lado entre Dptes '
#           'Puerto Montt y Dptes Valdivia en el clásico del sur de Chile',
#  'username': 'Fernando España E'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d8'),
#  'fecha': 'Sat Apr 14 22:59:16 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Terminó.... Terminó, cerrado 2 a 2 entre #PuertoMontt y '
#           '#Valdivia..... Ya 4 fechas sin perder los salmoneros y los… '
#           'https://t.co/asRieIY2b7',
#  'username': 'primerabchile'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6d9'),
#  'fecha': 'Sat Apr 14 22:59:06 +0000 2018',
#  'location': 'Santiago, Chile',
#  'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt '
#           '#Valdivia empatan 2-2 goles para los salmoneros Joaquín Diaz y '
#           'Jaime Gr…',
#  'username': 'Fco. Nasser Viligrón'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6da'),
#  'fecha': 'Sat Apr 14 22:58:28 +0000 2018',
#  'location': 'Medellín, Colombia',
#  'tweet': 'RT @JairoSa81951568: @ANI_Colombia @MinTransporteCo '
#           '@TransitoPolicia la infraestructura vial en la vía Yarumal puerto '
#           'Valdivia es pésima pa…',
#  'username': 'mige'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6db'),
#  'fecha': 'Sat Apr 14 22:58:20 +0000 2018',
#  'location': '',
#  'tweet': '@andrizek hahahha e o jogo do palmeiras foi tudo normal ne? '
#           'hahahahah',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6dc'),
#  'fecha': 'Sat Apr 14 22:58:07 +0000 2018',
#  'location': 'Valdivia-Chile',
#  'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#           'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#           '@canal13. Irem…',
#  'username': 'Mylthon'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6dd'),
#  'fecha': 'Sat Apr 14 22:57:47 +0000 2018',
#  'location': '',
#  'tweet': 'El referi F. Jara declara que el partido entre Puerto Montt y D. '
#           'Valdivia esta empatado.',
#  'username': 'Orsai Chile'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6de'),
#  'fecha': 'Sat Apr 14 22:57:38 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt '
#           '#Valdivia empatan 2-2 goles para los salmoneros Joaquín Diaz y '
#           'Jaime Gr…',
#  'username': 'primerabchile'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6df'),
#  'fecha': 'Sat Apr 14 22:57:14 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'La gente se pregunta si #PuertoMontt juega a ganar o a no perder '
#           'contra #Valdivia....',
#  'username': 'primerabchile'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e0'),
#  'fecha': 'Sat Apr 14 22:57:07 +0000 2018',
#  'location': '',
#  'tweet': 'FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt #Valdivia '
#           'empatan 2-2 goles para los salmoneros Joaquín Diaz… '
#           'https://t.co/cRN6oWPviJ',
#  'username': 'ale argandoña'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e1'),
#  'fecha': 'Sat Apr 14 22:57:02 +0000 2018',
#  'location': '',
#  'tweet': '@djemerson_crf @FoxSportsBrasil @Flamengo ahh nao foi? se pega a '
#           'bola antes e depois o jogador nao é penalti? entao… '
#           'https://t.co/kw1ipPWUIi',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e2'),
#  'fecha': 'Sat Apr 14 22:56:17 +0000 2018',
#  'location': '',
#  'tweet': 'Me dijo q era la unica y tenía 20 gatas🎶',
#  'username': 'Nina Valdivia'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e3'),
#  'fecha': 'Sat Apr 14 22:55:56 +0000 2018',
#  'location': 'São Mateus, SP',
#  'tweet': 'RT @victorschimidt1: Meu #SPFC ideal seria esse. \n'
#           'Com a variação de Militão se posicionando como zagueiro no momento '
#           'ofensivo, júnior abert…',
#  'username': 'nessa| força Barça  🇾🇪'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e4'),
#  'fecha': 'Sat Apr 14 22:55:50 +0000 2018',
#  'location': 'Chile',
#  'tweet': "90'+4' ¡TERMINÓ EL PARTIDO!\n"
#           '\n'
#           'Deportes Puerto Montt y Deportes Valdivia repartieron puntos tras '
#           'igualar 2-2 en el Ch… https://t.co/IX500Drfal',
#  'username': 'En el Camarín'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e5'),
#  'fecha': 'Sat Apr 14 22:55:29 +0000 2018',
#  'location': 'Chile, Los Rios',
#  'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#           'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#           '#MarchaPorLaCienc…',
#  'username': 'Valdiviano'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e6'),
#  'fecha': 'Sat Apr 14 22:55:15 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Amarilla para Poncet en el Torreón.... Minuto 92 se acaba el '
#           '#PuertoMontt #Valdivia con cerrado empate.',
#  'username': 'primerabchile'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e7'),
#  'fecha': 'Sat Apr 14 22:55:02 +0000 2018',
#  'location': '',
#  'tweet': 'Thor con mis hijos en Valdivia, Chile https://t.co/RmexJX0TaL',
#  'username': 'armandomirabal'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e8'),
#  'fecha': 'Sat Apr 14 22:54:43 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'A minutos que comience el 3 juego @CDCLosLeones @cd_lasanimas '
#           '#valdiviacl Final @liga_nacional https://t.co/TteXPBinuu',
#  'username': 'CoolTV'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6e9'),
#  'fecha': 'Sat Apr 14 22:54:18 +0000 2018',
#  'location': 'Brasília, Brasil',
#  'tweet': '@Valdivia_10 @FoxSportsBrasil @Flamengo O negócio é que não foi '
#           'penal no Dudu. Que comparação medíocre.',
#  'username': 'CRF Djemerson'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ea'),
#  'fecha': 'Sat Apr 14 22:53:46 +0000 2018',
#  'location': '',
#  'tweet': "#PrimeraB | 90+2' AMARILLA para Gastón Poncet en Deportes Valdivia. "
#           'DPM 2-2 DV. https://t.co/MXqo07bJYt',
#  'username': 'Rumbo a Primera #RP'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6eb'),
#  'fecha': 'Sat Apr 14 22:53:39 +0000 2018',
#  'location': 'Chile',
#  'tweet': "90'+1' ¡AMARILLA en Deportes Valdivia!\n"
#           '\n'
#           'Gastón Poncet recibe una nueva amonestación en el elenco '
#           'visitante.… https://t.co/1gSx7Yn1tN',
#  'username': 'En el Camarín'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ec'),
#  'fecha': 'Sat Apr 14 22:53:21 +0000 2018',
#  'location': 'São Paulo',
#  'tweet': '@oboneco_ Estreia do valdivia ne?',
#  'username': 'Luiz'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ed'),
#  'fecha': 'Sat Apr 14 22:53:15 +0000 2018',
#  'location': '',
#  'tweet': '@FoxSportsBrasil @Flamengo contra o palmeiras falam que é mimimi ne',
#  'username': 'CHINELINHO'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ee'),
#  'fecha': 'Sat Apr 14 22:53:05 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Expulsado Javier Aquino.... Aguanta últimos minutos con uno menos '
#           '#PuertoMontt ... Ya en tiempo extra #Valdivia se va a buscar el '
#           'triunfo.',
#  'username': 'primerabchile'}
# {'_id': ObjectId('5ad2965ad8694d77f392b6ef'),
#  'fecha': 'Sat Apr 14 22:52:54 +0000 2018',
#  'location': '',
# ...
#  'location': '',
#  'tweet': 'RT @EducacionZ5_Ec: AHORA | Se da inicio de clases del período '
#           'lectivo 2018-2019 Bachillerato Internacional en la Unidad Educativa '
#           'Valdivia…',
#  'username': 'Lolita Del Carmen'}
# {'_id': ObjectId('5ad2965dd8694d77f392b80b'),
#  'fecha': 'Sat Apr 14 20:46:55 +0000 2018',
#  'location': '',
#  'tweet': 'RT @PicoPesantes: #PorLaEducacionEc Se realizó la entrega de '
#           'uniformes y textos en la UE "Valdivia" parroquia Manglaralto, '
#           'indicandoles a l…',
#  'username': 'Lolita Del Carmen'}
# {'_id': ObjectId('5ad2965dd8694d77f392b80c'),
#  'fecha': 'Sat Apr 14 20:46:31 +0000 2018',
#  'location': 'são paulo fc real madrid cf',
#  'tweet': 'valdivia, everton e carneiro\n'
#           'olha o contra ataque https://t.co/bBRy0L45Ts',
#  'username': 'pedro'}
# {'_id': ObjectId('5ad2965dd8694d77f392b80d'),
#  'fecha': 'Sat Apr 14 20:46:17 +0000 2018',
#  'location': 'México City',
#  'tweet': 'https://t.co/17zlJwqhzK',
#  'username': 'Andrea'}
# {'_id': ObjectId('5ad2965dd8694d77f392b80e'),
#  'fecha': 'Sat Apr 14 20:46:15 +0000 2018',
#  'location': '',
#  'tweet': 'RT @la_serena_chile: 🏈Alcalde Roberto Jacob junto al presidente de '
#           'la Asociación de Rugby La Serena, Robertino Collao, firmaron un '
#           'convenio…',
#  'username': 'leonidas chavez'}
# {'_id': ObjectId('5ad2965dd8694d77f392b80f'),
#  'fecha': 'Sat Apr 14 20:46:13 +0000 2018',
#  'location': '',
#  'tweet': 'RT @primerabdechile: Ya se vieneeeee..... Desde el Chinquihue '
#           'Puerto Montt - Valdivia, linfático tarde para ver fútbol',
#  'username': 'Felipe Gonzalez'}
# {'_id': ObjectId('5ad2965dd8694d77f392b810'),
#  'fecha': 'Sat Apr 14 20:45:45 +0000 2018',
#  'location': 'LA PAZ, BCS',
#  'tweet': 'RT @Martinez1Felip: Juan Alberto Valdivia Alvarado; candidato '
#           'priista a senador de la Republica, cabalga en caballo de hacienda '
#           'hacia la me…',
#  'username': 'JUANALBERTO VALDIVIA'}
# {'_id': ObjectId('5ad2965dd8694d77f392b811'),
#  'fecha': 'Sat Apr 14 20:45:26 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'Poco menos de una semanita para la próxima #BeerJSValdivia 😱 Ya '
#           'estamos preparando las presentaciones para el 19 de… '
#           'https://t.co/P4PwL0f5bF',
#  'username': 'BeerJS Valdivia'}
# {'_id': ObjectId('5ad2965dd8694d77f392b812'),
#  'fecha': 'Sat Apr 14 20:45:15 +0000 2018',
#  'location': 'machali-santiago',
#  'tweet': 'RT @alb0black: Niño comiendo erizos en Mercado Fluvial de Valdivia, '
#           'febrero 1960.\n'
#           '#Chile https://t.co/LxwuNHz8as',
#  'username': 'pablo rojo latapiat'}
# {'_id': ObjectId('5ad2965dd8694d77f392b813'),
#  'fecha': 'Sat Apr 14 20:45:03 +0000 2018',
#  'location': 'Región de Coquimbo- Chile',
#  'tweet': 'RT @la_serena_chile: 🏈Alcalde Roberto Jacob junto al presidente de '
#           'la Asociación de Rugby La Serena, Robertino Collao, firmaron un '
#           'convenio…',
#  'username': 'serenaycoquimbo'}
# {'_id': ObjectId('5ad2965dd8694d77f392b814'),
#  'fecha': 'Sat Apr 14 20:44:42 +0000 2018',
#  'location': 'La Serena, Chile',
#  'tweet': '🏈Alcalde Roberto Jacob junto al presidente de la Asociación de '
#           'Rugby La Serena, Robertino Collao, firmaron un conve… '
#           'https://t.co/dxJaiqIjPn',
#  'username': 'Municipio La Serena'}
# {'_id': ObjectId('5ad2965dd8694d77f392b815'),
#  'fecha': 'Sat Apr 14 20:44:35 +0000 2018',
#  'location': '',
#  'tweet': 'RT @joseantoniokast: Terminando encuentro con pastores en Valdivia. '
#           'Siempre es reconfortante conocer la opinión y recibir el apoyo de '
#           'la co…',
#  'username': 'estreangel'}
# {'_id': ObjectId('5ad2965dd8694d77f392b816'),
#  'fecha': 'Sat Apr 14 20:44:33 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Vai toma no seu cu @Cruzeiro',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b817'),
#  'fecha': 'Sat Apr 14 20:43:31 +0000 2018',
#  'location': 'Puerto Montt, Chile',
#  'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#           'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#           'Capitán.\n'
#           '\n'
#           'Ban…',
#  'username': 'Nadia Parra'}
# {'_id': ObjectId('5ad2965dd8694d77f392b818'),
#  'fecha': 'Sat Apr 14 20:43:12 +0000 2018',
#  'location': 'México City',
#  'tweet': 'https://t.co/2W6vZXQ3Sl',
#  'username': 'Andrea'}
# {'_id': ObjectId('5ad2965dd8694d77f392b819'),
#  'fecha': 'Sat Apr 14 20:42:44 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Camisa do Cruzeiro ta igual o Futebol do time acertou em cheio a '
#           'umbro',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b81a'),
#  'fecha': 'Sat Apr 14 20:42:25 +0000 2018',
#  'location': 'Puerto Montt, Chile',
#  'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#           'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#           'Capitán.\n'
#           '\n'
#           'Ban…',
#  'username': 'Mun. Puerto Montt'}
# {'_id': ObjectId('5ad2965dd8694d77f392b81b'),
#  'fecha': 'Sat Apr 14 20:42:23 +0000 2018',
#  'location': '',
#  'tweet': 'RT @Carabdechile: Carabineros del OS7 #LosRíos, procedió  a la '
#           'detección de dos hombres y una mujer extranjera por tráfico de '
#           'drogas, en la…',
#  'username': 'estreangel'}
# {'_id': ObjectId('5ad2965dd8694d77f392b81c'),
#  'fecha': 'Sat Apr 14 20:42:08 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'RT @vivisleles: Camisa feia pra combinar com o futebol desses '
#           'babacas',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b81d'),
#  'fecha': 'Sat Apr 14 20:41:47 +0000 2018',
#  'location': 'Camino Coñaripe-Liquiñe Km 15',
#  'tweet': 'Descubre lo que Termas Coñaripe tiene para ti!\n'
#           'el mejor servicio a tu disposición para un descanso soñado\n'
#           'no dejes… https://t.co/OJCSakgM1S',
#  'username': 'Termas Coñaripe'}
# {'_id': ObjectId('5ad2965dd8694d77f392b81e'),
#  'fecha': 'Sat Apr 14 20:41:35 +0000 2018',
#  'location': 'Santiago de Chile',
#  'tweet': 'Niño comiendo erizos en Mercado Fluvial de Valdivia, febrero 1960.\n'
#           '#Chile https://t.co/LxwuNHz8as',
#  'username': 'Alberto Sironvalle'}
# {'_id': ObjectId('5ad2965dd8694d77f392b81f'),
#  'fecha': 'Sat Apr 14 20:41:22 +0000 2018',
#  'location': 'Valdivia',
#  'tweet': 'RT @biobio: Carabineros allana local clandestino de alcohol en '
#           'Valdivia: detienen a decena de jóvenes https://t.co/68BlM6BCJ6 '
#           'https://t.co/…',
#  'username': 'Alexis'}
# {'_id': ObjectId('5ad2965dd8694d77f392b820'),
#  'fecha': 'Sat Apr 14 20:40:50 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Meu sonho é sair no soco com o Egídio',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b821'),
#  'fecha': 'Sat Apr 14 20:40:09 +0000 2018',
#  'location': 'México City',
#  'tweet': 'https://t.co/Qlc66pizwR',
#  'username': 'Andrea'}
# {'_id': ObjectId('5ad2965dd8694d77f392b822'),
#  'fecha': 'Sat Apr 14 20:39:50 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Árbitro: Felipe Jara\n'
#           'Asist 1: Julio Abdala\n'
#           'Asist 2: Rodrigo Concha\n'
#           '4to árbitro: Víctor Abarzúa\n'
#           '\n'
#           'Deportes Puerto Mon… https://t.co/p2BjlsF6oF',
#  'username': 'En el Camarín'}
# {'_id': ObjectId('5ad2965dd8694d77f392b823'),
#  'fecha': 'Sat Apr 14 20:39:33 +0000 2018',
#  'location': '',
#  'tweet': 'Gil que no activo, guacha que se le escapo.',
#  'username': 'Nina Valdivia'}
# {'_id': ObjectId('5ad2965dd8694d77f392b824'),
#  'fecha': 'Sat Apr 14 20:38:33 +0000 2018',
#  'location': '',
#  'tweet': 'RT @IndirectasRock: Uno intenta, intenta, intenta.. Hasta que no '
#           'intenta más.',
#  'username': 'Nina Valdivia'}
# {'_id': ObjectId('5ad2965dd8694d77f392b825'),
#  'fecha': 'Sat Apr 14 20:38:33 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Banca de Deportes Valdivia:\n'
#           '\n'
#           '33 Richard Leyton (AS)\n'
#           '15 Antonio Castillo\n'
#           '5 Max Gatica\n'
#           '19 Ignacio Torres\n'
#           '14 Jorge Gal… https://t.co/5hHoBCLsW2',
#  'username': 'En el Camarín'}
# {'_id': ObjectId('5ad2965dd8694d77f392b826'),
#  'fecha': 'Sat Apr 14 20:37:20 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Banca de Deportes Puerto Montt:\n'
#           '\n'
#           '12 Cristian Limenza (AS)\n'
#           '11 Hernán Becica\n'
#           '13 Leandro Delgado\n'
#           '9 Javier Guarino\n'
#           '28 B… https://t.co/PJ342YItiB',
#  'username': 'En el Camarín'}
# {'_id': ObjectId('5ad2965dd8694d77f392b827'),
#  'fecha': 'Sat Apr 14 20:35:54 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Parei com o Brasileirão na primeira rodada',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b828'),
#  'fecha': 'Sat Apr 14 20:35:14 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Time que quer ganhar jogo não pode colocar Rafael Marques',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b829'),
#  'fecha': 'Sat Apr 14 20:34:38 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Formación de Deportes Valdivia:\n'
#           '\n'
#           '1 Diego Figueroa\n'
#           '\n'
#           '8 Pablo Leal\n'
#           '17 Cristián González\n'
#           '23 Victor González\n'
#           '\n'
#           '11 Erick W… https://t.co/pMkUBXZ0hI',
#  'username': 'En el Camarín'}
# {'_id': ObjectId('5ad2965dd8694d77f392b82a'),
#  'fecha': 'Sat Apr 14 20:33:28 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Mano Menezes colocou Rafael Marques pra ficar 10 contra 10',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b82b'),
#  'fecha': 'Sat Apr 14 20:32:49 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Esse Boludo ta é tirando de reclamar ainda',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b82c'),
#  'fecha': 'Sat Apr 14 20:32:47 +0000 2018',
#  'location': '',
#  'tweet': 'RT @primerabdechile: Ya se vieneeeee..... Desde el Chinquihue '
#           'Puerto Montt - Valdivia, linfático tarde para ver fútbol',
#  'username': 'Dani Uz'}
# {'_id': ObjectId('5ad2965dd8694d77f392b82d'),
#  'fecha': 'Sat Apr 14 20:32:34 +0000 2018',
#  'location': '',
#  'tweet': 'RT @primerabdechile: Ya se vieneeeee..... Desde el Chinquihue '
#           'Puerto Montt - Valdivia, linfático tarde para ver fútbol',
#  'username': 'JUAN CARLOS'}
# {'_id': ObjectId('5ad2965dd8694d77f392b82e'),
#  'fecha': 'Sat Apr 14 20:31:52 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': '@Omar_Sabat @munivaldivia Pero Alcalde no me de respuestas, sea un '
#           'Alcalde con  acción... sabe, ud no me cae mal al… '
#           'https://t.co/g0a2R5zmN2',
#  'username': 'Lorenzo Yañez'}
# {'_id': ObjectId('5ad2965dd8694d77f392b82f'),
#  'fecha': 'Sat Apr 14 20:31:32 +0000 2018',
#  'location': 'Chile',
#  'tweet': 'Ya se vieneeeee..... Desde el Chinquihue Puerto Montt - Valdivia, '
#           'linfático tarde para ver fútbol',
#  'username': 'primerabchile'}
# {'_id': ObjectId('5ad2965dd8694d77f392b830'),
#  'fecha': 'Sat Apr 14 20:31:31 +0000 2018',
#  'location': '',
#  'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#           'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#           'Capitán.\n'
#           '\n'
#           'Ban…',
#  'username': 'delacunaaltablon'}
# {'_id': ObjectId('5ad2965dd8694d77f392b831'),
#  'fecha': 'Sat Apr 14 20:31:20 +0000 2018',
#  'location': 'Santiago, Chile',
#  'tweet': "I'm at Metro Pedro de Valdivia in Santiago, Región Metropolitana "
#           'https://t.co/UubelqLm3k',
#  'username': 'Jonathan Munizaga'}
# {'_id': ObjectId('5ad2965dd8694d77f392b832'),
#  'fecha': 'Sat Apr 14 20:30:00 +0000 2018',
#  'location': 'Valdivia, Chile',
#  'tweet': 'Área Silvestre Pilunkura te invita este 28 de abril a participar '
#           'colaborativamente en la construcción de su portal… '
#           'https://t.co/wm6xyGUfEP',
#  'username': 'Vive Valdivia'}
# {'_id': ObjectId('5ad2965dd8694d77f392b833'),
#  'fecha': 'Sat Apr 14 20:29:27 +0000 2018',
#  'location': 'Nicaragua',
#  'tweet': 'RT @realestelifc: Volvemos a Diriamba y Galeano lo sabe... '
#           'https://t.co/Yr1nUoUzVz',
#  'username': 'Andrea V 🌵'}
# {'_id': ObjectId('5ad2965dd8694d77f392b834'),
#  'fecha': 'Sat Apr 14 20:28:57 +0000 2018',
#  'location': '',
#  'tweet': 'RT @XicanitaBonita: My own attitude stresses me out sometimes. I '
#           'get mad at me for being mad.',
#  'username': 'Jackie'}
# {'_id': ObjectId('5ad2965dd8694d77f392b835'),
#  'fecha': 'Sat Apr 14 20:28:15 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Ainda bem q eu nem me iludi com Brasileirão',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b836'),
#  'fecha': 'Sat Apr 14 20:28:06 +0000 2018',
#  'location': 'Puerto Montt Chile',
#  'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#           'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#           'Capitán.\n'
#           '\n'
#           'Ban…',
#  'username': 'MarcosVelasquez'}
# {'_id': ObjectId('5ad2965dd8694d77f392b837'),
#  'fecha': 'Sat Apr 14 20:26:25 +0000 2018',
#  'location': 'Sete Lagoas, Minas Gerais',
#  'tweet': 'Virou modinha msm https://t.co/5cUd2HaGl7',
#  'username': 'Bieel™'}
# {'_id': ObjectId('5ad2965dd8694d77f392b838'),
#  'fecha': 'Sat Apr 14 20:25:44 +0000 2018',
#  'location': 'Puerto Montt, Chile',
#  'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#           'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#           'Capitán.\n'
#           '\n'
#           'Ban…',
#  'username': 'Torneo_CL'}
# {'_id': ObjectId('5ad2965dd8694d77f392b839'),
#  'fecha': 'Sat Apr 14 20:25:22 +0000 2018',
#  'location': 'México City',
#  'tweet': 'https://t.co/nPtnb2jK8A',
#  'username': 'Andrea'}
# {'_id': ObjectId('5ad2965dd8694d77f392b83a'),
#  'fecha': 'Sat Apr 14 20:24:03 +0000 2018',
#  'location': 'Puerto Montt, Chile',
#  'tweet': '⚽️  TABLA DE POSICIONES ⚽️ Así llegan Deportes #PuertoMontt y '
#           '#Valdivia al juego de hoy en el estadio Chinquihue. ¡… '
#           'https://t.co/DwFMYPPadk',
#  'username': 'Torneo_CL'}
# {'_id': ObjectId('5ad2965dd8694d77f392b83b'),
#  'fecha': 'Sat Apr 14 20:23:46 +0000 2018',
#  'location': 'Antofagasta, Chile',
#  'tweet': 'RT @RedInvestChile: En Valdivia, también se hace presente la Red de '
#           'Investigadoras en la #marchaporlaciencia https://t.co/uXB5XczoPn',
#  'username': 'BERNARDITA'}
# {'_id': ObjectId('5ad2965dd8694d77f392b83c'),
#  'fecha': 'Sat Apr 14 20:23:42 +0000 2018',
#  'location': '',
#  'tweet': 'https://t.co/EOZEDxr9yY',
#  'username': 'JohnnyBet Picks'}
# {'_id': ObjectId('5ad2965dd8694d77f392b83d'),
#  'fecha': 'Sat Apr 14 20:22:57 +0000 2018',
#  'location': '',
#  'tweet': '#PrimeraB | Deportes Puerto Montt vs Deportes Valdivia\n'
#           '\n'
#           'Xl de Deportes Valdivia:\n'
#           '\n'
#           'Diego Figueroa\n'
#           '*\n'
#           'Pablo Leal\n'
#           'Crist… https://t.co/CX0S6MYKhs',
#  'username': 'Rumbo a Primera #RP'}
# {'_id': ObjectId('5ad2965dd8694d77f392b83e'),
#  'fecha': 'Sat Apr 14 20:22:56 +0000 2018',
#  'location': '',
#  'tweet': 'Banca de suplentes\n'
#           '\n'
#           'Cristián Limenza (A. S. )\n'
#           'Leandro Delgado\n'
#           'Benjamín Valdivia\n'
#           'Albano Becica\n'
#           'Jorge Guajardo\n'
#           'Javier… https://t.co/sZuiKgmvjt',
#  'username': 'Rumbo a Primera #RP'}
# {'_id': ObjectId('5ad2965dd8694d77f392b83f'),
#  'fecha': 'Sat Apr 14 20:22:54 +0000 2018',
#  'location': '',
#  'tweet': '#PrimeraB | Deportes Puerto Montt vs Deportes Valdivia\n'
#           '\n'
#           'Xl de Deportes Puerto Montt:\n'
#           '\n'
#           'Fabián Moyano\n'
#           '*\n'
#           'Joaquín Díaz… https://t.co/hOk3GXLaqN',
#  'username': 'Rumbo a Primera #RP'}
# {'_id': ObjectId('5ad2965dd8694d77f392b840'),
#  'fecha': 'Sat Apr 14 20:22:51 +0000 2018',
#  'location': '',
#  'tweet': '#PrimeraB | ¡SE REEDITA EL CLÁSICO DEL SUR! Luego a las 18:00 horas '
#           'Deportes Puerto Montt recibe a Deportes Valdivia, en el Chinquihue.',
#  'username': 'Rumbo a Primera #RP'}
# ............................................................................................

# %%
from pymongo import MongoClient
import pprint
client = MongoClient()
db = client.INFO268
print ("Parte I, 1)Mostrar los documentos de su colección mostrando solamente el campo \"location\"." )
cursor = db.tweets.find()
for t in cursor:
    if (t['location']!=''):
        print (t['location'])
    else:
        print('None')
# Out:
# Parte I, 1)Mostrar los documentos de su colección mostrando solamente el campo "location".
# Valdivia, Chile
# Yungay 499, Valdivia
# Plaza Huincul, Neuquén, Argen.
# Plaza Huincul, Neuquén, Argen.
# None
# Plaza Huincul, Neuquén, Argen.
# Gravity Falls
# Plaza Huincul, Neuquén, Argen.
# Valdivia - Chile
# Plaza Huincul, Neuquén, Argen.
# Valdivia, Chile.
# Plaza Huincul, Neuquén, Argen.
# La Paz - Bolivia
# Osorno de - Chile
# Santiago, Chile
# None
# caracas venezuela
# V REGION
# None
# PUERTO MONTT, Chile
# Lima
# None
# None
# None
# Valdivia - Chile
# Santiago de Chile
# Valdivia
# None
# Valdivia
# None
# Valdivia, Chile
# None
# Chile
# Valdivia, Chile
# Lima
# None
# None
# chile
# None
# None
# Santiago, Chile
# None
# Metropolitana de Santiago
# None
# En Mi Casa
# Alagoinhas-BA
# None
# Belo Horizonte
# La Paz - Bolivia
# Valdivia, Chile
# None
# None
# None
# Santiago, Metropolitana de San
# Temuco, Chile
# Valdivia, Chile
# None
# Salta- Argentina
# Santiago Chile
# Valdivia, Chile
# Brasília, Distrito Federal
# salta argentina
# None
# Salta
# None
# Temuco, Chile
# Temuco, Chile
# Temuco, Chile
# None
# None
# Valdivia
# None
#  coquimbo-chile
# None
# Talca
# Santiago de Chile
# None
# None
# Santiago de Chile
# None
# Valdivia, Chile
# None
# Perú
# La Serena
# Venezuela♥/Por ahora en Chile
# None
# Cuiabá-MT
# La Serena, Coquimbo
# None
# None
# Valdivia
# Chile, sur
# Valdivia - Chile
# Nicaragua
# www.deportereyydereyes.cl
# Lima, Peru
# None
# None
# None
# Valdivia- Chile
# None
# None
# None
# Buenos Aires, Argentina
# None
# Sleepy Hollow y Calalini
# SP, Brazil
# Lima, Peru
# None
# Calama, Chile
# Valdivia-Chile
# Lissabon, Portugal
# None
# La Serena, Coquimbo
# Cuiabá-MT
# None
# None
# None
# Puerto Montt - Chile
# None
# None
# None
# None
# None
# Puerto Montt, Chile
# Puerto Montt, Chile
# lucanoland
# Santiago de Chile
# US, Chile and every where
# Brasília, Brasil
# Valdivia, Chile
# None
# Yungay 499, Valdivia
# None
# Chile
# None
# Santiago Chile
# None
# Puerto Montt
# Chile
# Santiago, Chile
# Medellín, Colombia
# None
# Valdivia-Chile
# None
# Chile
# Chile
# None
# None
# None
# São Mateus, SP
# Chile
# Chile, Los Rios
# Chile
# None
# Valdivia, Chile
# Brasília, Brasil
# None
# Chile
# São Paulo
# None
# Chile
# None
# Temuco, Chile
# None
# Valparaiso,Chile
# Valdivia, Chile
# None
# None
# None
# None
# None
# Puerto Montt
# None
# None
# Chile
# None
# -33.460545,-70.61319
# None
# Chile
# Valdivia
# Chile
# Valdivia, Chile
# La Reina, Chile
# Valdivia, Chile
# None
# Chile
# None
# None
# Valdivia, Chile
# None
# None
# Santiago, Chile
# Valdivia
# Chile
# None
# None
# Chile
# None
# São Mateus, SP
# Chile
# None
# Santos
# Ciudad de México
# None
# iTunes Amazon Spotify Youtube
# Tres Arroyos, Argentina
# None
# Mendoza, Argentina
# Chile
# None
# Chile
# La Paz, BCS
# Lima
# Ecuador
# None
# None
# None
# Valdivia, Chile
# None
# Santiago, Chile.
# Miraflores, Lima
# Brasil
# Estádio do Morumbi
# Valdivia, Chile
# Nicaragua
# None
# Chile
# Reino de Avalon
# Santiago de Chile
# Tempe, AZ
# Region de Tarapaca, Iquique.
# Metropolitana de Santiago, Chi
# Concepción, Chile
# Chile
# Puerto Montt, Chile
# González Suárez y Ceslao Marín
# GUAYAS 🇪🇨
# GUAYAS 🇪🇨
# Chile 🇨🇱
# sentado frente al mar.
# None
# None
# None
# Limache
# None
# Valdivia, Chile
# None
# Valdivia, Chile
# Valdivia, Chile
# Yungay 499, Valdivia
# Chile
# Yungay 499, Valdivia
# Valdivia, Chile
# None
# Las Condes, Chile
# Puerto Montt
# None
# Las Condes, Chile
# Region Metropolitana
# None
# Limache
# None
# Temuco, Chile
# None
# Snap e Insta: valenferrandini
# None
# Puerto Montt, Chile
# Plaza Huincul, Neuquén, Argen.
# Chile
# Plaza Huincul, Neuquén, Argen.
# Chile
# None
# Plaza Huincul, Neuquén, Argen.
# None
# Plaza Huincul, Neuquén, Argen.
# None
# Argentina
# Ceará, Brasil
# Plaza Huincul, Neuquén, Argen.
# Puerto Montt, Chile
# Temuco
# None
# Plaza Huincul, Neuquén, Argen.
# None
# Santiago, Chile
# Valdivia, Chile.
# Cada Rincon del Planeta
# Temuco
# Puerto Montt, Chile
# Valdivia, Chile
# Plaza Huincul, Neuquén, Argen.
# None
# None
# Chile
# Valdivia, Chile
# None
# Plaza Huincul, Neuquén, Argen.
# Temuco, Chile
# puerto montt, chile
# Plaza Huincul, Neuquén, Argen.
# Plaza Huincul, Neuquén, Argen.
# San José, Costa Rica
# Limache
# viña del mar
# Plaza Huincul, Neuquén, Argen.
# Santiago
# None
# None
# Puerto Montt, Chile
# Santa Elena-Manantial de Chanduy-Chanduy
# Montevideo, Uruguay
# None
# Chile
# Puerto Montt, Chile
# Chile
# Puerto Montt, Chile
# Valdivia - Chile
# Puerto Montt Chile
# Puerto Montt, Chile
# chile
# None
# Castro, Chiloé
# Puerto Montt
# None
# Santiago
# Puerto Montt
# Valdivia, Chile.
# Santiago de Chile
# None
# Valdivia, Chile
# Chile
# None
# ✌
# Chile
# chile
# Santiago, Metropolitana de Santiago
# Santa Cruz, Argentina
# None
# None
# Chile
# Brisbane, Queensland
# Santiago, Chile
# oaxaca de juarez, oaxaca
# Viña del Mar - Chile
# Valdivia, Chile
# planeta Tierra
# Quilicura, Chile
# Concepción (Chile)
# None
# Valdivia
# Chile
# -23.556215,-46.657982
# Valdivia, Chile
# Chile
# Viña del Mar.
# None
# None
# Valdivia, Chile
# None
# Pisco-Elqui
# La Granja, Chile
# Chile
# São Paulo, Brasil
# None
# None
# None
# Coquimbo, Chile
# Santiago de Chile
# Puerto Montt, Chile
# Valdivia, Chile
# None
# São Paulo - Brasil
# Maullín, Los Lagos - Santiago
# Santiago, Chile
# None
# None
# None
# None
# None
# London
# Talca,Chile
# Puerto Montt, Chile
# Chile
# Valdivia, Chile.
# Viña del Mar, Chile
# Los Rios - Magallanes y BioBio
# Concepción, Chile 🇨🇱
# Chile
# Valdivia, Chile
# Chile
# Santiago, Chile
# CHILE
# Sete Lagoas, Minas Gerais
# Naples, Florida
# Sete Lagoas, Minas Gerais
# Santiago, Chile
# VALDIVIA, CHILE.
# None
# Chile
# Santiago, Chile
# None
# Puerto Montt, X Región, Chile
# None
# Santiago, Chile
# Colombia
# Chillán, Chile
# Valdivia, Chile
# Santiago, Chile
# Santiago, Chile
# Santiago, Chile
# Sete Lagoas, Minas Gerais
# Las Condes, Chile
# Santiago, Chile
# Valdivia, Chile
# Santiago, Chile
# Santiago, Chile
# Chile
# None
# Santiago, Chile
# Santiago, Chile
# Sete Lagoas, Minas Gerais
# Valdivia ♥ Chile
# None
# Concón, Viña del Mar, Valparaíso
# None
# Chile
# Sete Lagoas, Minas Gerais
# None
# None
# Puerto Montt, Chile
# Santiago
# Santiago de Chile
# Sete Lagoas, Minas Gerais
# Cuenca-Ecuador
# None
# Santiago de Chile
# Sete Lagoas, Minas Gerais
# Sete Lagoas, Minas Gerais
# Estádio do Morumbi
# Chile
# Puerto Montt, Chile
# chile
# Chile
# Chile
# None
# None
# são paulo fc real madrid cf
# México City
# None
# None
# LA PAZ, BCS
# Valdivia, Chile
# machali-santiago
# Región de Coquimbo- Chile
# La Serena, Chile
# None
# Sete Lagoas, Minas Gerais
# Puerto Montt, Chile
# México City
# Sete Lagoas, Minas Gerais
# Puerto Montt, Chile
# None
# Sete Lagoas, Minas Gerais
# Camino Coñaripe-Liquiñe Km 15
# Santiago de Chile
# Valdivia
# Sete Lagoas, Minas Gerais
# México City
# Chile
# None
# None
# Chile
# Chile
# Sete Lagoas, Minas Gerais
# Sete Lagoas, Minas Gerais
# Chile
# Sete Lagoas, Minas Gerais
# Sete Lagoas, Minas Gerais
# None
# None
# Valdivia, Chile
# Chile
# None
# Santiago, Chile
# Valdivia, Chile
# Nicaragua
# None
# Sete Lagoas, Minas Gerais
# Puerto Montt Chile
# Sete Lagoas, Minas Gerais
# Puerto Montt, Chile
# México City
# Puerto Montt, Chile
# Antofagasta, Chile
# None
# None
# None
# None
# None

# %%
print ("Parte I, 2)Mostrar los tweets que contienen la palabra \"UACh\".")
cursor = db.tweets.find({"tweet":{"$regex":"uach", "$options": "i"}})
for t in cursor:
    pprint.pprint(t)
# Out:
# Parte I, 2)Mostrar los tweets que contienen la palabra "UACh".
# {'_id': ObjectId('5ad2965dd8694d77f392b823'),
#  'fecha': 'Sat Apr 14 20:39:33 +0000 2018',
#  'location': '',
#  'tweet': 'Gil que no activo, guacha que se le escapo.',
#  'username': 'Nina Valdivia'}

# %%
print ("Parte I, 3)Contar el número de tweets por username.")
cursor = db.tweets.aggregate([ {"$group" : {"_id":"$username", "count":{"$sum":1} } } ])
for t in cursor:
    pprint.pprint(t)
# Out:
# Parte I, 3)Contar el número de tweets por username.
# {'_id': 'JohnnyBet Picks', 'count': 1}
# {'_id': 'Jackie', 'count': 1}
# {'_id': 'Jonathan Munizaga', 'count': 1}
# {'_id': 'delacunaaltablon', 'count': 1}
# {'_id': 'Dani Uz', 'count': 1}
# {'_id': 'Alexis', 'count': 1}
# {'_id': 'Alberto Sironvalle', 'count': 1}
# {'_id': 'Mun. Puerto Montt', 'count': 1}
# {'_id': 'Nadia Parra', 'count': 1}
# {'_id': 'Municipio La Serena', 'count': 1}
# {'_id': 'BeerJS Valdivia', 'count': 1}
# {'_id': 'JUANALBERTO VALDIVIA', 'count': 1}
# {'_id': 'Andrea', 'count': 4}
# {'_id': 'Lolita Del Carmen', 'count': 2}
# {'_id': 'Gustavo Gatica', 'count': 1}
# {'_id': 'Dixit.io', 'count': 1}
# {'_id': 'Eulalia Pozo Vicuña', 'count': 1}
# {'_id': 'Tecnociencia', 'count': 1}
# {'_id': 'Orlando Navarro V.', 'count': 1}
# {'_id': 'Caio Casagrande', 'count': 1}
# {'_id': 'Roberto Iturralde', 'count': 1}
# {'_id': 'Constanza', 'count': 1}
# {'_id': 'Regional 98.9 FM', 'count': 1}
# {'_id': 'Marccello', 'count': 1}
# {'_id': 'INVIAS  #767', 'count': 1}
# {'_id': 'P.P.', 'count': 9}
# {'_id': 'Felipe Carrasco', 'count': 1}
# {'_id': 'LA TERUKA - LosRios', 'count': 1}
# {'_id': 'Bieel™', 'count': 18}
# {'_id': 'Miguel Araneda', 'count': 1}
# {'_id': 'pablo rojo latapiat', 'count': 1}
# {'_id': 'Alejandro Rodríguez', 'count': 1}
# {'_id': 'Aguante Valdivia', 'count': 1}
# {'_id': "Mauricio C'", 'count': 1}
# {'_id': 'Vicente Bugueño', 'count': 1}
# {'_id': 'Xina', 'count': 1}
# {'_id': 'Carolina Infante', 'count': 1}
# {'_id': 'Moises Galindo', 'count': 1}
# {'_id': '\uf8ff Rodrigo Báez', 'count': 1}
# {'_id': 'Sir Alexis Guerrero', 'count': 1}
# {'_id': 'Marcelo Mendonça', 'count': 1}
# {'_id': 'BERNARDITA', 'count': 1}
# {'_id': 'LeoSam', 'count': 1}
# {'_id': 'Alvaro Elgueta', 'count': 1}
# {'_id': 'el Confutatorio', 'count': 1}
# {'_id': 'SalvadorSchwartzmann', 'count': 1}
# {'_id': 'Patita', 'count': 1}
# {'_id': 'Amalia Pereira 🌼', 'count': 1}
# {'_id': 'carlos yucudani', 'count': 1}
# {'_id': 'Ideas For Good', 'count': 1}
# {'_id': 'Nicolás C', 'count': 1}
# {'_id': 'Roberto Cadagán D', 'count': 1}
# {'_id': 'JUAN CARLOS', 'count': 2}
# {'_id': 'Javiera Bahamonde', 'count': 1}
# {'_id': 'Matias.Eduardo', 'count': 1}
# {'_id': 'Danilo Oyarzún', 'count': 1}
# {'_id': 'A LA HORA Noticias', 'count': 1}
# {'_id': 'Italo Antonio', 'count': 1}
# {'_id': 'Sebastian Oñate', 'count': 1}
# {'_id': 'Pollo', 'count': 1}
# {'_id': 'MercedesGonzalez', 'count': 1}
# {'_id': 'Hector', 'count': 2}
# {'_id': 'paulina loyola', 'count': 2}
# {'_id': 'javier narea olmos', 'count': 1}
# {'_id': 'César A. Valdivia', 'count': 1}
# {'_id': 'BA VG', 'count': 1}
# {'_id': 'italo saffirio', 'count': 1}
# {'_id': 'Edgar Valdivia', 'count': 1}
# {'_id': 'Dep. Puerto Montt', 'count': 2}
# {'_id': 'Cristian Alberto Orias', 'count': 1}
# {'_id': 'Ubagueras Mundial™️', 'count': 1}
# {'_id': '\uf8ff Cristian', 'count': 1}
# {'_id': 'Francisca Terminel', 'count': 1}
# {'_id': 'Cami Almonacid', 'count': 1}
# {'_id': 'cris sanchezv', 'count': 1}
# {'_id': 'Abrahel Angell ♀', 'count': 1}
# {'_id': 'Franco Magnet Zegna', 'count': 1}
# {'_id': 'Chaoz.', 'count': 3}
# {'_id': 'Alicia Blake', 'count': 1}
# {'_id': 'Robert Aguayo Rubio', 'count': 1}
# {'_id': 'Alejandro Rosales', 'count': 1}
# {'_id': 'Fernando Sermeño', 'count': 1}
# {'_id': 'MarcosVelasquez', 'count': 2}
# {'_id': 'Dagotiam ENEAcampeão', 'count': 2}
# {'_id': 'Daniel San', 'count': 1}
# {'_id': 'Gloria Alejandra', 'count': 2}
# {'_id': 'El Tiempo Valdivia', 'count': 1}
# {'_id': 'PlanetaEscort.cl', 'count': 3}
# {'_id': 'Micky', 'count': 3}
# {'_id': 'josé ureta', 'count': 1}
# {'_id': 'serenaycoquimbo', 'count': 1}
# {'_id': 'Hernán Ocáriz Díaz', 'count': 1}
# {'_id': 'Paulo', 'count': 1}
# {'_id': 'Botitas De Tarth', 'count': 1}
# {'_id': 'Danilo Ormeño', 'count': 1}
# {'_id': 'andrea', 'count': 1}
# {'_id': 'Miguel Gamonal', 'count': 3}
# {'_id': 'VICTOR NAVARRETE', 'count': 1}
# {'_id': 'legis.pe', 'count': 1}
# {'_id': 'Gaston Galindez', 'count': 1}
# {'_id': 'Agenda Construcción', 'count': 1}
# {'_id': 'Hermy del Carmen Moyano Haro', 'count': 1}
# {'_id': 'sergio sepulveda', 'count': 1}
# {'_id': 'Juan Pablo Castillo', 'count': 1}
# {'_id': 'valen 🌌', 'count': 1}
# {'_id': 'Fco Covarrubias Izq.', 'count': 1}
# {'_id': 'NiKolas', 'count': 1}
# {'_id': 'Silvia H Martínez S', 'count': 1}
# {'_id': 'Rafael Vale', 'count': 1}
# {'_id': 'Cecilia Aguero R', 'count': 1}
# {'_id': 'GUST∆', 'count': 1}
# {'_id': 'Willie Stephen', 'count': 1}
# {'_id': 'Coke Salinas', 'count': 1}
# {'_id': 'Marcela Jesús', 'count': 1}
# {'_id': 'ClaU Contreras', 'count': 1}
# {'_id': 'Catalina 🤔', 'count': 1}
# {'_id': 'fernando ubiergo', 'count': 1}
# {'_id': 'Ca cm0l3d1 Ja', 'count': 1}
# {'_id': 'Jorge cqn', 'count': 1}
# {'_id': 'ignacio saldivia', 'count': 2}
# {'_id': 'Lucas Blaset', 'count': 1}
# {'_id': 'Jorge Quezada H', 'count': 1}
# {'_id': 'Waldo Poblete', 'count': 1}
# {'_id': 'Gonzalo Canales', 'count': 1}
# {'_id': 'Mujeres Peronistas', 'count': 1}
# {'_id': 'Radio Austral CD 970', 'count': 1}
# {'_id': 'Carlos Oporto', 'count': 1}
# {'_id': 'El Indio Pérez', 'count': 1}
# {'_id': 'Ana Bermont', 'count': 1}
# {'_id': 'primerabchile', 'count': 14}
# {'_id': 'Jaime Coloma T.', 'count': 1}
# {'_id': 'Almendra', 'count': 1}
# {'_id': 'Daniel Campusano', 'count': 1}
# {'_id': 'Nancy Herrera', 'count': 2}
# {'_id': 'YuRay Valdivia', 'count': 1}
# {'_id': 'Deportes Valdivia', 'count': 4}
# {'_id': 'Jesus Rincones A', 'count': 1}
# {'_id': 'Marcelo León', 'count': 1}
# {'_id': 'Jorge Ortega 🇨🇱', 'count': 1}
# {'_id': 'CHINELINHO', 'count': 19}
# {'_id': 'Nancy Valdivia', 'count': 1}
# {'_id': 'Felipe Gonzalez', 'count': 10}
# {'_id': 'Rumbo a Primera #RP', 'count': 13}
# {'_id': 'Jaime Cardenas', 'count': 1}
# {'_id': 'Carla Montecinos', 'count': 1}
# {'_id': 'GIPART', 'count': 1}
# {'_id': 'Mabel', 'count': 1}
# {'_id': 'Yordano CCTV', 'count': 1}
# {'_id': 'Guilherme Lins', 'count': 1}
# {'_id': '\U0001f926Isabel\U0001f926', 'count': 1}
# {'_id': 'Comunicar y Servir', 'count': 1}
# {'_id': 'Yajaira Basaure', 'count': 1}
# {'_id': 'Jorge Peralta Romo', 'count': 1}
# {'_id': 'Rosa Oyarce', 'count': 1}
# {'_id': 'soyvaldivia.cl', 'count': 6}
# {'_id': 'KATHY VALDIVIA ❤️', 'count': 6}
# {'_id': 'Andrea Obaid', 'count': 2}
# {'_id': 'Pamela Uribe', 'count': 1}
# {'_id': 'Gidion', 'count': 1}
# {'_id': 'Gabriel #GOBD', 'count': 1}
# {'_id': 'Intendencia RM', 'count': 1}
# {'_id': 'CALDERON', 'count': 1}
# {'_id': 'Nestor', 'count': 1}
# {'_id': 'Daniela Alejandra ✨', 'count': 1}
# {'_id': 'RioenLinea', 'count': 1}
# {'_id': 'El Engendro', 'count': 1}
# {'_id': 'FELIPE ANTONIO ROJAS', 'count': 1}
# {'_id': 'Andrés Reyes Barria', 'count': 1}
# {'_id': 'Vive Valdivia', 'count': 1}
# {'_id': 'marlyna 2016', 'count': 1}
# {'_id': 'Aus Valdivia, Chile', 'count': 1}
# {'_id': 'Eugenia Gonzalez', 'count': 1}
# {'_id': 'Esther Coronel de Ib', 'count': 2}
# {'_id': 'Andrés Oyarzo', 'count': 1}
# {'_id': 'Ivonne Fernandez', 'count': 1}
# {'_id': 'Science for Progress - Science Advocacy', 'count': 1}
# {'_id': 'Dominic', 'count': 1}
# {'_id': 'Alejandro Durán R.', 'count': 1}
# {'_id': '@bellita56', 'count': 1}
# {'_id': 'Juan Antonio Torres', 'count': 1}
# {'_id': 'Murilo Batista', 'count': 1}
# {'_id': 'Carlos v F', 'count': 1}
# {'_id': 'Ximena Ravanal', 'count': 1}
# {'_id': 'LuisAguilera', 'count': 1}
# {'_id': 'Miguel Moscoso', 'count': 1}
# {'_id': 'Mario Ayala', 'count': 1}
# {'_id': 'Tonga basso', 'count': 1}
# {'_id': 'Lorenzo Yañez', 'count': 1}
# {'_id': 'Andrea V 🌵', 'count': 3}
# {'_id': '#PASIONALBIVERDE 🇨🇱🇳🇬', 'count': 1}
# {'_id': 'Luis Alberto Bustos', 'count': 1}
# {'_id': 'Hector Arenas', 'count': 1}
# {'_id': 'mauricio saldivia', 'count': 1}
# {'_id': 'Orsai Chile', 'count': 2}
# {'_id': 'José Miguel González', 'count': 1}
# {'_id': 'Bárbara Cox', 'count': 5}
# {'_id': 'Fernando España T', 'count': 1}
# {'_id': 'estreangel', 'count': 3}
# {'_id': 'Puerto es Albiverde', 'count': 8}
# {'_id': 'SDDS RUEDA', 'count': 1}
# {'_id': 'GUILLERMO SEBASTIAN', 'count': 1}
# {'_id': 'Termas Coñaripe', 'count': 1}
# {'_id': 'Diario Austral', 'count': 4}
# {'_id': 'Ampliado del Tren', 'count': 1}
# {'_id': 'pedro', 'count': 1}
# {'_id': 'Alejandro Barañano', 'count': 1}
# {'_id': 'Felipe Nicolás Esparza', 'count': 1}
# {'_id': 'Peatón Furioso 2017', 'count': 5}
# {'_id': 'El Sudaca', 'count': 1}
# {'_id': 'Omar Téllez Elgueta', 'count': 3}
# {'_id': 'PlayDiario', 'count': 1}
# {'_id': 'Maximiliano Bello', 'count': 1}
# {'_id': 'CRF Djemerson', 'count': 2}
# {'_id': 'Huaso retamboriao', 'count': 1}
# {'_id': 'Javier Santana F', 'count': 1}
# {'_id': 'Sevienencambios!!!!', 'count': 1}
# {'_id': 'Marina Boattini', 'count': 3}
# {'_id': 'MINVU LOS RIOS', 'count': 1}
# {'_id': 'Quiero Mi Barrio', 'count': 1}
# {'_id': 'Pepe Toledo', 'count': 1}
# {'_id': 'Diego Jara Ramírez', 'count': 1}
# {'_id': 'BrigadaParlamentariaPS', 'count': 1}
# {'_id': 'Fernando España E', 'count': 2}
# {'_id': 'CoolTV', 'count': 1}
# {'_id': '#poderanimal', 'count': 1}
# {'_id': 'mige', 'count': 1}
# {'_id': 'Marfe', 'count': 1}
# {'_id': 'Lucano', 'count': 1}
# {'_id': 'Mylthon', 'count': 1}
# {'_id': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ', 'count': 17}
# {'_id': 'ale argandoña', 'count': 1}
# {'_id': 'En el Camarín', 'count': 19}
# {'_id': 'Valdiviano', 'count': 1}
# {'_id': 'armandomirabal', 'count': 1}
# {'_id': 'Gonzalo', 'count': 1}
# {'_id': 'Marcha por la Ciencia y el Conocimiento Chile', 'count': 1}
# {'_id': 'Monica Becerra', 'count': 1}
# {'_id': 'Luiz', 'count': 1}
# {'_id': 'ERIN PRESLEY', 'count': 1}
# {'_id': 'Rafael Baquedano Ch.', 'count': 1}
# {'_id': 'Nina Valdivia', 'count': 6}
# {'_id': 'cristián', 'count': 1}
# {'_id': 'Hardy', 'count': 1}
# {'_id': 'Nico', 'count': 1}
# {'_id': 'Alfonso De Urresti', 'count': 2}
# {'_id': 'JuanCarlos TedeschiE', 'count': 1}
# {'_id': 'Jacky San Martin', 'count': 1}
# {'_id': 'Leandro Paredes', 'count': 1}
# {'_id': 'Herman Valdivia', 'count': 1}
# {'_id': 'Katalina Ebel', 'count': 1}
# {'_id': 'Fernando Ubiergo', 'count': 1}
# {'_id': 'leonidas chavez', 'count': 1}
# {'_id': 'Cristian Pérez', 'count': 1}
# {'_id': 'Deportes Para Ti', 'count': 1}
# {'_id': 'Carmen Andrea', 'count': 1}
# {'_id': 'Bruno Garces', 'count': 1}
# {'_id': 'Maca Rodriguez', 'count': 1}
# {'_id': 'Trabajos en Chile', 'count': 1}
# {'_id': 'Carlos López', 'count': 1}
# {'_id': 'Bri Bri', 'count': 1}
# {'_id': 'Pedro Alexandre', 'count': 1}
# {'_id': 'Luis Zambrano', 'count': 1}
# {'_id': 'Nati❄️', 'count': 1}
# {'_id': 'teja', 'count': 1}
# {'_id': 'Patricio', 'count': 1}
# {'_id': 'Rosario Araneda', 'count': 1}
# {'_id': 'David Caifil', 'count': 1}
# {'_id': 'Valito', 'count': 1}
# {'_id': 'Paz Daniela', 'count': 1}
# {'_id': 'TorcidaTricolorSPFC', 'count': 1}
# {'_id': 'Ruben Corral', 'count': 1}
# {'_id': 'Roberto Fuentealba K', 'count': 1}
# {'_id': 'Felipe', 'count': 1}
# {'_id': 'Bedgar', 'count': 2}
# {'_id': 'Cris Mellado', 'count': 1}
# {'_id': 'MossArt', 'count': 1}
# {'_id': 'Pilar', 'count': 1}
# {'_id': 'Húsares De La Muerte', 'count': 2}
# {'_id': 'diegoyarzun13', 'count': 1}
# {'_id': 'ryokito', 'count': 1}
# {'_id': 'Noticias Policiales', 'count': 1}
# {'_id': 'Esteban Silva Cuadra', 'count': 1}
# {'_id': 'Johanna', 'count': 1}
# {'_id': 'María Laura Martínez', 'count': 1}
# {'_id': 'mano Marcos', 'count': 1}
# {'_id': 'Antonio Yepez', 'count': 1}
# {'_id': 'MAE-Pastaza', 'count': 1}
# {'_id': 'Vania Figueroa', 'count': 2}
# {'_id': 'Karina Bravo', 'count': 1}
# {'_id': 'Raul Severino', 'count': 1}
# {'_id': 'Berni Fuentes', 'count': 2}
# {'_id': 'Sole Cáceres', 'count': 1}
# {'_id': 'gonzalo tiznado', 'count': 1}
# {'_id': 'Luis Romario', 'count': 1}
# {'_id': 'Fco. Nasser Viligrón', 'count': 1}
# {'_id': 'FelipeGallegosVargas', 'count': 1}
# {'_id': 'nessa| força Barça  🇾🇪', 'count': 2}
# {'_id': 'elias', 'count': 1}
# {'_id': 'Fredy Vargas', 'count': 1}
# {'_id': 'iona e. leopold b.', 'count': 1}
# {'_id': 'Héctor Yépez M', 'count': 2}
# {'_id': 'Torneo_CL', 'count': 4}
# {'_id': 'Rodrigo Mora Pozas', 'count': 1}
# {'_id': 'Seremi M.Ambiente RM', 'count': 1}
# {'_id': 'Enrique Aparicio', 'count': 1}
# {'_id': 'Jose Miguel 🇨🇱™', 'count': 1}
# {'_id': 'Luis Franco', 'count': 1}
# {'_id': 'Benjamin', 'count': 1}
# {'_id': 'Stenio Urbano ⭕⚪⚫', 'count': 1}

# %%
pprint.pprint(list(db.tweets.find()))
# Out:
# [{'_id': ObjectId('5ad29659d8694d77f392b64d'),
#   'fecha': 'Sun Apr 15 00:00:48 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'Valdivia empató 2-2 contra Deportes Puerto Montt '
#            'https://t.co/jQlaRwx9BZ',
#   'username': 'soyvaldivia.cl'},
#  {'_id': ObjectId('5ad29659d8694d77f392b64e'),
#   'fecha': 'Sun Apr 15 00:00:43 +0000 2018',
#   'location': 'Yungay 499, Valdivia',
#   'tweet': 'Valdivia empató 2-2 contra Deportes Puerto Montt '
#            'https://t.co/Ijw7N4aEhN',
#   'username': 'Diario Austral'},
#  {'_id': ObjectId('5ad29659d8694d77f392b64f'),
#   'fecha': 'Sun Apr 15 00:00:10 +0000 2018',
#   'location': 'Plaza Huincul, Neuquén, Argen.',
#   'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#            'https://t.co/K85uxOHf0M',
#   'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'},
#  {'_id': ObjectId('5ad29659d8694d77f392b650'),
#   'fecha': 'Sat Apr 14 23:59:34 +0000 2018',
#   'location': 'Plaza Huincul, Neuquén, Argen.',
#   'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#            'https://t.co/0xPd7pwBjZ',
#   'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'},
#  {'_id': ObjectId('5ad29659d8694d77f392b651'),
#   'fecha': 'Sat Apr 14 23:59:30 +0000 2018',
#   'location': '',
#   'tweet': '@jmc_valdivia Sin vergüenzas inconsecuentes mentirosos corruptos '
#            'aprovechadores todos sinónimos de zurdos',
#   'username': 'sergio sepulveda'},
#  {'_id': ObjectId('5ad29659d8694d77f392b652'),
#   'fecha': 'Sat Apr 14 23:59:03 +0000 2018',
#   'location': 'Plaza Huincul, Neuquén, Argen.',
#   'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#            'https://t.co/9DOyklHd62',
#   'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'},
#  {'_id': ObjectId('5ad29659d8694d77f392b653'),
#   'fecha': 'Sat Apr 14 23:58:59 +0000 2018',
#   'location': 'Gravity Falls',
#   'tweet': 'Con esto de viajar tanto ahora, he conocido ene de terminales.. '
#            'por el momento me quedo con el de #Valdivia',
#   'username': 'Mabel'},
#  {'_id': ObjectId('5ad29659d8694d77f392b654'),
#   'fecha': 'Sat Apr 14 23:58:20 +0000 2018',
#   'location': 'Plaza Huincul, Neuquén, Argen.',
#   'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#            'https://t.co/xuXWI4RYGV',
#   'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'},
#  {'_id': ObjectId('5ad29659d8694d77f392b655'),
#   'fecha': 'Sat Apr 14 23:58:10 +0000 2018',
#   'location': 'Valdivia - Chile',
#   'tweet': 'RT @alejoduranr: No hay caso. En @CineplanetChile de Valdivia le '
#            'suben el volumen a la publicidad, pero le bajan a la película. Es '
#            'algo que…',
#   'username': 'Jaime Cardenas'},
#  {'_id': ObjectId('5ad29659d8694d77f392b656'),
#   'fecha': 'Sat Apr 14 23:57:42 +0000 2018',
#   'location': 'Plaza Huincul, Neuquén, Argen.',
#   'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#            'https://t.co/G4TbYoBLrq',
#   'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'},
#  {'_id': ObjectId('5ad29659d8694d77f392b657'),
#   'fecha': 'Sat Apr 14 23:57:27 +0000 2018',
#   'location': 'Valdivia, Chile.',
#   'tweet': 'Termino un nuevo clásico del sur, igualaron 2-2 Valdivia y Puerto '
#            'Montt. La próxima semana se visita a San Felipe. 💪⚪️🔴',
#   'username': 'Deportes Valdivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b658'),
#   'fecha': 'Sat Apr 14 23:57:10 +0000 2018',
#   'location': 'Plaza Huincul, Neuquén, Argen.',
#   'tweet': 'Acaba de publicar una foto en Valdivia, Chile '
#            'https://t.co/zKsrSeNQG7',
#   'username': 'Jimmy ᶠᶸᶜᵏᵧₒᵤ'},
#  {'_id': ObjectId('5ad29659d8694d77f392b659'),
#   'fecha': 'Sat Apr 14 23:54:48 +0000 2018',
#   'location': 'La Paz - Bolivia',
#   'tweet': 'Muy bueno Carola Valdivia Hablamos pronto amiga!!! No después! '
#            'https://t.co/2r9lCwRl35',
#   'username': 'Esther Coronel de Ib'},
#  {'_id': ObjectId('5ad29659d8694d77f392b65a'),
#   'fecha': 'Sat Apr 14 23:54:26 +0000 2018',
#   'location': 'Osorno de - Chile',
#   'tweet': 'RT @soyvaldiviacl: Valdivia empató 2-2 contra Deportes Puerto '
#            'Montt. https://t.co/AzyPkeEdZj https://t.co/6kRK1NWDAY',
#   'username': 'Comunicar y Servir'},
#  {'_id': ObjectId('5ad29659d8694d77f392b65b'),
#   'fecha': 'Sat Apr 14 23:54:13 +0000 2018',
#   'location': 'Santiago, Chile',
#   'tweet': 'RT @ScienceMarchCL: Grande Valdivia!! 👍🏼 https://t.co/eEj8h8z8VB',
#   'username': 'Fco Covarrubias Izq.'},
#  {'_id': ObjectId('5ad29659d8694d77f392b65c'),
#   'fecha': 'Sat Apr 14 23:53:09 +0000 2018',
#   'location': '',
#   'tweet': 'RT @MlkdaColina: Hipocrisia que fala, né? https://t.co/jdMcrxNKoB',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad29659d8694d77f392b65d'),
#   'fecha': 'Sat Apr 14 23:53:02 +0000 2018',
#   'location': 'caracas venezuela',
#   'tweet': 'Exelente a pesar de la tristeza en Valdivia, Chile '
#            'https://t.co/JL0VdS3VbD',
#   'username': 'Jesus Rincones A'},
#  {'_id': ObjectId('5ad29659d8694d77f392b65e'),
#   'fecha': 'Sat Apr 14 23:52:00 +0000 2018',
#   'location': 'V REGION',
#   'tweet': '@carlosramone6 @SarcasmoChile7 @_The_Shining__ @Kaizer_cl '
#            '@dogfighters74 @jlabranaaburto @Jurel_Cesar @patodelsur53… '
#            'https://t.co/Gw1JGKDIBh',
#   'username': 'CALDERON'},
#  {'_id': ObjectId('5ad29659d8694d77f392b65f'),
#   'fecha': 'Sat Apr 14 23:51:55 +0000 2018',
#   'location': '',
#   'tweet': 'RT @legispe: Tutela de derechos y derecho a la prueba del '
#            'sospechoso (Casación 14-2010, La Libertad), por Jaime Coaguila '
#            'Valdivia https://t…',
#   'username': 'FELIPE ANTONIO ROJAS'},
#  {'_id': ObjectId('5ad29659d8694d77f392b660'),
#   'fecha': 'Sat Apr 14 23:51:27 +0000 2018',
#   'location': 'PUERTO MONTT, Chile',
#   'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#            'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#            '@canal13. Irem…',
#   'username': 'Hardy'},
#  {'_id': ObjectId('5ad29659d8694d77f392b661'),
#   'fecha': 'Sat Apr 14 23:51:26 +0000 2018',
#   'location': 'Lima ',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Nancy Herrera'},
#  {'_id': ObjectId('5ad29659d8694d77f392b662'),
#   'fecha': 'Sat Apr 14 23:50:51 +0000 2018',
#   'location': '',
#   'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#            'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#            '@canal13. Irem…',
#   'username': 'Jaime Coloma T.'},
#  {'_id': ObjectId('5ad29659d8694d77f392b663'),
#   'fecha': 'Sat Apr 14 23:50:18 +0000 2018',
#   'location': '',
#   'tweet': '@canal_CDO que gane valdivia, y la copa se quede en el sur después '
#            'de ganarle a castro, saludos desde Castro, chilo… '
#            'https://t.co/6Gyjo8JZic',
#   'username': 'ignacio saldivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b664'),
#   'fecha': 'Sat Apr 14 23:50:18 +0000 2018',
#   'location': '',
#   'tweet': '@canal_CDO que ganen las ánimas de valdivia, y la copa se quede en '
#            'el sur después de ganarle a castro, saludos desd… '
#            'https://t.co/IfZ5QnBrUx',
#   'username': 'ignacio saldivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b665'),
#   'fecha': 'Sat Apr 14 23:49:53 +0000 2018',
#   'location': 'Valdivia - Chile',
#   'tweet': '#QuieroMiSPALDING Vamos Fantasmas!! Desde Valdivia apoyando a las '
#            'Ánimas!! 🏆🏀👻👻👻 Mirándolos por #Cdo',
#   'username': 'ClaU Contreras'},
#  {'_id': ObjectId('5ad29659d8694d77f392b666'),
#   'fecha': 'Sat Apr 14 23:49:30 +0000 2018',
#   'location': 'Santiago de Chile',
#   'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#            'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#            '@canal13. Irem…',
#   'username': 'Andrea Obaid'},
#  {'_id': ObjectId('5ad29659d8694d77f392b667'),
#   'fecha': 'Sat Apr 14 23:48:24 +0000 2018',
#   'location': 'Valdivia',
#   'tweet': '👌🏽 en Valdivia, Chile https://t.co/FtuOFw2R6X',
#   'username': 'Carlos Oporto'},
#  {'_id': ObjectId('5ad29659d8694d77f392b668'),
#   'fecha': 'Sat Apr 14 23:48:24 +0000 2018',
#   'location': '',
#   'tweet': 'RT @pierovg2015: hasta cuando Sr @Lenin las unidades medicas '
#            '@IESSGuayas @IESSec van a ser centros de peregrinacion del '
#            'afiliado hoy lleva…',
#   'username': 'Antonio Yepez'},
#  {'_id': ObjectId('5ad29659d8694d77f392b669'),
#   'fecha': 'Sat Apr 14 23:48:18 +0000 2018',
#   'location': 'Valdivia',
#   'tweet': 'RT @quieromibarrio: Fiscalizaron obras de #QuieroMiBarrio del '
#            '@Minvu en el sector #TenienteMerino de #Valdivia '
#            'https://t.co/L5aIdncLEL @Min…',
#   'username': 'MINVU LOS RIOS'},
#  {'_id': ObjectId('5ad29659d8694d77f392b66a'),
#   'fecha': 'Sat Apr 14 23:46:24 +0000 2018',
#   'location': '',
#   'tweet': 'RT @StephenAmell: Heading to Coachella. When Beyonce gets on stage '
#            'I’ll be watching*.\n'
#            '\n'
#            '* - The #AndreTheGiant documentary at home because I…',
#   'username': 'KATHY VALDIVIA ❤️'},
#  {'_id': ObjectId('5ad29659d8694d77f392b66b'),
#   'fecha': 'Sat Apr 14 23:46:00 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': '#QuieromiSpalding Hola canal cdo quiero mi balón spalding desde '
#            'valdivia apoyando el basketball chileno https://t.co/SFcdD5Dmhy',
#   'username': 'Nestor'},
#  {'_id': ObjectId('5ad29659d8694d77f392b66c'),
#   'fecha': 'Sat Apr 14 23:45:53 +0000 2018',
#   'location': '',
#   'tweet': '#QuieroMiSpalding  mi pelota quedo quedó en el departamento de mi '
#            'polola y no me la va ha devolver mas :( Gonzalo Tiznado de '
#            'Valdivia.',
#   'username': 'gonzalo tiznado'},
#  {'_id': ObjectId('5ad29659d8694d77f392b66d'),
#   'fecha': 'Sat Apr 14 23:45:43 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Grande Valdivia!! 👍🏼 https://t.co/eEj8h8z8VB',
#   'username': 'Marcha por la Ciencia y el Conocimiento Chile'},
#  {'_id': ObjectId('5ad29659d8694d77f392b66e'),
#   'fecha': 'Sat Apr 14 23:45:26 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'Un chilote revoloteando por Valdivia necesita y ansía poder ganar '
#            'el balón para ir a lanzar un par de tiros a algun… '
#            'https://t.co/V66zgM0xjh',
#   'username': 'Andrés Reyes Barria'},
#  {'_id': ObjectId('5ad29659d8694d77f392b66f'),
#   'fecha': 'Sat Apr 14 23:44:35 +0000 2018',
#   'location': 'Lima ',
#   'tweet': 'RT @fernandoubiergo: Hoy por la noche Temuco, mañana en Valdivia y '
#            'el domingo en Concepción \n'
#            '\n'
#            'Vivo en la carretera 🎶 https://t.co/fbfVhfXZf4',
#   'username': 'Nancy Herrera'},
#  {'_id': ObjectId('5ad29659d8694d77f392b670'),
#   'fecha': 'Sat Apr 14 23:43:56 +0000 2018',
#   'location': '',
#   'tweet': '#QuieroMiSpalding saludos desde las Animas, Valdivia. Apoyando a '
#            'los fantasmas. Cariños',
#   'username': 'Ivonne Fernandez'},
#  {'_id': ObjectId('5ad29659d8694d77f392b671'),
#   'fecha': 'Sat Apr 14 23:43:51 +0000 2018',
#   'location': '',
#   'tweet': 'RT @poderanimal: @jimenab67 @PerrosPlazaHuem @Chilena9772 @ver65 '
#            '@silvfon @Carabdechile @UaaChile @rominasaoficial @MYRIAMHILLAVALO '
#            '@FundAn…',
#   'username': 'Eugenia Gonzalez'},
#  {'_id': ObjectId('5ad29659d8694d77f392b672'),
#   'fecha': 'Sat Apr 14 23:43:47 +0000 2018',
#   'location': 'chile',
#   'tweet': 'RT @rioenlinea: Carabineros allanó local clandestino “La Ratonera” '
#            'en Valdivia: Detuvieron a una mujer por robo '
#            'https://t.co/p7Yc8naanT #Va…',
#   'username': '@bellita56'},
#  {'_id': ObjectId('5ad29659d8694d77f392b673'),
#   'fecha': 'Sat Apr 14 23:43:29 +0000 2018',
#   'location': '',
#   'tweet': '#QuieroMiSpalding. Desde Valdivia apoyando a las Animas con '
#            'Claudia Susana y Pilar',
#   'username': 'Waldo Poblete'},
#  {'_id': ObjectId('5ad29659d8694d77f392b674'),
#   'fecha': 'Sat Apr 14 23:43:29 +0000 2018',
#   'location': '',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Carla Montecinos'},
#  {'_id': ObjectId('5ad29659d8694d77f392b675'),
#   'fecha': 'Sat Apr 14 23:43:11 +0000 2018',
#   'location': 'Santiago, Chile',
#   'tweet': 'Vamos Las Animas, vamos Valdivia!!! #QuieroMiSpalding',
#   'username': 'Alejandro Rosales'},
#  {'_id': ObjectId('5ad29659d8694d77f392b676'),
#   'fecha': 'Sat Apr 14 23:42:25 +0000 2018',
#   'location': '',
#   'tweet': 'RT @ciclorecreovia: ¡LOS SÁBADOS TAMBIÉN!\n'
#            '\n'
#            'También los sábados puedes disfrutar CicloRecreoVía.\n'
#            '\n'
#            'CicloRecreoVía funciona cada sábado en el…',
#   'username': 'Ximena Ravanal'},
#  {'_id': ObjectId('5ad29659d8694d77f392b677'),
#   'fecha': 'Sat Apr 14 23:42:08 +0000 2018',
#   'location': 'Metropolitana de Santiago',
#   'tweet': 'RT @IntendenciaRM: Sigue estas recomendaciones si vas al partido '
#            'entre @ColoColo y @udechile este domingo en el Estadio Nacional:\n'
#            '⚽️ Puerta…',
#   'username': 'Rosa Oyarce'},
#  {'_id': ObjectId('5ad29659d8694d77f392b678'),
#   'fecha': 'Sat Apr 14 23:39:54 +0000 2018',
#   'location': '',
#   'tweet': '@canal_CDO #QuieroMiSpalding desde VALDIVIA disfrutando el '
#            'basquetbol por CDO!!',
#   'username': 'diegoyarzun13'},
#  {'_id': ObjectId('5ad29659d8694d77f392b679'),
#   'fecha': 'Sat Apr 14 23:38:54 +0000 2018',
#   'location': 'En Mi Casa',
#   'tweet': '#QuieroMiSpalding #LigaDIRECTV Vamos fantasmas!! Apoyando desde '
#            'Valdivia💪👻',
#   'username': 'Almendra'},
#  {'_id': ObjectId('5ad29659d8694d77f392b67a'),
#   'fecha': 'Sat Apr 14 23:38:29 +0000 2018',
#   'location': 'Alagoinhas-BA',
#   'tweet': 'RT @brunogarces: @R0n4ldFla @ColoColo @udechile Barroso twitou '
#            'quando tiraram ele de um jogo, e mandou nas indiretas que o mundo '
#            'da voltas,…',
#   'username': 'SDDS RUEDA'},
#  {'_id': ObjectId('5ad29659d8694d77f392b67b'),
#   'fecha': 'Sat Apr 14 23:37:35 +0000 2018',
#   'location': '',
#   'tweet': 'RT @Wbrokering: @DeUrrestiSenado Gracias, Senador, por su visita a '
#            'la recientemente electa directiva de la Junta de Vecinos de '
#            'Torobayo! Mu…',
#   'username': 'Mario Ayala'},
#  {'_id': ObjectId('5ad29659d8694d77f392b67c'),
#   'fecha': 'Sat Apr 14 23:37:26 +0000 2018',
#   'location': 'Belo Horizonte',
#   'tweet': '@R0n4ldFla @ColoColo @udechile Barroso twitou quando tiraram ele '
#            'de um jogo, e mandou nas indiretas que o mundo da… '
#            'https://t.co/AEQDHuA09D',
#   'username': 'Bruno Garces'},
#  {'_id': ObjectId('5ad29659d8694d77f392b67d'),
#   'fecha': 'Sat Apr 14 23:36:50 +0000 2018',
#   'location': 'La Paz - Bolivia',
#   'tweet': 'Absolutamente así es! Muy bueno Carola Valdivia Gran abrazo de luz '
#            'amiga querida!!! https://t.co/ZtFhKhyE46',
#   'username': 'Esther Coronel de Ib'},
#  {'_id': ObjectId('5ad29659d8694d77f392b67e'),
#   'fecha': 'Sat Apr 14 23:36:27 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#            'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#            '#MarchaPorLaCienc…',
#   'username': 'Luis Alberto Bustos'},
#  {'_id': ObjectId('5ad29659d8694d77f392b67f'),
#   'fecha': 'Sat Apr 14 23:36:15 +0000 2018',
#   'location': '',
#   'tweet': '@PatoPapao @caju_sz XD\n\nEAE PATO, TUDO BOM?',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad29659d8694d77f392b680'),
#   'fecha': 'Sat Apr 14 23:35:24 +0000 2018',
#   'location': '',
#   'tweet': '@caju_sz alo @EA segue a call',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad29659d8694d77f392b681'),
#   'fecha': 'Sat Apr 14 23:34:27 +0000 2018',
#   'location': '',
#   'tweet': 'RT @Temucodiario: #Temuco: Ministro Monckeberg firma mensajes para '
#            'obras de doble vía Fundo El Carmen y Av. Pedro de Valdivia  '
#            'https://t.co…',
#   'username': 'Carlos v F'},
#  {'_id': ObjectId('5ad29659d8694d77f392b682'),
#   'fecha': 'Sat Apr 14 23:33:22 +0000 2018',
#   'location': 'Santiago, Metropolitana de San',
#   'tweet': 'RT @PedroMarinR: El entrenador de @ColoColo Pablo Guede confirma '
#            'el 11 para enfrentar a la U. Orión; Campos, Zaldivia, Insaurralde, '
#            'Opazo;…',
#   'username': 'Hector Arenas'},
#  {'_id': ObjectId('5ad29659d8694d77f392b683'),
#   'fecha': 'Sat Apr 14 23:33:08 +0000 2018',
#   'location': 'Temuco, Chile',
#   'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ '
#            '#PuertoMontt #Valdivia empatan 2-2 goles para los salmoneros '
#            'Joaquín Diaz y Jaime Gr…',
#   'username': '#PASIONALBIVERDE 🇨🇱🇳🇬'},
#  {'_id': ObjectId('5ad29659d8694d77f392b684'),
#   'fecha': 'Sat Apr 14 23:31:49 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'Valdivia empató 2-2 contra Deportes Puerto Montt. '
#            'https://t.co/AzyPkeEdZj https://t.co/6kRK1NWDAY',
#   'username': 'soyvaldivia.cl'},
#  {'_id': ObjectId('5ad29659d8694d77f392b685'),
#   'fecha': 'Sat Apr 14 23:31:47 +0000 2018',
#   'location': '',
#   'tweet': 'RT @rioenlinea: Carabineros allanó local clandestino “La Ratonera” '
#            'en Valdivia: Detuvieron a una mujer por robo '
#            'https://t.co/p7Yc8naanT #Va…',
#   'username': 'LuisAguilera'},
#  {'_id': ObjectId('5ad29659d8694d77f392b686'),
#   'fecha': 'Sat Apr 14 23:31:38 +0000 2018',
#   'location': 'Salta- Argentina',
#   'tweet': 'RT @gastonggalindez: #AHORA con @marcos_galian @AmbienteMuni en '
#            'Ciudad Valdivia conversamos con Patricia y Ramón sobre mejoras '
#            'ambientales…',
#   'username': 'Marcela Jesús'},
#  {'_id': ObjectId('5ad29659d8694d77f392b687'),
#   'fecha': 'Sat Apr 14 23:31:32 +0000 2018',
#   'location': 'Santiago Chile',
#   'tweet': 'RT @karina_bravof: La @RedInvestChile en la marcha por la ciencia '
#            'y el conocimiento también estuvo presente en regiones.\n'
#            'Valdivia\n'
#            'Valaparaí…',
#   'username': 'Esteban Silva Cuadra'},
#  {'_id': ObjectId('5ad29659d8694d77f392b688'),
#   'fecha': 'Sat Apr 14 23:31:17 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'RT @IchiBlake: Vamos Valdivia...todas y todos apoyando a '
#            '@cd_lasanimas #valdiviacl \n'
#            '¡ es nuestro Básquetbol !!',
#   'username': 'Cecilia Aguero R'},
#  {'_id': ObjectId('5ad29659d8694d77f392b689'),
#   'fecha': 'Sat Apr 14 23:30:48 +0000 2018',
#   'location': 'Brasília, Distrito Federal',
#   'tweet': 'valdivia do #SPFC fazendo live de PUBG &lt;3 que homem '
#            'https://t.co/8jgz7l6DgK',
#   'username': 'Rafael Vale'},
#  {'_id': ObjectId('5ad29659d8694d77f392b68a'),
#   'fecha': 'Sat Apr 14 23:30:44 +0000 2018',
#   'location': 'salta argentina',
#   'tweet': 'RT @gastonggalindez: #AHORA con @marcos_galian @AmbienteMuni en '
#            'Ciudad Valdivia conversamos con Patricia y Ramón sobre mejoras '
#            'ambientales…',
#   'username': 'NiKolas'},
#  {'_id': ObjectId('5ad29659d8694d77f392b68b'),
#   'fecha': 'Sat Apr 14 23:30:44 +0000 2018',
#   'location': '',
#   'tweet': '@R_Gacitua Sabes que no he podido encontrar en Valdivia 😣 con '
#            'queso crema no queda nada mal',
#   'username': 'Maca Rodriguez'},
#  {'_id': ObjectId('5ad29659d8694d77f392b68c'),
#   'fecha': 'Sat Apr 14 23:30:18 +0000 2018',
#   'location': 'Salta',
#   'tweet': '#AHORA con @marcos_galian @AmbienteMuni en Ciudad Valdivia '
#            'conversamos con Patricia y Ramón sobre mejoras ambiental… '
#            'https://t.co/hhC3GilyBy',
#   'username': 'Gaston Galindez'},
#  {'_id': ObjectId('5ad29659d8694d77f392b68d'),
#   'fecha': 'Sat Apr 14 23:29:24 +0000 2018',
#   'location': '',
#   'tweet': '#QuieroMiSpalding Grande @canal_CDO Apoyo a las ánimas.Valdivia '
#            'siempre',
#   'username': 'VICTOR NAVARRETE'},
#  {'_id': ObjectId('5ad29659d8694d77f392b68e'),
#   'fecha': 'Sat Apr 14 23:29:24 +0000 2018',
#   'location': 'Temuco, Chile',
#   'tweet': 'RT @municipiotemuco: Muy temprano nuestras vecinas del sector '
#            'Pedro de Valdivia, se reunieron con el alcalde Miguel Becker y su '
#            'equipo, en…',
#   'username': 'Miguel Gamonal'},
#  {'_id': ObjectId('5ad29659d8694d77f392b68f'),
#   'fecha': 'Sat Apr 14 23:29:17 +0000 2018',
#   'location': 'Temuco, Chile',
#   'tweet': 'RT @municipiotemuco: Gracias a todas las vecinas del macrosector '
#            'Pedro de Valdivia por su visita y por compartir sus inquietudes. '
#            '#ContigoM…',
#   'username': 'Miguel Gamonal'},
#  {'_id': ObjectId('5ad29659d8694d77f392b690'),
#   'fecha': 'Sat Apr 14 23:29:11 +0000 2018',
#   'location': 'Temuco, Chile',
#   'tweet': 'RT @municipiotemuco: Ministro de Vivienda y Urbanismo Cristián '
#            'Monckeberg, en compañía del alcalde Miguel Becker y autoridades '
#            'regionales,…',
#   'username': 'Miguel Gamonal'},
#  {'_id': ObjectId('5ad29659d8694d77f392b691'),
#   'fecha': 'Sat Apr 14 23:29:06 +0000 2018',
#   'location': '',
#   'tweet': 'https://t.co/4l7Q3k4YEo',
#   'username': 'Nina Valdivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b692'),
#   'fecha': 'Sat Apr 14 23:28:46 +0000 2018',
#   'location': '',
#   'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ '
#            '#PuertoMontt #Valdivia empatan 2-2 goles para los salmoneros '
#            'Joaquín Diaz y Jaime Gr…',
#   'username': 'Rumbo a Primera #RP'},
#  {'_id': ObjectId('5ad29659d8694d77f392b693'),
#   'fecha': 'Sat Apr 14 23:26:50 +0000 2018',
#   'location': 'Valdivia',
#   'tweet': 'RT @alb0black: Niño comiendo erizos en Mercado Fluvial de '
#            'Valdivia, febrero 1960.\n'
#            '#Chile https://t.co/LxwuNHz8as',
#   'username': 'Danilo Ormeño'},
#  {'_id': ObjectId('5ad29659d8694d77f392b694'),
#   'fecha': 'Sat Apr 14 23:25:09 +0000 2018',
#   'location': '',
#   'tweet': 'https://t.co/mo1DDHvHfP',
#   'username': 'Nancy Valdivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b695'),
#   'fecha': 'Sat Apr 14 23:24:46 +0000 2018',
#   'location': ' coquimbo-chile',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Ana Bermont'},
#  {'_id': ObjectId('5ad29659d8694d77f392b696'),
#   'fecha': 'Sat Apr 14 23:24:09 +0000 2018',
#   'location': '',
#   'tweet': 'Pull up to my bumper baby! This afternoon in #Sarasota #Florida at '
#            'a @MySFF screening of #BloodlightAndBami, a… '
#            'https://t.co/9QuVIiMzdW',
#   'username': 'YuRay Valdivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b697'),
#   'fecha': 'Sat Apr 14 23:23:59 +0000 2018',
#   'location': 'Talca',
#   'tweet': '@EricksenSalinas Hubo una o 2 llegadas con aaalgo de peligro. Pero '
#            'recién en el último cuarto de cancha nos apretab… '
#            'https://t.co/L1NCoWQptr',
#   'username': 'Paulo'},
#  {'_id': ObjectId('5ad29659d8694d77f392b698'),
#   'fecha': 'Sat Apr 14 23:23:15 +0000 2018',
#   'location': 'Santiago de Chile',
#   'tweet': 'RT @ceciliamorel: Qué emoción poder ser parte del primer encuentro '
#            'de la Orquesta Juvenil Regional de Valdivia @FOJIChile. La música '
#            'nos in…',
#   'username': 'Sole Cáceres'},
#  {'_id': ObjectId('5ad29659d8694d77f392b699'),
#   'fecha': 'Sat Apr 14 23:23:11 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: En reunión con Alcalde @omar_sabat '
#            'conversando sobre los desafíos de Valdivia. Una ciudad muy linda y '
#            'según el Alcalde…',
#   'username': 'Micky'},
#  {'_id': ObjectId('5ad29659d8694d77f392b69a'),
#   'fecha': 'Sat Apr 14 23:22:44 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: Seguimos recorriendo Valdivia! '
#            'https://t.co/O2w2OkvKVX',
#   'username': 'Micky'},
#  {'_id': ObjectId('5ad29659d8694d77f392b69b'),
#   'fecha': 'Sat Apr 14 23:22:40 +0000 2018',
#   'location': 'Santiago de Chile',
#   'tweet': 'Naty (M. Pedro de Valdivia): 30.000 la media hora con americana '
#            '!!! Llámame estoy disponible :)… https://t.co/PKuHlezmMT',
#   'username': 'PlanetaEscort.cl'},
#  {'_id': ObjectId('5ad29659d8694d77f392b69c'),
#   'fecha': 'Sat Apr 14 23:22:36 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: Terminando encuentro con pastores en '
#            'Valdivia. Siempre es reconfortante conocer la opinión y recibir el '
#            'apoyo de la co…',
#   'username': 'Micky'},
#  {'_id': ObjectId('5ad29659d8694d77f392b69d'),
#   'fecha': 'Sat Apr 14 23:22:04 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': '🇨🇱 #ValdiviaCL domingo 15: Mín 11º/Máx 15ºC  En la madrugada: '
#            'Nubosidad parcial, ocasionalmente nublado y niebla '
#            'https://t.co/xTAH155ZGc',
#   'username': 'El Tiempo Valdivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b69e'),
#   'fecha': 'Sat Apr 14 23:22:03 +0000 2018',
#   'location': '',
#   'tweet': 'RT @MERIC_Chile: El Centro de Investigación e Innovación en '
#            'Energía Marina @MERIC_Chile inició los preparativos de la 3ª '
#            'versión del Intern…',
#   'username': 'Francisca Terminel'},
#  {'_id': ObjectId('5ad29659d8694d77f392b69f'),
#   'fecha': 'Sat Apr 14 23:20:46 +0000 2018',
#   'location': 'Perú',
#   'tweet': 'RT @legispe: Tutela de derechos y derecho a la prueba del '
#            'sospechoso (Casación 14-2010, La Libertad), por Jaime Coaguila '
#            'Valdivia https://t…',
#   'username': 'Marfe'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a0'),
#   'fecha': 'Sat Apr 14 23:20:30 +0000 2018',
#   'location': 'La Serena',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Daniel San'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a1'),
#   'fecha': 'Sat Apr 14 23:19:20 +0000 2018',
#   'location': 'Venezuela♥/Por ahora en Chile ',
#   'tweet': 'Por el 3ero de la serie Final #LigaDIRECTV Leones de Quilpué Vs. '
#            'Las Ánimas de Valdivia 🏀 en… https://t.co/BOWq9mKvp3',
#   'username': 'Yajaira Basaure'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a2'),
#   'fecha': 'Sat Apr 14 23:19:00 +0000 2018',
#   'location': '',
#   'tweet': '#temuco Dictan acusación contra un General y un Capitán de '
#            'Carabineros (r) por hechos ocurridos en 1973\n'
#            'Abril 6, 20… https://t.co/MnkmBE4BJO',
#   'username': 'El Indio Pérez'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a3'),
#   'fecha': 'Sat Apr 14 23:15:58 +0000 2018',
#   'location': 'Cuiabá-MT',
#   'tweet': '@fcimsep @Copeiro13 @andrizek Surpresa nenhuma vindo desse '
#            'cara!!!Lembra desse safado entregando o Valdívia para o… '
#            'https://t.co/UDcd7zDlVT',
#   'username': 'Dagotiam ENEAcampeão'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a4'),
#   'fecha': 'Sat Apr 14 23:15:12 +0000 2018',
#   'location': 'La Serena, Coquimbo',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Jorge Ortega 🇨🇱'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a5'),
#   'fecha': 'Sat Apr 14 23:14:54 +0000 2018',
#   'location': '',
#   'tweet': '@janatran69 @matizaldivia @JulioBarroso5 No lo hacen porque '
#            'Valdivia y Paredes les ordenan eso. No tienen voz propi… '
#            'https://t.co/FRkKUDkfuT',
#   'username': 'mauricio saldivia'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a6'),
#   'fecha': 'Sat Apr 14 23:14:33 +0000 2018',
#   'location': '',
#   'tweet': 'RT @gidion1208: Los gráficos de la nueva generación son una '
#            'pasada! w/  javigoms  Minimoltech  Manu Valdivia #HAGAMOSVINE #... '
#            'https://t.co…',
#   'username': 'Gidion'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a7'),
#   'fecha': 'Sat Apr 14 23:12:35 +0000 2018',
#   'location': 'Valdivia',
#   'tweet': 'RT @IchiBlake: Vamos Valdivia...todas y todos apoyando a '
#            '@cd_lasanimas #valdiviacl \n'
#            '¡ es nuestro Básquetbol !!',
#   'username': 'Carlos López'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a8'),
#   'fecha': 'Sat Apr 14 23:12:24 +0000 2018',
#   'location': 'Chile, sur',
#   'tweet': 'RT @alb0black: Niño comiendo erizos en Mercado Fluvial de '
#            'Valdivia, febrero 1960.\n'
#            '#Chile https://t.co/LxwuNHz8as',
#   'username': 'Robert Aguayo Rubio'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6a9'),
#   'fecha': 'Sat Apr 14 23:11:52 +0000 2018',
#   'location': 'Valdivia - Chile',
#   'tweet': 'Vamos Valdivia...todas y todos apoyando a @cd_lasanimas '
#            '#valdiviacl \n'
#            '¡ es nuestro Básquetbol !!',
#   'username': 'Alicia Blake'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6aa'),
#   'fecha': 'Sat Apr 14 23:11:40 +0000 2018',
#   'location': 'Nicaragua',
#   'tweet': 'RT @ToruoAzalia: Tengo miedo por lo que esta pasando en el mundo.',
#   'username': 'Andrea V 🌵'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6ab'),
#   'fecha': 'Sat Apr 14 23:11:29 +0000 2018',
#   'location': 'www.deportereyydereyes.cl',
#   'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ '
#            '#PuertoMontt #Valdivia empatan 2-2 goles para los salmoneros '
#            'Joaquín Diaz y Jaime Gr…',
#   'username': 'Juan Antonio Torres'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6ac'),
#   'fecha': 'Sat Apr 14 23:10:50 +0000 2018',
#   'location': 'Lima, Peru',
#   'tweet': 'Tutela de derechos y derecho a la prueba del sospechoso (Casación '
#            '14-2010, La Libertad), por Jaime Coaguila Valdivi… '
#            'https://t.co/Udkt6GNOFD',
#   'username': 'Franco Magnet Zegna'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6ad'),
#   'fecha': 'Sat Apr 14 23:10:43 +0000 2018',
#   'location': '',
#   'tweet': '@chico_perez Es atractiva turísticamente, pero para vivir es '
#            'horrible... Fome, pura lluvia y todo lo atractivo está fuera de '
#            'Valdivia.',
#   'username': 'Ca cm0l3d1 Ja'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6ae'),
#   'fecha': 'Sat Apr 14 23:10:40 +0000 2018',
#   'location': '',
#   'tweet': 'RT @CebolinhaSEP: Espelando alguém dizer plo Flamengo...\n'
#            '\n'
#            '"Poxa,  pla que isso?"\n'
#            '"Deixa pla lá"\n'
#            '"Vai pelder o foco"\n'
#            '"Tá bligando por bobage…',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6af'),
#   'fecha': 'Sat Apr 14 23:10:15 +0000 2018',
#   'location': '',
#   'tweet': '@gustastockler =/',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad29659d8694d77f392b6b0'),
#   'fecha': 'Sat Apr 14 23:10:14 +0000 2018',
#   'location': 'Valdivia- Chile',
#   'tweet': 'Grande @canal_CDO desde Valdivia apoyando a @CDCLosLeones. '
#            '#QuieromiSpalding @camilo_zamora me debe un saludo desde… '
#            'https://t.co/nJCfRaLJwk',
#   'username': 'Benjamin'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b1'),
#   'fecha': 'Sat Apr 14 23:10:12 +0000 2018',
#   'location': '',
#   'tweet': 'Acostados con mí hijo viendo la final de liga DirecTV ... Mi hijo '
#            'quiere el regalito x fis #QuieroMiSpalding https://t.co/8yLS24WIKp',
#   'username': 'David Caifil'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b2'),
#   'fecha': 'Sat Apr 14 23:10:11 +0000 2018',
#   'location': '',
#   'tweet': '#quieromispalding aunque soy del cdv, con todo apoyamos a los '
#            'fantasmas!!!! Vamos con todo apoyando al basquet de valdivia!!!!',
#   'username': '\uf8ff Cristian'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b3'),
#   'fecha': 'Sat Apr 14 23:09:57 +0000 2018',
#   'location': '',
#   'tweet': '@canal_CDO .apoyando a las animas desde Quellon. Saludos a mi hijo '
#            'Luciano Cadin amante del basquetbol que estudia… '
#            'https://t.co/I1c05xHhQn',
#   'username': 'Hermy del Carmen Moyano Haro'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b4'),
#   'fecha': 'Sat Apr 14 23:09:47 +0000 2018',
#   'location': 'Buenos Aires, Argentina',
#   'tweet': 'RT @miguelisaok: Charla con vecinos de Ciudad Valdivia.\n'
#            'Preocupación por la situación económica del País, pero siempre '
#            'frente a las dificul…',
#   'username': 'Mujeres Peronistas'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b5'),
#   'fecha': 'Sat Apr 14 23:09:34 +0000 2018',
#   'location': '',
#   'tweet': '#QuieroMISPALDING por favor que no se pegue el canal....desde '
#            'Valdivia',
#   'username': 'Pamela Uribe'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b6'),
#   'fecha': 'Sat Apr 14 23:09:31 +0000 2018',
#   'location': 'Sleepy Hollow y Calalini',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Abrahel Angell ♀'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b7'),
#   'fecha': 'Sat Apr 14 23:08:39 +0000 2018',
#   'location': 'SP, Brazil',
#   'tweet': '@Valdivia_10 Hoje tá fora do normal',
#   'username': 'GUST∆'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b8'),
#   'fecha': 'Sat Apr 14 23:08:37 +0000 2018',
#   'location': 'Lima, Peru',
#   'tweet': 'Tutela de derechos y derecho a la prueba del sospechoso (Casación '
#            '14-2010, La Libertad), por Jaime Coaguila Valdivia '
#            'https://t.co/moXYLEr8Ml',
#   'username': 'legis.pe'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6b9'),
#   'fecha': 'Sat Apr 14 23:08:06 +0000 2018',
#   'location': '',
#   'tweet': '@gustastockler so hoje? orraaa uhsahuad',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6ba'),
#   'fecha': 'Sat Apr 14 23:07:26 +0000 2018',
#   'location': 'Calama, Chile',
#   'tweet': 'Final jornada día sábado #CampeonatoLoto2018, el puntero consiguió '
#            'un empate en talca ante rangers y D. Valdivia em… '
#            'https://t.co/2TeZKyrZ38',
#   'username': 'Jorge cqn'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6bb'),
#   'fecha': 'Sat Apr 14 23:07:10 +0000 2018',
#   'location': 'Valdivia-Chile',
#   'tweet': '#QuieromiSpalding desde Valdivia apoyando a las '
#            'ánimas👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻👻\n'
#            '#ligadirectv espero ese balón pa… https://t.co/Y4OwyqzZGC',
#   'username': 'Botitas De Tarth'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6bc'),
#   'fecha': 'Sat Apr 14 23:06:52 +0000 2018',
#   'location': 'Lissabon, Portugal',
#   'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#            'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#            '#MarchaPorLaCienc…',
#   'username': 'Science for Progress - Science Advocacy'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6bd'),
#   'fecha': 'Sat Apr 14 23:06:26 +0000 2018',
#   'location': '',
#   'tweet': '@Jovirone1 melhoras jovi \nxesque',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6be'),
#   'fecha': 'Sat Apr 14 23:06:18 +0000 2018',
#   'location': 'La Serena, Coquimbo',
#   'tweet': 'RT @fernandoubiergo: Se va el día en la bella Valdivia.  \n'
#            'Esta noche nuestro concierto a las 22:30 https://t.co/lEkw6aqQYF',
#   'username': 'Fernando Sermeño'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6bf'),
#   'fecha': 'Sat Apr 14 23:06:07 +0000 2018',
#   'location': 'Cuiabá-MT',
#   'tweet': '@WFracari @CebolinhaSEP @andrizek Não esqueci aquela desse cara de '
#            'pau dedar o Valdívia AO VIVO no programa dele para o procurador do '
#            'STJD..',
#   'username': 'Dagotiam ENEAcampeão'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c0'),
#   'fecha': 'Sat Apr 14 23:05:41 +0000 2018',
#   'location': '',
#   'tweet': 'Y aquí estoy... En casa de nuevo, con mi gente, con los que te '
#            'quieren.\n'
#            '\n'
#            'Nos vemos éste noche en Suka!\n'
#            '\n'
#            'PD: Si o no… https://t.co/4NP6J4vzWP',
#   'username': 'Cristian Pérez'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c1'),
#   'fecha': 'Sat Apr 14 23:04:53 +0000 2018',
#   'location': '',
#   'tweet': '@djemerson_crf @FoxSportsBrasil @Flamengo De hoje nem fodendo '
#            'hahahahah',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c2'),
#   'fecha': 'Sat Apr 14 23:04:51 +0000 2018',
#   'location': '',
#   'tweet': 'El recibimiento de los hinchas que viajaron de Valdivia para ver a '
#            '@cd_lasanimas ante @CDCLosLeones en Quilpué… '
#            'https://t.co/e24TvIEerY',
#   'username': 'José Miguel González'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c3'),
#   'fecha': 'Sat Apr 14 23:04:30 +0000 2018',
#   'location': 'Puerto Montt - Chile',
#   'tweet': 'RT @primerabdechile: Terminó.... Terminó, cerrado 2 a 2 entre '
#            '#PuertoMontt y #Valdivia..... Ya 4 fechas sin perder los '
#            'salmoneros y los del…',
#   'username': 'Fernando España T'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c4'),
#   'fecha': 'Sat Apr 14 23:04:14 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: Ahora voy al aire desde Valdivia en @T13 '
#            '#Tele13 conversaré con @Alvaropaci sobre la suspensión de la '
#            'charla de mañana…',
#   'username': 'Peatón Furioso 2017'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c5'),
#   'fecha': 'Sat Apr 14 23:04:08 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: En reunión con Alcalde @omar_sabat '
#            'conversando sobre los desafíos de Valdivia. Una ciudad muy linda y '
#            'según el Alcalde…',
#   'username': 'Peatón Furioso 2017'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c6'),
#   'fecha': 'Sat Apr 14 23:04:02 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: Seguimos recorriendo Valdivia! '
#            'https://t.co/O2w2OkvKVX',
#   'username': 'Peatón Furioso 2017'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c7'),
#   'fecha': 'Sat Apr 14 23:03:55 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: Terminando encuentro con pastores en '
#            'Valdivia. Siempre es reconfortante conocer la opinión y recibir el '
#            'apoyo de la co…',
#   'username': 'Peatón Furioso 2017'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c8'),
#   'fecha': 'Sat Apr 14 23:03:50 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: En la Plaza de Valdivia: conversando con la '
#            'prensa, anotando las inquietudes de la gente; y una que otra '
#            'selfie 📷 http…',
#   'username': 'Peatón Furioso 2017'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6c9'),
#   'fecha': 'Sat Apr 14 23:03:47 +0000 2018',
#   'location': 'Puerto Montt, Chile',
#   'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ '
#            '#PuertoMontt #Valdivia empatan 2-2 goles para los salmoneros '
#            'Joaquín Diaz y Jaime Gr…',
#   'username': 'Puerto es Albiverde'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6ca'),
#   'fecha': 'Sat Apr 14 23:03:24 +0000 2018',
#   'location': 'Puerto Montt, Chile',
#   'tweet': 'RT @omarandrest: Con dos pelotas claras para abrir la cuenta en el '
#            '2do tiempo el arquero de Valdivia se transformó en figura, el '
#            'juego mejo…',
#   'username': 'Puerto es Albiverde'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6cb'),
#   'fecha': 'Sat Apr 14 23:01:46 +0000 2018',
#   'location': 'lucanoland',
#   'tweet': 'RT @tejastermaster: updates de cachimbadas hasta el momento:\n'
#            '1eros = Andrea Luna y Wanxaco\n'
#            '2dos = el cumpleañero Valdivia\n'
#            '3eros = Sandro Fa…',
#   'username': 'Lucano'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6cc'),
#   'fecha': 'Sat Apr 14 23:01:08 +0000 2018',
#   'location': 'Santiago de Chile',
#   'tweet': 'Con dos pelotas claras para abrir la cuenta en el 2do tiempo el '
#            'arquero de Valdivia se transformó en figura, el jue… '
#            'https://t.co/lncuuxO329',
#   'username': 'Omar Téllez Elgueta'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6cd'),
#   'fecha': 'Sat Apr 14 23:01:08 +0000 2018',
#   'location': 'US, Chile and every where',
#   'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#            'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#            '#MarchaPorLaCienc…',
#   'username': 'Maximiliano Bello'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6ce'),
#   'fecha': 'Sat Apr 14 23:01:04 +0000 2018',
#   'location': 'Brasília, Brasil',
#   'tweet': '@Valdivia_10 @FoxSportsBrasil @Flamengo Irmão, eu acho que não '
#            'foi, vc acha. Tem analista que acha que foi é que nã… '
#            'https://t.co/LEQhAOhN1u',
#   'username': 'CRF Djemerson'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6cf'),
#   'fecha': 'Sat Apr 14 23:00:57 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'Valdivia empata a dos contra Puerto Montt https://t.co/jQlaRwx9BZ',
#   'username': 'soyvaldivia.cl'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d0'),
#   'fecha': 'Sat Apr 14 23:00:46 +0000 2018',
#   'location': '',
#   'tweet': 'RT @primerabdechile: Terminó.... Terminó, cerrado 2 a 2 entre '
#            '#PuertoMontt y #Valdivia..... Ya 4 fechas sin perder los '
#            'salmoneros y los del…',
#   'username': 'Felipe Gonzalez'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d1'),
#   'fecha': 'Sat Apr 14 23:00:43 +0000 2018',
#   'location': 'Yungay 499, Valdivia',
#   'tweet': 'Valdivia empata a dos contra Puerto Montt https://t.co/Ijw7N4aEhN',
#   'username': 'Diario Austral'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d2'),
#   'fecha': 'Sat Apr 14 23:00:33 +0000 2018',
#   'location': '',
#   'tweet': 'Final ! Deportes Puerto Montt 2-2 Deportes Valdivia',
#   'username': 'Felipe Gonzalez'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d3'),
#   'fecha': 'Sat Apr 14 23:00:19 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'RT @primerabdechile: Terminó.... Terminó, cerrado 2 a 2 entre '
#            '#PuertoMontt y #Valdivia..... Ya 4 fechas sin perder los '
#            'salmoneros y los del…',
#   'username': 'Sevienencambios!!!!'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d4'),
#   'fecha': 'Sat Apr 14 23:00:00 +0000 2018',
#   'location': '',
#   'tweet': 'Fiscalizaron obras de #QuieroMiBarrio del @Minvu en el sector '
#            '#TenienteMerino de #Valdivia https://t.co/L5aIdncLEL… '
#            'https://t.co/SDw2UvLvl7',
#   'username': 'Quiero Mi Barrio'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d5'),
#   'fecha': 'Sat Apr 14 22:59:38 +0000 2018',
#   'location': 'Santiago Chile',
#   'tweet': 'RT @ceciliamorel: Seguimos en nuestra gira por la región de Los '
#            'Ríos. Ya estamos en Valdivia, feliz de seguir conociendo '
#            'propuestas que mej…',
#   'username': 'Silvia H Martínez S'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d6'),
#   'fecha': 'Sat Apr 14 22:59:27 +0000 2018',
#   'location': '',
#   'tweet': 'RT @DeUrrestiSenado: Hoy acompañamos a las Agrupación de Parkinson '
#            'Valdivia en la primera marcha 45 socios que se han propuesto '
#            'conseguir u…',
#   'username': 'BrigadaParlamentariaPS'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d7'),
#   'fecha': 'Sat Apr 14 22:59:17 +0000 2018',
#   'location': 'Puerto Montt',
#   'tweet': 'Termina el partido en un empate a 2 goles por lado entre Dptes '
#            'Puerto Montt y Dptes Valdivia en el clásico del sur de Chile',
#   'username': 'Fernando España E'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d8'),
#   'fecha': 'Sat Apr 14 22:59:16 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Terminó.... Terminó, cerrado 2 a 2 entre #PuertoMontt y '
#            '#Valdivia..... Ya 4 fechas sin perder los salmoneros y los… '
#            'https://t.co/asRieIY2b7',
#   'username': 'primerabchile'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6d9'),
#   'fecha': 'Sat Apr 14 22:59:06 +0000 2018',
#   'location': 'Santiago, Chile',
#   'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ '
#            '#PuertoMontt #Valdivia empatan 2-2 goles para los salmoneros '
#            'Joaquín Diaz y Jaime Gr…',
#   'username': 'Fco. Nasser Viligrón'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6da'),
#   'fecha': 'Sat Apr 14 22:58:28 +0000 2018',
#   'location': 'Medellín, Colombia',
#   'tweet': 'RT @JairoSa81951568: @ANI_Colombia @MinTransporteCo '
#            '@TransitoPolicia la infraestructura vial en la vía Yarumal puerto '
#            'Valdivia es pésima pa…',
#   'username': 'mige'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6db'),
#   'fecha': 'Sat Apr 14 22:58:20 +0000 2018',
#   'location': '',
#   'tweet': '@andrizek hahahha e o jogo do palmeiras foi tudo normal ne? '
#            'hahahahah',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6dc'),
#   'fecha': 'Sat Apr 14 22:58:07 +0000 2018',
#   'location': 'Valdivia-Chile',
#   'tweet': 'RT @AndreaObaid: Mañana a las 1630hs te invito a viajar con '
#            'nosotros con @Tecno_ciencia que ahora se emite en TV abierta por '
#            '@canal13. Irem…',
#   'username': 'Mylthon'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6dd'),
#   'fecha': 'Sat Apr 14 22:57:47 +0000 2018',
#   'location': '',
#   'tweet': 'El referi F. Jara declara que el partido entre Puerto Montt y D. '
#            'Valdivia esta empatado.',
#   'username': 'Orsai Chile'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6de'),
#   'fecha': 'Sat Apr 14 22:57:38 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'RT @kandyuc: FINAL PARTIDO| ante 3.302 espectadores ⚽️ '
#            '#PuertoMontt #Valdivia empatan 2-2 goles para los salmoneros '
#            'Joaquín Diaz y Jaime Gr…',
#   'username': 'primerabchile'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6df'),
#   'fecha': 'Sat Apr 14 22:57:14 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'La gente se pregunta si #PuertoMontt juega a ganar o a no perder '
#            'contra #Valdivia....',
#   'username': 'primerabchile'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e0'),
#   'fecha': 'Sat Apr 14 22:57:07 +0000 2018',
#   'location': '',
#   'tweet': 'FINAL PARTIDO| ante 3.302 espectadores ⚽️ #PuertoMontt #Valdivia '
#            'empatan 2-2 goles para los salmoneros Joaquín Diaz… '
#            'https://t.co/cRN6oWPviJ',
#   'username': 'ale argandoña'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e1'),
#   'fecha': 'Sat Apr 14 22:57:02 +0000 2018',
#   'location': '',
#   'tweet': '@djemerson_crf @FoxSportsBrasil @Flamengo ahh nao foi? se pega a '
#            'bola antes e depois o jogador nao é penalti? entao… '
#            'https://t.co/kw1ipPWUIi',
#   'username': 'CHINELINHO'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e2'),
#   'fecha': 'Sat Apr 14 22:56:17 +0000 2018',
#   'location': '',
#   'tweet': 'Me dijo q era la unica y tenía 20 gatas🎶',
#   'username': 'Nina Valdivia'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e3'),
#   'fecha': 'Sat Apr 14 22:55:56 +0000 2018',
#   'location': 'São Mateus, SP',
#   'tweet': 'RT @victorschimidt1: Meu #SPFC ideal seria esse. \n'
#            'Com a variação de Militão se posicionando como zagueiro no momento '
#            'ofensivo, júnior abert…',
#   'username': 'nessa| força Barça  🇾🇪'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e4'),
#   'fecha': 'Sat Apr 14 22:55:50 +0000 2018',
#   'location': 'Chile',
#   'tweet': "90'+4' ¡TERMINÓ EL PARTIDO!\n"
#            '\n'
#            'Deportes Puerto Montt y Deportes Valdivia repartieron puntos tras '
#            'igualar 2-2 en el Ch… https://t.co/IX500Drfal',
#   'username': 'En el Camarín'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e5'),
#   'fecha': 'Sat Apr 14 22:55:29 +0000 2018',
#   'location': 'Chile, Los Rios',
#   'tweet': 'RT @ChristieCarla: En #Valdivia marcha por la ciencia y el '
#            'conocimiento @ScienceMarchCL @MasCienciaChile @UAustraldeChile '
#            '#MarchaPorLaCienc…',
#   'username': 'Valdiviano'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e6'),
#   'fecha': 'Sat Apr 14 22:55:15 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Amarilla para Poncet en el Torreón.... Minuto 92 se acaba el '
#            '#PuertoMontt #Valdivia con cerrado empate.',
#   'username': 'primerabchile'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e7'),
#   'fecha': 'Sat Apr 14 22:55:02 +0000 2018',
#   'location': '',
#   'tweet': 'Thor con mis hijos en Valdivia, Chile https://t.co/RmexJX0TaL',
#   'username': 'armandomirabal'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e8'),
#   'fecha': 'Sat Apr 14 22:54:43 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'A minutos que comience el 3 juego @CDCLosLeones @cd_lasanimas '
#            '#valdiviacl Final @liga_nacional https://t.co/TteXPBinuu',
#   'username': 'CoolTV'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6e9'),
#   'fecha': 'Sat Apr 14 22:54:18 +0000 2018',
#   'location': 'Brasília, Brasil',
#   'tweet': '@Valdivia_10 @FoxSportsBrasil @Flamengo O negócio é que não foi '
#            'penal no Dudu. Que comparação medíocre.',
#   'username': 'CRF Djemerson'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6ea'),
#   'fecha': 'Sat Apr 14 22:53:46 +0000 2018',
#   'location': '',
#   'tweet': "#PrimeraB | 90+2' AMARILLA para Gastón Poncet en Deportes "
#            'Valdivia. DPM 2-2 DV. https://t.co/MXqo07bJYt',
#   'username': 'Rumbo a Primera #RP'},
#  {'_id': ObjectId('5ad2965ad8694d77f392b6eb'),
#   'fecha': 'Sat Apr 14 22:53:39 +0000 2018',
#   'location': 'Chile',
# ...
#            'uniformes y textos en la UE "Valdivia" parroquia Manglaralto, '
#            'indicandoles a l…',
#   'username': 'Lolita Del Carmen'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b80c'),
#   'fecha': 'Sat Apr 14 20:46:31 +0000 2018',
#   'location': 'são paulo fc real madrid cf',
#   'tweet': 'valdivia, everton e carneiro\n'
#            'olha o contra ataque https://t.co/bBRy0L45Ts',
#   'username': 'pedro'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b80d'),
#   'fecha': 'Sat Apr 14 20:46:17 +0000 2018',
#   'location': 'México City',
#   'tweet': 'https://t.co/17zlJwqhzK',
#   'username': 'Andrea'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b80e'),
#   'fecha': 'Sat Apr 14 20:46:15 +0000 2018',
#   'location': '',
#   'tweet': 'RT @la_serena_chile: 🏈Alcalde Roberto Jacob junto al presidente de '
#            'la Asociación de Rugby La Serena, Robertino Collao, firmaron un '
#            'convenio…',
#   'username': 'leonidas chavez'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b80f'),
#   'fecha': 'Sat Apr 14 20:46:13 +0000 2018',
#   'location': '',
#   'tweet': 'RT @primerabdechile: Ya se vieneeeee..... Desde el Chinquihue '
#            'Puerto Montt - Valdivia, linfático tarde para ver fútbol',
#   'username': 'Felipe Gonzalez'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b810'),
#   'fecha': 'Sat Apr 14 20:45:45 +0000 2018',
#   'location': 'LA PAZ, BCS',
#   'tweet': 'RT @Martinez1Felip: Juan Alberto Valdivia Alvarado; candidato '
#            'priista a senador de la Republica, cabalga en caballo de hacienda '
#            'hacia la me…',
#   'username': 'JUANALBERTO VALDIVIA'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b811'),
#   'fecha': 'Sat Apr 14 20:45:26 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'Poco menos de una semanita para la próxima #BeerJSValdivia 😱 Ya '
#            'estamos preparando las presentaciones para el 19 de… '
#            'https://t.co/P4PwL0f5bF',
#   'username': 'BeerJS Valdivia'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b812'),
#   'fecha': 'Sat Apr 14 20:45:15 +0000 2018',
#   'location': 'machali-santiago',
#   'tweet': 'RT @alb0black: Niño comiendo erizos en Mercado Fluvial de '
#            'Valdivia, febrero 1960.\n'
#            '#Chile https://t.co/LxwuNHz8as',
#   'username': 'pablo rojo latapiat'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b813'),
#   'fecha': 'Sat Apr 14 20:45:03 +0000 2018',
#   'location': 'Región de Coquimbo- Chile',
#   'tweet': 'RT @la_serena_chile: 🏈Alcalde Roberto Jacob junto al presidente de '
#            'la Asociación de Rugby La Serena, Robertino Collao, firmaron un '
#            'convenio…',
#   'username': 'serenaycoquimbo'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b814'),
#   'fecha': 'Sat Apr 14 20:44:42 +0000 2018',
#   'location': 'La Serena, Chile',
#   'tweet': '🏈Alcalde Roberto Jacob junto al presidente de la Asociación de '
#            'Rugby La Serena, Robertino Collao, firmaron un conve… '
#            'https://t.co/dxJaiqIjPn',
#   'username': 'Municipio La Serena'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b815'),
#   'fecha': 'Sat Apr 14 20:44:35 +0000 2018',
#   'location': '',
#   'tweet': 'RT @joseantoniokast: Terminando encuentro con pastores en '
#            'Valdivia. Siempre es reconfortante conocer la opinión y recibir el '
#            'apoyo de la co…',
#   'username': 'estreangel'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b816'),
#   'fecha': 'Sat Apr 14 20:44:33 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Vai toma no seu cu @Cruzeiro',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b817'),
#   'fecha': 'Sat Apr 14 20:43:31 +0000 2018',
#   'location': 'Puerto Montt, Chile',
#   'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#            'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#            'Capitán.\n'
#            '\n'
#            'Ban…',
#   'username': 'Nadia Parra'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b818'),
#   'fecha': 'Sat Apr 14 20:43:12 +0000 2018',
#   'location': 'México City',
#   'tweet': 'https://t.co/2W6vZXQ3Sl',
#   'username': 'Andrea'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b819'),
#   'fecha': 'Sat Apr 14 20:42:44 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Camisa do Cruzeiro ta igual o Futebol do time acertou em cheio a '
#            'umbro',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b81a'),
#   'fecha': 'Sat Apr 14 20:42:25 +0000 2018',
#   'location': 'Puerto Montt, Chile',
#   'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#            'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#            'Capitán.\n'
#            '\n'
#            'Ban…',
#   'username': 'Mun. Puerto Montt'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b81b'),
#   'fecha': 'Sat Apr 14 20:42:23 +0000 2018',
#   'location': '',
#   'tweet': 'RT @Carabdechile: Carabineros del OS7 #LosRíos, procedió  a la '
#            'detección de dos hombres y una mujer extranjera por tráfico de '
#            'drogas, en la…',
#   'username': 'estreangel'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b81c'),
#   'fecha': 'Sat Apr 14 20:42:08 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'RT @vivisleles: Camisa feia pra combinar com o futebol desses '
#            'babacas',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b81d'),
#   'fecha': 'Sat Apr 14 20:41:47 +0000 2018',
#   'location': 'Camino Coñaripe-Liquiñe Km 15',
#   'tweet': 'Descubre lo que Termas Coñaripe tiene para ti!\n'
#            'el mejor servicio a tu disposición para un descanso soñado\n'
#            'no dejes… https://t.co/OJCSakgM1S',
#   'username': 'Termas Coñaripe'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b81e'),
#   'fecha': 'Sat Apr 14 20:41:35 +0000 2018',
#   'location': 'Santiago de Chile',
#   'tweet': 'Niño comiendo erizos en Mercado Fluvial de Valdivia, febrero '
#            '1960.\n'
#            '#Chile https://t.co/LxwuNHz8as',
#   'username': 'Alberto Sironvalle'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b81f'),
#   'fecha': 'Sat Apr 14 20:41:22 +0000 2018',
#   'location': 'Valdivia',
#   'tweet': 'RT @biobio: Carabineros allana local clandestino de alcohol en '
#            'Valdivia: detienen a decena de jóvenes https://t.co/68BlM6BCJ6 '
#            'https://t.co/…',
#   'username': 'Alexis'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b820'),
#   'fecha': 'Sat Apr 14 20:40:50 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Meu sonho é sair no soco com o Egídio',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b821'),
#   'fecha': 'Sat Apr 14 20:40:09 +0000 2018',
#   'location': 'México City',
#   'tweet': 'https://t.co/Qlc66pizwR',
#   'username': 'Andrea'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b822'),
#   'fecha': 'Sat Apr 14 20:39:50 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Árbitro: Felipe Jara\n'
#            'Asist 1: Julio Abdala\n'
#            'Asist 2: Rodrigo Concha\n'
#            '4to árbitro: Víctor Abarzúa\n'
#            '\n'
#            'Deportes Puerto Mon… https://t.co/p2BjlsF6oF',
#   'username': 'En el Camarín'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b823'),
#   'fecha': 'Sat Apr 14 20:39:33 +0000 2018',
#   'location': '',
#   'tweet': 'Gil que no activo, guacha que se le escapo.',
#   'username': 'Nina Valdivia'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b824'),
#   'fecha': 'Sat Apr 14 20:38:33 +0000 2018',
#   'location': '',
#   'tweet': 'RT @IndirectasRock: Uno intenta, intenta, intenta.. Hasta que no '
#            'intenta más.',
#   'username': 'Nina Valdivia'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b825'),
#   'fecha': 'Sat Apr 14 20:38:33 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Banca de Deportes Valdivia:\n'
#            '\n'
#            '33 Richard Leyton (AS)\n'
#            '15 Antonio Castillo\n'
#            '5 Max Gatica\n'
#            '19 Ignacio Torres\n'
#            '14 Jorge Gal… https://t.co/5hHoBCLsW2',
#   'username': 'En el Camarín'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b826'),
#   'fecha': 'Sat Apr 14 20:37:20 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Banca de Deportes Puerto Montt:\n'
#            '\n'
#            '12 Cristian Limenza (AS)\n'
#            '11 Hernán Becica\n'
#            '13 Leandro Delgado\n'
#            '9 Javier Guarino\n'
#            '28 B… https://t.co/PJ342YItiB',
#   'username': 'En el Camarín'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b827'),
#   'fecha': 'Sat Apr 14 20:35:54 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Parei com o Brasileirão na primeira rodada',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b828'),
#   'fecha': 'Sat Apr 14 20:35:14 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Time que quer ganhar jogo não pode colocar Rafael Marques',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b829'),
#   'fecha': 'Sat Apr 14 20:34:38 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Formación de Deportes Valdivia:\n'
#            '\n'
#            '1 Diego Figueroa\n'
#            '\n'
#            '8 Pablo Leal\n'
#            '17 Cristián González\n'
#            '23 Victor González\n'
#            '\n'
#            '11 Erick W… https://t.co/pMkUBXZ0hI',
#   'username': 'En el Camarín'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b82a'),
#   'fecha': 'Sat Apr 14 20:33:28 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Mano Menezes colocou Rafael Marques pra ficar 10 contra 10',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b82b'),
#   'fecha': 'Sat Apr 14 20:32:49 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Esse Boludo ta é tirando de reclamar ainda',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b82c'),
#   'fecha': 'Sat Apr 14 20:32:47 +0000 2018',
#   'location': '',
#   'tweet': 'RT @primerabdechile: Ya se vieneeeee..... Desde el Chinquihue '
#            'Puerto Montt - Valdivia, linfático tarde para ver fútbol',
#   'username': 'Dani Uz'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b82d'),
#   'fecha': 'Sat Apr 14 20:32:34 +0000 2018',
#   'location': '',
#   'tweet': 'RT @primerabdechile: Ya se vieneeeee..... Desde el Chinquihue '
#            'Puerto Montt - Valdivia, linfático tarde para ver fútbol',
#   'username': 'JUAN CARLOS'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b82e'),
#   'fecha': 'Sat Apr 14 20:31:52 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': '@Omar_Sabat @munivaldivia Pero Alcalde no me de respuestas, sea un '
#            'Alcalde con  acción... sabe, ud no me cae mal al… '
#            'https://t.co/g0a2R5zmN2',
#   'username': 'Lorenzo Yañez'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b82f'),
#   'fecha': 'Sat Apr 14 20:31:32 +0000 2018',
#   'location': 'Chile',
#   'tweet': 'Ya se vieneeeee..... Desde el Chinquihue Puerto Montt - Valdivia, '
#            'linfático tarde para ver fútbol',
#   'username': 'primerabchile'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b830'),
#   'fecha': 'Sat Apr 14 20:31:31 +0000 2018',
#   'location': '',
#   'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#            'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#            'Capitán.\n'
#            '\n'
#            'Ban…',
#   'username': 'delacunaaltablon'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b831'),
#   'fecha': 'Sat Apr 14 20:31:20 +0000 2018',
#   'location': 'Santiago, Chile',
#   'tweet': "I'm at Metro Pedro de Valdivia in Santiago, Región Metropolitana "
#            'https://t.co/UubelqLm3k',
#   'username': 'Jonathan Munizaga'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b832'),
#   'fecha': 'Sat Apr 14 20:30:00 +0000 2018',
#   'location': 'Valdivia, Chile',
#   'tweet': 'Área Silvestre Pilunkura te invita este 28 de abril a participar '
#            'colaborativamente en la construcción de su portal… '
#            'https://t.co/wm6xyGUfEP',
#   'username': 'Vive Valdivia'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b833'),
#   'fecha': 'Sat Apr 14 20:29:27 +0000 2018',
#   'location': 'Nicaragua',
#   'tweet': 'RT @realestelifc: Volvemos a Diriamba y Galeano lo sabe... '
#            'https://t.co/Yr1nUoUzVz',
#   'username': 'Andrea V 🌵'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b834'),
#   'fecha': 'Sat Apr 14 20:28:57 +0000 2018',
#   'location': '',
#   'tweet': 'RT @XicanitaBonita: My own attitude stresses me out sometimes. I '
#            'get mad at me for being mad.',
#   'username': 'Jackie'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b835'),
#   'fecha': 'Sat Apr 14 20:28:15 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Ainda bem q eu nem me iludi com Brasileirão',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b836'),
#   'fecha': 'Sat Apr 14 20:28:06 +0000 2018',
#   'location': 'Puerto Montt Chile',
#   'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#            'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#            'Capitán.\n'
#            '\n'
#            'Ban…',
#   'username': 'MarcosVelasquez'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b837'),
#   'fecha': 'Sat Apr 14 20:26:25 +0000 2018',
#   'location': 'Sete Lagoas, Minas Gerais',
#   'tweet': 'Virou modinha msm https://t.co/5cUd2HaGl7',
#   'username': 'Bieel™'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b838'),
#   'fecha': 'Sat Apr 14 20:25:44 +0000 2018',
#   'location': 'Puerto Montt, Chile',
#   'tweet': 'RT @DPMChile: Estos son los 11 elegidos por Luis Landeros para '
#            'enfrentar a @depvaldivia a partir de las 18 hrs. Fabián Moyano '
#            'Capitán.\n'
#            '\n'
#            'Ban…',
#   'username': 'Torneo_CL'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b839'),
#   'fecha': 'Sat Apr 14 20:25:22 +0000 2018',
#   'location': 'México City',
#   'tweet': 'https://t.co/nPtnb2jK8A',
#   'username': 'Andrea'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b83a'),
#   'fecha': 'Sat Apr 14 20:24:03 +0000 2018',
#   'location': 'Puerto Montt, Chile',
#   'tweet': '⚽️  TABLA DE POSICIONES ⚽️ Así llegan Deportes #PuertoMontt y '
#            '#Valdivia al juego de hoy en el estadio Chinquihue. ¡… '
#            'https://t.co/DwFMYPPadk',
#   'username': 'Torneo_CL'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b83b'),
#   'fecha': 'Sat Apr 14 20:23:46 +0000 2018',
#   'location': 'Antofagasta, Chile',
#   'tweet': 'RT @RedInvestChile: En Valdivia, también se hace presente la Red '
#            'de Investigadoras en la #marchaporlaciencia '
#            'https://t.co/uXB5XczoPn',
#   'username': 'BERNARDITA'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b83c'),
#   'fecha': 'Sat Apr 14 20:23:42 +0000 2018',
#   'location': '',
#   'tweet': 'https://t.co/EOZEDxr9yY',
#   'username': 'JohnnyBet Picks'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b83d'),
#   'fecha': 'Sat Apr 14 20:22:57 +0000 2018',
#   'location': '',
#   'tweet': '#PrimeraB | Deportes Puerto Montt vs Deportes Valdivia\n'
#            '\n'
#            'Xl de Deportes Valdivia:\n'
#            '\n'
#            'Diego Figueroa\n'
#            '*\n'
#            'Pablo Leal\n'
#            'Crist… https://t.co/CX0S6MYKhs',
#   'username': 'Rumbo a Primera #RP'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b83e'),
#   'fecha': 'Sat Apr 14 20:22:56 +0000 2018',
#   'location': '',
#   'tweet': 'Banca de suplentes\n'
#            '\n'
#            'Cristián Limenza (A. S. )\n'
#            'Leandro Delgado\n'
#            'Benjamín Valdivia\n'
#            'Albano Becica\n'
#            'Jorge Guajardo\n'
#            'Javier… https://t.co/sZuiKgmvjt',
#   'username': 'Rumbo a Primera #RP'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b83f'),
#   'fecha': 'Sat Apr 14 20:22:54 +0000 2018',
#   'location': '',
#   'tweet': '#PrimeraB | Deportes Puerto Montt vs Deportes Valdivia\n'
#            '\n'
#            'Xl de Deportes Puerto Montt:\n'
#            '\n'
#            'Fabián Moyano\n'
#            '*\n'
#            'Joaquín Díaz… https://t.co/hOk3GXLaqN',
#   'username': 'Rumbo a Primera #RP'},
#  {'_id': ObjectId('5ad2965dd8694d77f392b840'),
#   'fecha': 'Sat Apr 14 20:22:51 +0000 2018',
#   'location': '',
#   'tweet': '#PrimeraB | ¡SE REEDITA EL CLÁSICO DEL SUR! Luego a las 18:00 '
#            'horas Deportes Puerto Montt recibe a Deportes Valdivia, en el '
#            'Chinquihue.',
#   'username': 'Rumbo a Primera #RP'}]
